# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Run0104 based model
#
# -  theta = 0.2

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-09-26_Run0107.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-09-26_Run0107
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='relu')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.2)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 96s - loss: 0.2810 - mean_absolute_error: 0.3743 - mean_squared_error: 0.2764 - rmse: 0.4912 - val_loss: 0.2827 - val_mean_absolute_error: 0.3907 - val_mean_squared_error: 0.2769 - val_rmse: 0.4746
# Epoch 2/100
#  - 92s - loss: 0.2033 - mean_absolute_error: 0.3208 - mean_squared_error: 0.1971 - rmse: 0.4216 - val_loss: 0.2798 - val_mean_absolute_error: 0.3815 - val_mean_squared_error: 0.2732 - val_rmse: 0.4653
# Epoch 3/100
#  - 103s - loss: 0.1997 - mean_absolute_error: 0.3172 - mean_squared_error: 0.1930 - rmse: 0.4169 - val_loss: 0.2694 - val_mean_absolute_error: 0.3757 - val_mean_squared_error: 0.2625 - val_rmse: 0.4574
# Epoch 4/100
#  - 89s - loss: 0.1972 - mean_absolute_error: 0.3146 - mean_squared_error: 0.1901 - rmse: 0.4138 - val_loss: 0.2689 - val_mean_absolute_error: 0.3671 - val_mean_squared_error: 0.2616 - val_rmse: 0.4508
# Epoch 5/100
#  - 91s - loss: 0.1951 - mean_absolute_error: 0.3124 - mean_squared_error: 0.1876 - rmse: 0.4109 - val_loss: 0.2709 - val_mean_absolute_error: 0.3746 - val_mean_squared_error: 0.2633 - val_rmse: 0.4558
# Epoch 6/100
#  - 99s - loss: 0.1940 - mean_absolute_error: 0.3111 - mean_squared_error: 0.1862 - rmse: 0.4096 - val_loss: 0.2687 - val_mean_absolute_error: 0.3770 - val_mean_squared_error: 0.2608 - val_rmse: 0.4580
# Epoch 7/100
#  - 97s - loss: 0.1934 - mean_absolute_error: 0.3104 - mean_squared_error: 0.1855 - rmse: 0.4086 - val_loss: 0.2535 - val_mean_absolute_error: 0.3628 - val_mean_squared_error: 0.2454 - val_rmse: 0.4441
# Epoch 8/100
#  - 95s - loss: 0.1930 - mean_absolute_error: 0.3098 - mean_squared_error: 0.1849 - rmse: 0.4078 - val_loss: 0.2734 - val_mean_absolute_error: 0.3717 - val_mean_squared_error: 0.2652 - val_rmse: 0.4516
# Epoch 9/100
#  - 89s - loss: 0.1928 - mean_absolute_error: 0.3096 - mean_squared_error: 0.1846 - rmse: 0.4076 - val_loss: 0.2600 - val_mean_absolute_error: 0.3621 - val_mean_squared_error: 0.2518 - val_rmse: 0.4440
# Epoch 10/100
#  - 94s - loss: 0.1925 - mean_absolute_error: 0.3093 - mean_squared_error: 0.1842 - rmse: 0.4073 - val_loss: 0.2758 - val_mean_absolute_error: 0.3722 - val_mean_squared_error: 0.2676 - val_rmse: 0.4519
# Epoch 11/100
#  - 99s - loss: 0.1924 - mean_absolute_error: 0.3092 - mean_squared_error: 0.1841 - rmse: 0.4072 - val_loss: 0.2572 - val_mean_absolute_error: 0.3622 - val_mean_squared_error: 0.2489 - val_rmse: 0.4455
# Epoch 12/100
#  - 97s - loss: 0.1920 - mean_absolute_error: 0.3087 - mean_squared_error: 0.1837 - rmse: 0.4066 - val_loss: 0.2635 - val_mean_absolute_error: 0.3764 - val_mean_squared_error: 0.2552 - val_rmse: 0.4578
# Epoch 13/100
#  - 99s - loss: 0.1919 - mean_absolute_error: 0.3087 - mean_squared_error: 0.1836 - rmse: 0.4063 - val_loss: 0.2671 - val_mean_absolute_error: 0.3688 - val_mean_squared_error: 0.2588 - val_rmse: 0.4497
# Epoch 14/100
#  - 92s - loss: 0.1919 - mean_absolute_error: 0.3085 - mean_squared_error: 0.1835 - rmse: 0.4063 - val_loss: 0.2831 - val_mean_absolute_error: 0.3862 - val_mean_squared_error: 0.2748 - val_rmse: 0.4627
# Epoch 15/100
#  - 101s - loss: 0.1916 - mean_absolute_error: 0.3082 - mean_squared_error: 0.1832 - rmse: 0.4060 - val_loss: 0.2686 - val_mean_absolute_error: 0.3701 - val_mean_squared_error: 0.2602 - val_rmse: 0.4523
# Epoch 16/100
#  - 101s - loss: 0.1914 - mean_absolute_error: 0.3081 - mean_squared_error: 0.1830 - rmse: 0.4057 - val_loss: 0.2769 - val_mean_absolute_error: 0.3784 - val_mean_squared_error: 0.2686 - val_rmse: 0.4582
# Epoch 17/100
#  - 99s - loss: 0.1911 - mean_absolute_error: 0.3077 - mean_squared_error: 0.1828 - rmse: 0.4055 - val_loss: 0.2839 - val_mean_absolute_error: 0.3815 - val_mean_squared_error: 0.2755 - val_rmse: 0.4629
# Epoch 18/100
#  - 99s - loss: 0.1911 - mean_absolute_error: 0.3077 - mean_squared_error: 0.1827 - rmse: 0.4053 - val_loss: 0.2855 - val_mean_absolute_error: 0.3823 - val_mean_squared_error: 0.2770 - val_rmse: 0.4636
# Epoch 19/100
#  - 100s - loss: 0.1909 - mean_absolute_error: 0.3074 - mean_squared_error: 0.1824 - rmse: 0.4050 - val_loss: 0.2630 - val_mean_absolute_error: 0.3723 - val_mean_squared_error: 0.2544 - val_rmse: 0.4538
# Epoch 20/100
#  - 103s - loss: 0.1907 - mean_absolute_error: 0.3071 - mean_squared_error: 0.1822 - rmse: 0.4049 - val_loss: 0.2748 - val_mean_absolute_error: 0.3750 - val_mean_squared_error: 0.2662 - val_rmse: 0.4568
# Epoch 21/100
#  - 96s - loss: 0.1907 - mean_absolute_error: 0.3070 - mean_squared_error: 0.1821 - rmse: 0.4046 - val_loss: 0.2570 - val_mean_absolute_error: 0.3651 - val_mean_squared_error: 0.2484 - val_rmse: 0.4467
# Epoch 22/100
#  - 100s - loss: 0.1907 - mean_absolute_error: 0.3070 - mean_squared_error: 0.1821 - rmse: 0.4046 - val_loss: 0.2661 - val_mean_absolute_error: 0.3717 - val_mean_squared_error: 0.2574 - val_rmse: 0.4524
# Epoch 23/100
#  - 104s - loss: 0.1906 - mean_absolute_error: 0.3069 - mean_squared_error: 0.1819 - rmse: 0.4044 - val_loss: 0.2596 - val_mean_absolute_error: 0.3654 - val_mean_squared_error: 0.2509 - val_rmse: 0.4454
# Epoch 24/100
#  - 99s - loss: 0.1905 - mean_absolute_error: 0.3067 - mean_squared_error: 0.1818 - rmse: 0.4042 - val_loss: 0.2490 - val_mean_absolute_error: 0.3540 - val_mean_squared_error: 0.2402 - val_rmse: 0.4343
# Epoch 25/100
#  - 99s - loss: 0.1905 - mean_absolute_error: 0.3066 - mean_squared_error: 0.1817 - rmse: 0.4042 - val_loss: 0.2691 - val_mean_absolute_error: 0.3679 - val_mean_squared_error: 0.2603 - val_rmse: 0.4486
# Epoch 26/100
#  - 94s - loss: 0.1905 - mean_absolute_error: 0.3068 - mean_squared_error: 0.1817 - rmse: 0.4042 - val_loss: 0.2558 - val_mean_absolute_error: 0.3580 - val_mean_squared_error: 0.2469 - val_rmse: 0.4387
# Epoch 27/100
#  - 98s - loss: 0.1905 - mean_absolute_error: 0.3066 - mean_squared_error: 0.1816 - rmse: 0.4041 - val_loss: 0.2557 - val_mean_absolute_error: 0.3576 - val_mean_squared_error: 0.2468 - val_rmse: 0.4399
# Epoch 28/100
#  - 104s - loss: 0.1903 - mean_absolute_error: 0.3066 - mean_squared_error: 0.1814 - rmse: 0.4038 - val_loss: 0.2588 - val_mean_absolute_error: 0.3579 - val_mean_squared_error: 0.2500 - val_rmse: 0.4404
# Epoch 29/100
#  - 111s - loss: 0.1905 - mean_absolute_error: 0.3067 - mean_squared_error: 0.1816 - rmse: 0.4041 - val_loss: 0.2618 - val_mean_absolute_error: 0.3694 - val_mean_squared_error: 0.2529 - val_rmse: 0.4496
# Epoch 30/100
#  - 105s - loss: 0.1904 - mean_absolute_error: 0.3066 - mean_squared_error: 0.1815 - rmse: 0.4039 - val_loss: 0.2546 - val_mean_absolute_error: 0.3589 - val_mean_squared_error: 0.2457 - val_rmse: 0.4400
# Epoch 31/100
#  - 104s - loss: 0.1903 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1814 - rmse: 0.4039 - val_loss: 0.2670 - val_mean_absolute_error: 0.3674 - val_mean_squared_error: 0.2581 - val_rmse: 0.4499
# Epoch 32/100
#  - 104s - loss: 0.1904 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1815 - rmse: 0.4038 - val_loss: 0.2494 - val_mean_absolute_error: 0.3583 - val_mean_squared_error: 0.2405 - val_rmse: 0.4381
# Epoch 33/100
#  - 97s - loss: 0.1904 - mean_absolute_error: 0.3065 - mean_squared_error: 0.1815 - rmse: 0.4038 - val_loss: 0.2583 - val_mean_absolute_error: 0.3676 - val_mean_squared_error: 0.2493 - val_rmse: 0.4491
# Epoch 34/100
#  - 104s - loss: 0.1903 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1813 - rmse: 0.4035 - val_loss: 0.2508 - val_mean_absolute_error: 0.3575 - val_mean_squared_error: 0.2418 - val_rmse: 0.4381
# Epoch 35/100
#  - 102s - loss: 0.1904 - mean_absolute_error: 0.3065 - mean_squared_error: 0.1814 - rmse: 0.4038 - val_loss: 0.2588 - val_mean_absolute_error: 0.3648 - val_mean_squared_error: 0.2498 - val_rmse: 0.4443
# Epoch 36/100
#  - 102s - loss: 0.1902 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1812 - rmse: 0.4037 - val_loss: 0.2776 - val_mean_absolute_error: 0.3746 - val_mean_squared_error: 0.2686 - val_rmse: 0.4599
# Epoch 37/100
#  - 103s - loss: 0.1901 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1812 - rmse: 0.4035 - val_loss: 0.2676 - val_mean_absolute_error: 0.3651 - val_mean_squared_error: 0.2586 - val_rmse: 0.4490
# Epoch 38/100
#  - 103s - loss: 0.1903 - mean_absolute_error: 0.3065 - mean_squared_error: 0.1813 - rmse: 0.4035 - val_loss: 0.2462 - val_mean_absolute_error: 0.3507 - val_mean_squared_error: 0.2372 - val_rmse: 0.4307
# Epoch 39/100
#  - 99s - loss: 0.1901 - mean_absolute_error: 0.3062 - mean_squared_error: 0.1811 - rmse: 0.4036 - val_loss: 0.2601 - val_mean_absolute_error: 0.3648 - val_mean_squared_error: 0.2511 - val_rmse: 0.4428
# Epoch 40/100
#  - 102s - loss: 0.1901 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1811 - rmse: 0.4034 - val_loss: 0.2559 - val_mean_absolute_error: 0.3557 - val_mean_squared_error: 0.2469 - val_rmse: 0.4385
# Epoch 41/100
#  - 103s - loss: 0.1901 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1811 - rmse: 0.4035 - val_loss: 0.2598 - val_mean_absolute_error: 0.3585 - val_mean_squared_error: 0.2507 - val_rmse: 0.4404
# Epoch 42/100
#  - 110s - loss: 0.1901 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1811 - rmse: 0.4036 - val_loss: 0.2534 - val_mean_absolute_error: 0.3526 - val_mean_squared_error: 0.2444 - val_rmse: 0.4348
# Epoch 43/100
#  - 105s - loss: 0.1901 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1810 - rmse: 0.4033 - val_loss: 0.2661 - val_mean_absolute_error: 0.3655 - val_mean_squared_error: 0.2571 - val_rmse: 0.4492
# Epoch 44/100
#  - 107s - loss: 0.1901 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1810 - rmse: 0.4033 - val_loss: 0.2791 - val_mean_absolute_error: 0.3820 - val_mean_squared_error: 0.2701 - val_rmse: 0.4607
# Epoch 45/100
#  - 458s - loss: 0.1901 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1810 - rmse: 0.4034 - val_loss: 0.2566 - val_mean_absolute_error: 0.3642 - val_mean_squared_error: 0.2475 - val_rmse: 0.4467
# Epoch 46/100
#  - 87s - loss: 0.1899 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1809 - rmse: 0.4031 - val_loss: 0.2700 - val_mean_absolute_error: 0.3748 - val_mean_squared_error: 0.2610 - val_rmse: 0.4589
# Epoch 47/100
#  - 90s - loss: 0.1901 - mean_absolute_error: 0.3062 - mean_squared_error: 0.1811 - rmse: 0.4034 - val_loss: 0.2582 - val_mean_absolute_error: 0.3694 - val_mean_squared_error: 0.2491 - val_rmse: 0.4511
# Epoch 48/100
#  - 99s - loss: 0.1900 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1809 - rmse: 0.4034 - val_loss: 0.2643 - val_mean_absolute_error: 0.3626 - val_mean_squared_error: 0.2552 - val_rmse: 0.4436
# Epoch 49/100
#  - 107s - loss: 0.1900 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1810 - rmse: 0.4034 - val_loss: 0.2598 - val_mean_absolute_error: 0.3618 - val_mean_squared_error: 0.2507 - val_rmse: 0.4435
# Epoch 50/100
#  - 109s - loss: 0.1900 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1810 - rmse: 0.4033 - val_loss: 0.2597 - val_mean_absolute_error: 0.3656 - val_mean_squared_error: 0.2507 - val_rmse: 0.4448
# Epoch 51/100
#  - 104s - loss: 0.1898 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1808 - rmse: 0.4032 - val_loss: 0.2593 - val_mean_absolute_error: 0.3617 - val_mean_squared_error: 0.2503 - val_rmse: 0.4424
# Epoch 52/100
#  - 92s - loss: 0.1899 - mean_absolute_error: 0.3059 - mean_squared_error: 0.1808 - rmse: 0.4032 - val_loss: 0.2724 - val_mean_absolute_error: 0.3687 - val_mean_squared_error: 0.2634 - val_rmse: 0.4531
# Epoch 53/100
#  - 94s - loss: 0.1900 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1809 - rmse: 0.4032 - val_loss: 0.2530 - val_mean_absolute_error: 0.3568 - val_mean_squared_error: 0.2440 - val_rmse: 0.4382
# Test loss: 0.2530209823792352
# val_mean_absolute_error: 0.3567730063287913
# score
# [0.2530209823792352, 0.3567730063287913, 0.24397348344849037, 0.45622725231902234]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
