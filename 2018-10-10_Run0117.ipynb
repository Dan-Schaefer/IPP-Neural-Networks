# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0104 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
#
# -  This series contains Run0115 - Run0125
#
#
# Settings:
# -  theta = 0.2

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-10_Run0117.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-10_Run0117
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.2)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 79s - loss: 0.2671 - mean_absolute_error: 0.3698 - mean_squared_error: 0.2626 - rmse: 0.4820 - val_loss: 0.2814 - val_mean_absolute_error: 0.3850 - val_mean_squared_error: 0.2761 - val_rmse: 0.4629
# Epoch 2/100
#  - 72s - loss: 0.2110 - mean_absolute_error: 0.3261 - mean_squared_error: 0.2055 - rmse: 0.4296 - val_loss: 0.3004 - val_mean_absolute_error: 0.3890 - val_mean_squared_error: 0.2948 - val_rmse: 0.4745
# Epoch 3/100
#  - 81s - loss: 0.2074 - mean_absolute_error: 0.3225 - mean_squared_error: 0.2016 - rmse: 0.4254 - val_loss: 0.2683 - val_mean_absolute_error: 0.3741 - val_mean_squared_error: 0.2624 - val_rmse: 0.4561
# Epoch 4/100
#  - 81s - loss: 0.2056 - mean_absolute_error: 0.3202 - mean_squared_error: 0.1995 - rmse: 0.4231 - val_loss: 0.2645 - val_mean_absolute_error: 0.3651 - val_mean_squared_error: 0.2582 - val_rmse: 0.4469
# Epoch 5/100
#  - 77s - loss: 0.2044 - mean_absolute_error: 0.3187 - mean_squared_error: 0.1980 - rmse: 0.4213 - val_loss: 0.2519 - val_mean_absolute_error: 0.3536 - val_mean_squared_error: 0.2453 - val_rmse: 0.4358
# Epoch 6/100
#  - 82s - loss: 0.2035 - mean_absolute_error: 0.3176 - mean_squared_error: 0.1969 - rmse: 0.4201 - val_loss: 0.2674 - val_mean_absolute_error: 0.3756 - val_mean_squared_error: 0.2607 - val_rmse: 0.4550
# Epoch 7/100
#  - 79s - loss: 0.2032 - mean_absolute_error: 0.3172 - mean_squared_error: 0.1964 - rmse: 0.4197 - val_loss: 0.2613 - val_mean_absolute_error: 0.3643 - val_mean_squared_error: 0.2544 - val_rmse: 0.4483
# Epoch 8/100
#  - 75s - loss: 0.2026 - mean_absolute_error: 0.3166 - mean_squared_error: 0.1956 - rmse: 0.4186 - val_loss: 0.2607 - val_mean_absolute_error: 0.3603 - val_mean_squared_error: 0.2537 - val_rmse: 0.4401
# Epoch 9/100
#  - 83s - loss: 0.2024 - mean_absolute_error: 0.3161 - mean_squared_error: 0.1953 - rmse: 0.4183 - val_loss: 0.2554 - val_mean_absolute_error: 0.3612 - val_mean_squared_error: 0.2482 - val_rmse: 0.4432
# Epoch 10/100
#  - 78s - loss: 0.2022 - mean_absolute_error: 0.3158 - mean_squared_error: 0.1950 - rmse: 0.4180 - val_loss: 0.2908 - val_mean_absolute_error: 0.3801 - val_mean_squared_error: 0.2836 - val_rmse: 0.4609
# Epoch 11/100
#  - 75s - loss: 0.2018 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1945 - rmse: 0.4173 - val_loss: 0.2590 - val_mean_absolute_error: 0.3581 - val_mean_squared_error: 0.2518 - val_rmse: 0.4400
# Epoch 12/100
#  - 81s - loss: 0.2018 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1945 - rmse: 0.4174 - val_loss: 0.2577 - val_mean_absolute_error: 0.3599 - val_mean_squared_error: 0.2503 - val_rmse: 0.4426
# Epoch 13/100
#  - 76s - loss: 0.2016 - mean_absolute_error: 0.3153 - mean_squared_error: 0.1943 - rmse: 0.4172 - val_loss: 0.2611 - val_mean_absolute_error: 0.3656 - val_mean_squared_error: 0.2537 - val_rmse: 0.4458
# Epoch 14/100
#  - 77s - loss: 0.2014 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1940 - rmse: 0.4168 - val_loss: 0.2674 - val_mean_absolute_error: 0.3624 - val_mean_squared_error: 0.2600 - val_rmse: 0.4436
# Epoch 15/100
#  - 80s - loss: 0.2011 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1937 - rmse: 0.4165 - val_loss: 0.2596 - val_mean_absolute_error: 0.3581 - val_mean_squared_error: 0.2521 - val_rmse: 0.4405
# Epoch 16/100
#  - 72s - loss: 0.2011 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1936 - rmse: 0.4164 - val_loss: 0.2525 - val_mean_absolute_error: 0.3539 - val_mean_squared_error: 0.2450 - val_rmse: 0.4350
# Epoch 17/100
#  - 78s - loss: 0.2008 - mean_absolute_error: 0.3144 - mean_squared_error: 0.1933 - rmse: 0.4161 - val_loss: 0.2863 - val_mean_absolute_error: 0.3912 - val_mean_squared_error: 0.2787 - val_rmse: 0.4685
# Epoch 18/100
#  - 81s - loss: 0.2008 - mean_absolute_error: 0.3144 - mean_squared_error: 0.1932 - rmse: 0.4160 - val_loss: 0.2548 - val_mean_absolute_error: 0.3635 - val_mean_squared_error: 0.2472 - val_rmse: 0.4430
# Epoch 19/100
#  - 73s - loss: 0.2008 - mean_absolute_error: 0.3144 - mean_squared_error: 0.1931 - rmse: 0.4159 - val_loss: 0.2629 - val_mean_absolute_error: 0.3603 - val_mean_squared_error: 0.2552 - val_rmse: 0.4414
# Epoch 20/100
#  - 76s - loss: 0.2007 - mean_absolute_error: 0.3141 - mean_squared_error: 0.1930 - rmse: 0.4158 - val_loss: 0.2490 - val_mean_absolute_error: 0.3523 - val_mean_squared_error: 0.2412 - val_rmse: 0.4338
# Epoch 21/100
#  - 80s - loss: 0.2006 - mean_absolute_error: 0.3140 - mean_squared_error: 0.1929 - rmse: 0.4155 - val_loss: 0.2555 - val_mean_absolute_error: 0.3535 - val_mean_squared_error: 0.2477 - val_rmse: 0.4327
# Epoch 22/100
#  - 75s - loss: 0.2006 - mean_absolute_error: 0.3140 - mean_squared_error: 0.1928 - rmse: 0.4155 - val_loss: 0.2686 - val_mean_absolute_error: 0.3643 - val_mean_squared_error: 0.2608 - val_rmse: 0.4422
# Epoch 23/100
#  - 84s - loss: 0.2004 - mean_absolute_error: 0.3138 - mean_squared_error: 0.1926 - rmse: 0.4153 - val_loss: 0.2836 - val_mean_absolute_error: 0.3888 - val_mean_squared_error: 0.2757 - val_rmse: 0.4703
# Epoch 24/100
#  - 83s - loss: 0.2005 - mean_absolute_error: 0.3138 - mean_squared_error: 0.1926 - rmse: 0.4152 - val_loss: 0.2663 - val_mean_absolute_error: 0.3656 - val_mean_squared_error: 0.2584 - val_rmse: 0.4446
# Epoch 25/100
#  - 80s - loss: 0.2004 - mean_absolute_error: 0.3138 - mean_squared_error: 0.1925 - rmse: 0.4151 - val_loss: 0.2559 - val_mean_absolute_error: 0.3645 - val_mean_squared_error: 0.2480 - val_rmse: 0.4503
# Epoch 26/100
#  - 80s - loss: 0.2003 - mean_absolute_error: 0.3137 - mean_squared_error: 0.1924 - rmse: 0.4149 - val_loss: 0.2684 - val_mean_absolute_error: 0.3741 - val_mean_squared_error: 0.2605 - val_rmse: 0.4537
# Epoch 27/100
#  - 83s - loss: 0.2003 - mean_absolute_error: 0.3138 - mean_squared_error: 0.1923 - rmse: 0.4148 - val_loss: 0.2675 - val_mean_absolute_error: 0.3630 - val_mean_squared_error: 0.2595 - val_rmse: 0.4435
# Epoch 28/100
#  - 107s - loss: 0.2001 - mean_absolute_error: 0.3135 - mean_squared_error: 0.1922 - rmse: 0.4148 - val_loss: 0.2505 - val_mean_absolute_error: 0.3607 - val_mean_squared_error: 0.2426 - val_rmse: 0.4452
# Epoch 29/100
#  - 111s - loss: 0.2000 - mean_absolute_error: 0.3133 - mean_squared_error: 0.1921 - rmse: 0.4145 - val_loss: 0.2538 - val_mean_absolute_error: 0.3631 - val_mean_squared_error: 0.2459 - val_rmse: 0.4444
# Epoch 30/100
#  - 81s - loss: 0.1999 - mean_absolute_error: 0.3134 - mean_squared_error: 0.1919 - rmse: 0.4145 - val_loss: 0.2589 - val_mean_absolute_error: 0.3595 - val_mean_squared_error: 0.2510 - val_rmse: 0.4431
# Epoch 31/100
#  - 86s - loss: 0.1999 - mean_absolute_error: 0.3133 - mean_squared_error: 0.1919 - rmse: 0.4145 - val_loss: 0.2800 - val_mean_absolute_error: 0.3728 - val_mean_squared_error: 0.2720 - val_rmse: 0.4518
# Epoch 32/100
#  - 81s - loss: 0.2000 - mean_absolute_error: 0.3134 - mean_squared_error: 0.1920 - rmse: 0.4146 - val_loss: 0.2605 - val_mean_absolute_error: 0.3599 - val_mean_squared_error: 0.2526 - val_rmse: 0.4414
# Epoch 33/100
#  - 78s - loss: 0.1999 - mean_absolute_error: 0.3132 - mean_squared_error: 0.1919 - rmse: 0.4145 - val_loss: 0.2568 - val_mean_absolute_error: 0.3631 - val_mean_squared_error: 0.2488 - val_rmse: 0.4441
# Epoch 34/100
#  - 84s - loss: 0.1999 - mean_absolute_error: 0.3133 - mean_squared_error: 0.1919 - rmse: 0.4144 - val_loss: 0.2534 - val_mean_absolute_error: 0.3545 - val_mean_squared_error: 0.2453 - val_rmse: 0.4377
# Epoch 35/100
#  - 82s - loss: 0.1998 - mean_absolute_error: 0.3132 - mean_squared_error: 0.1917 - rmse: 0.4142 - val_loss: 0.2535 - val_mean_absolute_error: 0.3616 - val_mean_squared_error: 0.2455 - val_rmse: 0.4448
# Epoch 36/100
#  - 77s - loss: 0.1997 - mean_absolute_error: 0.3133 - mean_squared_error: 0.1917 - rmse: 0.4143 - val_loss: 0.2622 - val_mean_absolute_error: 0.3660 - val_mean_squared_error: 0.2542 - val_rmse: 0.4446
# Test loss: 0.2622311323708208
# val_mean_absolute_error: 0.3659658374334846
# score
# [0.2622311323708208, 0.3659658374334846, 0.25420667814119136, 0.4618599585212327]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
