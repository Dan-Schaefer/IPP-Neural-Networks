# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0104 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
#
# -  This series contains Run0115 - Run0125
#
#
# Settings:
# -  theta = 0.4

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-10_Run0119.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-10_Run0119
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.4)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 73s - loss: 0.2729 - mean_absolute_error: 0.3751 - mean_squared_error: 0.2681 - rmse: 0.4875 - val_loss: 0.2633 - val_mean_absolute_error: 0.3675 - val_mean_squared_error: 0.2573 - val_rmse: 0.4497
# Epoch 2/100
#  - 82s - loss: 0.2123 - mean_absolute_error: 0.3275 - mean_squared_error: 0.2058 - rmse: 0.4306 - val_loss: 0.2725 - val_mean_absolute_error: 0.3703 - val_mean_squared_error: 0.2657 - val_rmse: 0.4556
# Epoch 3/100
#  - 82s - loss: 0.2083 - mean_absolute_error: 0.3236 - mean_squared_error: 0.2012 - rmse: 0.4255 - val_loss: 0.2888 - val_mean_absolute_error: 0.3946 - val_mean_squared_error: 0.2816 - val_rmse: 0.4791
# Epoch 4/100
#  - 77s - loss: 0.2068 - mean_absolute_error: 0.3217 - mean_squared_error: 0.1994 - rmse: 0.4236 - val_loss: 0.2554 - val_mean_absolute_error: 0.3568 - val_mean_squared_error: 0.2479 - val_rmse: 0.4377
# Epoch 5/100
#  - 88s - loss: 0.2059 - mean_absolute_error: 0.3209 - mean_squared_error: 0.1983 - rmse: 0.4224 - val_loss: 0.2964 - val_mean_absolute_error: 0.3903 - val_mean_squared_error: 0.2888 - val_rmse: 0.4727
# Epoch 6/100
#  - 82s - loss: 0.2055 - mean_absolute_error: 0.3202 - mean_squared_error: 0.1977 - rmse: 0.4217 - val_loss: 0.2722 - val_mean_absolute_error: 0.3688 - val_mean_squared_error: 0.2644 - val_rmse: 0.4514
# Epoch 7/100
#  - 75s - loss: 0.2050 - mean_absolute_error: 0.3194 - mean_squared_error: 0.1971 - rmse: 0.4209 - val_loss: 0.2937 - val_mean_absolute_error: 0.3782 - val_mean_squared_error: 0.2858 - val_rmse: 0.4621
# Epoch 8/100
#  - 80s - loss: 0.2045 - mean_absolute_error: 0.3190 - mean_squared_error: 0.1965 - rmse: 0.4203 - val_loss: 0.2665 - val_mean_absolute_error: 0.3667 - val_mean_squared_error: 0.2584 - val_rmse: 0.4511
# Epoch 9/100
#  - 101s - loss: 0.2040 - mean_absolute_error: 0.3182 - mean_squared_error: 0.1958 - rmse: 0.4196 - val_loss: 0.2529 - val_mean_absolute_error: 0.3562 - val_mean_squared_error: 0.2447 - val_rmse: 0.4355
# Epoch 10/100
#  - 89s - loss: 0.2039 - mean_absolute_error: 0.3181 - mean_squared_error: 0.1956 - rmse: 0.4195 - val_loss: 0.2463 - val_mean_absolute_error: 0.3506 - val_mean_squared_error: 0.2380 - val_rmse: 0.4305
# Epoch 11/100
#  - 84s - loss: 0.2038 - mean_absolute_error: 0.3177 - mean_squared_error: 0.1954 - rmse: 0.4189 - val_loss: 0.2590 - val_mean_absolute_error: 0.3583 - val_mean_squared_error: 0.2506 - val_rmse: 0.4373
# Epoch 12/100
#  - 105s - loss: 0.2035 - mean_absolute_error: 0.3175 - mean_squared_error: 0.1951 - rmse: 0.4187 - val_loss: 0.2660 - val_mean_absolute_error: 0.3676 - val_mean_squared_error: 0.2575 - val_rmse: 0.4493
# Epoch 13/100
#  - 128s - loss: 0.2032 - mean_absolute_error: 0.3171 - mean_squared_error: 0.1947 - rmse: 0.4182 - val_loss: 0.2640 - val_mean_absolute_error: 0.3674 - val_mean_squared_error: 0.2554 - val_rmse: 0.4473
# Epoch 14/100
#  - 128s - loss: 0.2032 - mean_absolute_error: 0.3170 - mean_squared_error: 0.1946 - rmse: 0.4183 - val_loss: 0.2907 - val_mean_absolute_error: 0.3869 - val_mean_squared_error: 0.2820 - val_rmse: 0.4649
# Epoch 15/100
#  - 89s - loss: 0.2031 - mean_absolute_error: 0.3169 - mean_squared_error: 0.1945 - rmse: 0.4178 - val_loss: 0.2484 - val_mean_absolute_error: 0.3478 - val_mean_squared_error: 0.2397 - val_rmse: 0.4316
# Epoch 16/100
#  - 86s - loss: 0.2029 - mean_absolute_error: 0.3167 - mean_squared_error: 0.1942 - rmse: 0.4177 - val_loss: 0.2747 - val_mean_absolute_error: 0.3681 - val_mean_squared_error: 0.2660 - val_rmse: 0.4504
# Epoch 17/100
#  - 76s - loss: 0.2027 - mean_absolute_error: 0.3165 - mean_squared_error: 0.1939 - rmse: 0.4174 - val_loss: 0.2579 - val_mean_absolute_error: 0.3671 - val_mean_squared_error: 0.2492 - val_rmse: 0.4501
# Epoch 18/100
#  - 84s - loss: 0.2027 - mean_absolute_error: 0.3166 - mean_squared_error: 0.1939 - rmse: 0.4175 - val_loss: 0.2596 - val_mean_absolute_error: 0.3627 - val_mean_squared_error: 0.2508 - val_rmse: 0.4449
# Epoch 19/100
#  - 355s - loss: 0.2025 - mean_absolute_error: 0.3164 - mean_squared_error: 0.1936 - rmse: 0.4170 - val_loss: 0.2430 - val_mean_absolute_error: 0.3407 - val_mean_squared_error: 0.2342 - val_rmse: 0.4231
# Epoch 20/100
#  - 98s - loss: 0.2026 - mean_absolute_error: 0.3163 - mean_squared_error: 0.1937 - rmse: 0.4171 - val_loss: 0.2683 - val_mean_absolute_error: 0.3607 - val_mean_squared_error: 0.2594 - val_rmse: 0.4428
# Epoch 21/100
#  - 77s - loss: 0.2025 - mean_absolute_error: 0.3162 - mean_squared_error: 0.1936 - rmse: 0.4170 - val_loss: 0.2708 - val_mean_absolute_error: 0.3742 - val_mean_squared_error: 0.2618 - val_rmse: 0.4514
# Epoch 22/100
#  - 79s - loss: 0.2024 - mean_absolute_error: 0.3161 - mean_squared_error: 0.1934 - rmse: 0.4169 - val_loss: 0.2739 - val_mean_absolute_error: 0.3779 - val_mean_squared_error: 0.2650 - val_rmse: 0.4597
# Epoch 23/100
#  - 84s - loss: 0.2020 - mean_absolute_error: 0.3157 - mean_squared_error: 0.1931 - rmse: 0.4166 - val_loss: 0.2600 - val_mean_absolute_error: 0.3570 - val_mean_squared_error: 0.2510 - val_rmse: 0.4400
# Epoch 24/100
#  - 74s - loss: 0.2022 - mean_absolute_error: 0.3159 - mean_squared_error: 0.1933 - rmse: 0.4167 - val_loss: 0.2686 - val_mean_absolute_error: 0.3648 - val_mean_squared_error: 0.2596 - val_rmse: 0.4479
# Epoch 25/100
#  - 82s - loss: 0.2021 - mean_absolute_error: 0.3156 - mean_squared_error: 0.1931 - rmse: 0.4163 - val_loss: 0.2648 - val_mean_absolute_error: 0.3617 - val_mean_squared_error: 0.2558 - val_rmse: 0.4458
# Epoch 26/100
#  - 100s - loss: 0.2022 - mean_absolute_error: 0.3157 - mean_squared_error: 0.1932 - rmse: 0.4166 - val_loss: 0.2574 - val_mean_absolute_error: 0.3556 - val_mean_squared_error: 0.2484 - val_rmse: 0.4375
# Epoch 27/100
#  - 118s - loss: 0.2021 - mean_absolute_error: 0.3157 - mean_squared_error: 0.1931 - rmse: 0.4165 - val_loss: 0.2658 - val_mean_absolute_error: 0.3716 - val_mean_squared_error: 0.2567 - val_rmse: 0.4544
# Epoch 28/100
#  - 116s - loss: 0.2019 - mean_absolute_error: 0.3154 - mean_squared_error: 0.1928 - rmse: 0.4162 - val_loss: 0.2632 - val_mean_absolute_error: 0.3659 - val_mean_squared_error: 0.2542 - val_rmse: 0.4497
# Epoch 29/100
#  - 89s - loss: 0.2019 - mean_absolute_error: 0.3154 - mean_squared_error: 0.1928 - rmse: 0.4162 - val_loss: 0.2562 - val_mean_absolute_error: 0.3576 - val_mean_squared_error: 0.2471 - val_rmse: 0.4413
# Epoch 30/100
#  - 90s - loss: 0.2020 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1930 - rmse: 0.4164 - val_loss: 0.2540 - val_mean_absolute_error: 0.3565 - val_mean_squared_error: 0.2450 - val_rmse: 0.4375
# Epoch 31/100
#  - 95s - loss: 0.2020 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1930 - rmse: 0.4163 - val_loss: 0.2805 - val_mean_absolute_error: 0.3797 - val_mean_squared_error: 0.2714 - val_rmse: 0.4625
# Epoch 32/100
#  - 96s - loss: 0.2017 - mean_absolute_error: 0.3152 - mean_squared_error: 0.1927 - rmse: 0.4159 - val_loss: 0.2973 - val_mean_absolute_error: 0.3957 - val_mean_squared_error: 0.2882 - val_rmse: 0.4784
# Epoch 33/100
#  - 88s - loss: 0.2018 - mean_absolute_error: 0.3154 - mean_squared_error: 0.1927 - rmse: 0.4161 - val_loss: 0.2527 - val_mean_absolute_error: 0.3546 - val_mean_squared_error: 0.2437 - val_rmse: 0.4357
# Epoch 34/100
#  - 78s - loss: 0.2018 - mean_absolute_error: 0.3152 - mean_squared_error: 0.1928 - rmse: 0.4162 - val_loss: 0.2581 - val_mean_absolute_error: 0.3609 - val_mean_squared_error: 0.2491 - val_rmse: 0.4432
# Test loss: 0.25810607083345394
# val_mean_absolute_error: 0.3608733086730654
# score
# [0.25810607083345394, 0.3608733086730654, 0.2490866495724896, 0.4621487118034225]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
