# %% [markdown]
# The purpose of this notebook is to debug the Run0101 series.
#
# MISSION:
# Keep branch1, branch2 datasets together. Otherwise wrong matching!

# %% [markdown]
# Code base starts from Run0101 and modifies it thereafter.

# %% [markdown]
# # NOTA BENE:

# %% [markdown]
# This notebook was modified retrospectively (2018-09-15) to fix the file save bug (basically the file name bzw. the Jupyter notebook name was not being read correctly and consequently the model and TensorBoard files were not being saved properly.)

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-09-11_Run0101b.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-09-11_Run0101b
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
import pandas
import numpy
import sys
import os
from copy import deepcopy

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# Define custon LateFusionActivation function
def custom_activation(LateFusionActivation):
    return TODO

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30)(visible_branch1)
hidden2_branch1 = Dense(30)(hidden1_branch1)

# branch2
visible_branch2 = Input(shape=(1,))

# merge input models
merge = concatenate([hidden2_branch1, visible_branch2])

# interpretation model
output = Dense(1, activation='sigmoid')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
# plot_model(model, 'ModelPlots/' + str(file_name) + 'model_plot.png')




model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,172
# Trainable params: 1,172
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 60s - loss: 0.8065 - mean_absolute_error: 0.7586 - mean_squared_error: 0.8065 - rmse: 0.8817 - val_loss: 0.8275 - val_mean_absolute_error: 0.7691 - val_mean_squared_error: 0.8275 - val_rmse: 0.8682
# Epoch 2/100
#  - 62s - loss: 0.7966 - mean_absolute_error: 0.7529 - mean_squared_error: 0.7966 - rmse: 0.8763 - val_loss: 0.8420 - val_mean_absolute_error: 0.7753 - val_mean_squared_error: 0.8420 - val_rmse: 0.8750
# Epoch 3/100
#  - 66s - loss: 0.7964 - mean_absolute_error: 0.7526 - mean_squared_error: 0.7964 - rmse: 0.8760 - val_loss: 0.8369 - val_mean_absolute_error: 0.7741 - val_mean_squared_error: 0.8369 - val_rmse: 0.8730
# Epoch 4/100
#  - 63s - loss: 0.7963 - mean_absolute_error: 0.7525 - mean_squared_error: 0.7963 - rmse: 0.8761 - val_loss: 0.8308 - val_mean_absolute_error: 0.7706 - val_mean_squared_error: 0.8308 - val_rmse: 0.8698
# Epoch 5/100
#  - 70s - loss: 0.7962 - mean_absolute_error: 0.7524 - mean_squared_error: 0.7962 - rmse: 0.8760 - val_loss: 0.8308 - val_mean_absolute_error: 0.7705 - val_mean_squared_error: 0.8308 - val_rmse: 0.8697
# Epoch 6/100
#  - 60s - loss: 0.7961 - mean_absolute_error: 0.7524 - mean_squared_error: 0.7961 - rmse: 0.8758 - val_loss: 0.8359 - val_mean_absolute_error: 0.7729 - val_mean_squared_error: 0.8359 - val_rmse: 0.8722
# Epoch 7/100
#  - 69s - loss: 0.7961 - mean_absolute_error: 0.7524 - mean_squared_error: 0.7961 - rmse: 0.8758 - val_loss: 0.8372 - val_mean_absolute_error: 0.7732 - val_mean_squared_error: 0.8372 - val_rmse: 0.8727
# Epoch 8/100
#  - 63s - loss: 0.7961 - mean_absolute_error: 0.7524 - mean_squared_error: 0.7961 - rmse: 0.8758 - val_loss: 0.8271 - val_mean_absolute_error: 0.7688 - val_mean_squared_error: 0.8271 - val_rmse: 0.8680
# Epoch 9/100
#  - 73s - loss: 0.7960 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7960 - rmse: 0.8759 - val_loss: 0.8358 - val_mean_absolute_error: 0.7728 - val_mean_squared_error: 0.8358 - val_rmse: 0.8720
# Epoch 10/100
#  - 59s - loss: 0.7959 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7959 - rmse: 0.8759 - val_loss: 0.8383 - val_mean_absolute_error: 0.7733 - val_mean_squared_error: 0.8383 - val_rmse: 0.8729
# Epoch 11/100
#  - 64s - loss: 0.7959 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7959 - rmse: 0.8760 - val_loss: 0.8289 - val_mean_absolute_error: 0.7691 - val_mean_squared_error: 0.8289 - val_rmse: 0.8685
# Epoch 12/100
#  - 59s - loss: 0.7960 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7960 - rmse: 0.8759 - val_loss: 0.8467 - val_mean_absolute_error: 0.7781 - val_mean_squared_error: 0.8467 - val_rmse: 0.8774
# Epoch 13/100
#  - 65s - loss: 0.7959 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7959 - rmse: 0.8757 - val_loss: 0.8422 - val_mean_absolute_error: 0.7760 - val_mean_squared_error: 0.8422 - val_rmse: 0.8752
# Epoch 14/100
#  - 60s - loss: 0.7960 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7960 - rmse: 0.8757 - val_loss: 0.8340 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.8340 - val_rmse: 0.8711
# Epoch 15/100
#  - 65s - loss: 0.7960 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7960 - rmse: 0.8758 - val_loss: 0.8428 - val_mean_absolute_error: 0.7758 - val_mean_squared_error: 0.8428 - val_rmse: 0.8753
# Epoch 16/100
#  - 63s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8330 - val_mean_absolute_error: 0.7715 - val_mean_squared_error: 0.8330 - val_rmse: 0.8708
# Epoch 17/100
#  - 62s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8757 - val_loss: 0.8298 - val_mean_absolute_error: 0.7703 - val_mean_squared_error: 0.8298 - val_rmse: 0.8693
# Epoch 18/100
#  - 66s - loss: 0.7959 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8374 - val_mean_absolute_error: 0.7736 - val_mean_squared_error: 0.8374 - val_rmse: 0.8728
# Epoch 19/100
#  - 61s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8566 - val_mean_absolute_error: 0.7829 - val_mean_squared_error: 0.8566 - val_rmse: 0.8822
# Epoch 20/100
#  - 69s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8235 - val_mean_absolute_error: 0.7668 - val_mean_squared_error: 0.8235 - val_rmse: 0.8661
# Epoch 21/100
#  - 61s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8319 - val_mean_absolute_error: 0.7707 - val_mean_squared_error: 0.8319 - val_rmse: 0.8701
# Epoch 22/100
#  - 73s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8759 - val_loss: 0.8371 - val_mean_absolute_error: 0.7736 - val_mean_squared_error: 0.8371 - val_rmse: 0.8727
# Epoch 23/100
#  - 62s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8757 - val_loss: 0.8344 - val_mean_absolute_error: 0.7726 - val_mean_squared_error: 0.8344 - val_rmse: 0.8716
# Epoch 24/100
#  - 69s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8363 - val_mean_absolute_error: 0.7731 - val_mean_squared_error: 0.8363 - val_rmse: 0.8724
# Epoch 25/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8256 - val_mean_absolute_error: 0.7681 - val_mean_squared_error: 0.8256 - val_rmse: 0.8672
# Epoch 26/100
#  - 64s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8312 - val_mean_absolute_error: 0.7706 - val_mean_squared_error: 0.8312 - val_rmse: 0.8699
# Epoch 27/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8234 - val_mean_absolute_error: 0.7672 - val_mean_squared_error: 0.8234 - val_rmse: 0.8662
# Epoch 28/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8409 - val_mean_absolute_error: 0.7751 - val_mean_squared_error: 0.8409 - val_rmse: 0.8746
# Epoch 29/100
#  - 66s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8757 - val_loss: 0.8289 - val_mean_absolute_error: 0.7690 - val_mean_squared_error: 0.8289 - val_rmse: 0.8685
# Epoch 30/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8259 - val_mean_absolute_error: 0.7671 - val_mean_squared_error: 0.8259 - val_rmse: 0.8670
# Epoch 31/100
#  - 69s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8323 - val_mean_absolute_error: 0.7715 - val_mean_squared_error: 0.8323 - val_rmse: 0.8705
# Epoch 32/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8361 - val_mean_absolute_error: 0.7730 - val_mean_squared_error: 0.8361 - val_rmse: 0.8722
# Epoch 33/100
#  - 69s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8279 - val_mean_absolute_error: 0.7693 - val_mean_squared_error: 0.8279 - val_rmse: 0.8684
# Epoch 34/100
#  - 60s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8338 - val_mean_absolute_error: 0.7718 - val_mean_squared_error: 0.8338 - val_rmse: 0.8711
# Epoch 35/100
#  - 68s - loss: 0.7959 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7959 - rmse: 0.8758 - val_loss: 0.8248 - val_mean_absolute_error: 0.7677 - val_mean_squared_error: 0.8248 - val_rmse: 0.8668
# Epoch 36/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8445 - val_mean_absolute_error: 0.7770 - val_mean_squared_error: 0.8445 - val_rmse: 0.8763
# Epoch 37/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8532 - val_mean_absolute_error: 0.7815 - val_mean_squared_error: 0.8532 - val_rmse: 0.8807
# Epoch 38/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8321 - val_mean_absolute_error: 0.7713 - val_mean_squared_error: 0.8321 - val_rmse: 0.8704
# Epoch 39/100
#  - 65s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8363 - val_mean_absolute_error: 0.7728 - val_mean_squared_error: 0.8363 - val_rmse: 0.8724
# Epoch 40/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8373 - val_mean_absolute_error: 0.7741 - val_mean_squared_error: 0.8373 - val_rmse: 0.8731
# Epoch 41/100
#  - 64s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8314 - val_mean_absolute_error: 0.7703 - val_mean_squared_error: 0.8314 - val_rmse: 0.8697
# Epoch 42/100
#  - 64s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8374 - val_mean_absolute_error: 0.7737 - val_mean_squared_error: 0.8374 - val_rmse: 0.8729
# Epoch 43/100
#  - 63s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8327 - val_mean_absolute_error: 0.7716 - val_mean_squared_error: 0.8327 - val_rmse: 0.8707
# Epoch 44/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8331 - val_mean_absolute_error: 0.7717 - val_mean_squared_error: 0.8331 - val_rmse: 0.8709
# Epoch 45/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7523 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8355 - val_mean_absolute_error: 0.7722 - val_mean_squared_error: 0.8355 - val_rmse: 0.8717
# Epoch 46/100
#  - 69s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8293 - val_mean_absolute_error: 0.7702 - val_mean_squared_error: 0.8293 - val_rmse: 0.8692
# Epoch 47/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8481 - val_mean_absolute_error: 0.7795 - val_mean_squared_error: 0.8481 - val_rmse: 0.8784
# Epoch 48/100
#  - 69s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8349 - val_mean_absolute_error: 0.7723 - val_mean_squared_error: 0.8349 - val_rmse: 0.8716
# Epoch 49/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8334 - val_mean_absolute_error: 0.7717 - val_mean_squared_error: 0.8334 - val_rmse: 0.8709
# Epoch 50/100
#  - 71s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8759 - val_loss: 0.8333 - val_mean_absolute_error: 0.7709 - val_mean_squared_error: 0.8333 - val_rmse: 0.8705
# Epoch 51/100
#  - 61s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8335 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.8335 - val_rmse: 0.8710
# Epoch 52/100
#  - 72s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8307 - val_mean_absolute_error: 0.7705 - val_mean_squared_error: 0.8307 - val_rmse: 0.8697
# Epoch 53/100
#  - 66s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8330 - val_mean_absolute_error: 0.7712 - val_mean_squared_error: 0.8330 - val_rmse: 0.8706
# Epoch 54/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8344 - val_mean_absolute_error: 0.7724 - val_mean_squared_error: 0.8344 - val_rmse: 0.8714
# Epoch 55/100
#  - 71s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8334 - val_mean_absolute_error: 0.7715 - val_mean_squared_error: 0.8334 - val_rmse: 0.8708
# Epoch 56/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8504 - val_mean_absolute_error: 0.7799 - val_mean_squared_error: 0.8504 - val_rmse: 0.8792
# Epoch 57/100
#  - 69s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8403 - val_mean_absolute_error: 0.7753 - val_mean_squared_error: 0.8403 - val_rmse: 0.8743
# Epoch 58/100
#  - 59s - loss: 0.7958 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8303 - val_mean_absolute_error: 0.7701 - val_mean_squared_error: 0.8303 - val_rmse: 0.8693
# Epoch 59/100
#  - 68s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8322 - val_mean_absolute_error: 0.7714 - val_mean_squared_error: 0.8322 - val_rmse: 0.8705
# Epoch 60/100
#  - 61s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8758 - val_loss: 0.8379 - val_mean_absolute_error: 0.7737 - val_mean_squared_error: 0.8379 - val_rmse: 0.8731
# Epoch 61/100
#  - 68s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8442 - val_mean_absolute_error: 0.7774 - val_mean_squared_error: 0.8442 - val_rmse: 0.8764
# Epoch 62/100
#  - 60s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8430 - val_mean_absolute_error: 0.7765 - val_mean_squared_error: 0.8430 - val_rmse: 0.8757
# Epoch 63/100
#  - 69s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8758 - val_loss: 0.8419 - val_mean_absolute_error: 0.7761 - val_mean_squared_error: 0.8419 - val_rmse: 0.8753
# Epoch 64/100
#  - 60s - loss: 0.7958 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8301 - val_mean_absolute_error: 0.7703 - val_mean_squared_error: 0.8301 - val_rmse: 0.8694
# Epoch 65/100
#  - 63s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8372 - val_mean_absolute_error: 0.7737 - val_mean_squared_error: 0.8372 - val_rmse: 0.8729
# Epoch 66/100
#  - 60s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8405 - val_mean_absolute_error: 0.7748 - val_mean_squared_error: 0.8405 - val_rmse: 0.8743
# Epoch 67/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8330 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.8330 - val_rmse: 0.8708
# Epoch 68/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8364 - val_mean_absolute_error: 0.7729 - val_mean_squared_error: 0.8364 - val_rmse: 0.8722
# Epoch 69/100
#  - 63s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8260 - val_mean_absolute_error: 0.7675 - val_mean_squared_error: 0.8260 - val_rmse: 0.8671
# Epoch 70/100
#  - 70s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8358 - val_mean_absolute_error: 0.7730 - val_mean_squared_error: 0.8358 - val_rmse: 0.8722
# Epoch 71/100
#  - 61s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8755 - val_loss: 0.8418 - val_mean_absolute_error: 0.7757 - val_mean_squared_error: 0.8418 - val_rmse: 0.8749
# Epoch 72/100
#  - 70s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8350 - val_mean_absolute_error: 0.7726 - val_mean_squared_error: 0.8350 - val_rmse: 0.8717
# Epoch 73/100
#  - 61s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8270 - val_mean_absolute_error: 0.7685 - val_mean_squared_error: 0.8270 - val_rmse: 0.8677
# Epoch 74/100
#  - 70s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8411 - val_mean_absolute_error: 0.7758 - val_mean_squared_error: 0.8411 - val_rmse: 0.8748
# Epoch 75/100
#  - 82s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8385 - val_mean_absolute_error: 0.7738 - val_mean_squared_error: 0.8385 - val_rmse: 0.8733
# Epoch 76/100
#  - 67s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8755 - val_loss: 0.8362 - val_mean_absolute_error: 0.7730 - val_mean_squared_error: 0.8362 - val_rmse: 0.8723
# Epoch 77/100
#  - 74s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8400 - val_mean_absolute_error: 0.7753 - val_mean_squared_error: 0.8400 - val_rmse: 0.8744
# Epoch 78/100
#  - 63s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8317 - val_mean_absolute_error: 0.7710 - val_mean_squared_error: 0.8317 - val_rmse: 0.8701
# Epoch 79/100
#  - 72s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8399 - val_mean_absolute_error: 0.7749 - val_mean_squared_error: 0.8399 - val_rmse: 0.8742
# Epoch 80/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8443 - val_mean_absolute_error: 0.7766 - val_mean_squared_error: 0.8443 - val_rmse: 0.8761
# Epoch 81/100
#  - 65s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8423 - val_mean_absolute_error: 0.7755 - val_mean_squared_error: 0.8423 - val_rmse: 0.8751
# Epoch 82/100
#  - 67s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8417 - val_mean_absolute_error: 0.7757 - val_mean_squared_error: 0.8417 - val_rmse: 0.8749
# Epoch 83/100
#  - 68s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8352 - val_mean_absolute_error: 0.7724 - val_mean_squared_error: 0.8352 - val_rmse: 0.8717
# Epoch 84/100
#  - 75s - loss: 0.7958 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8354 - val_mean_absolute_error: 0.7731 - val_mean_squared_error: 0.8354 - val_rmse: 0.8720
# Epoch 85/100
#  - 62s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8420 - val_mean_absolute_error: 0.7760 - val_mean_squared_error: 0.8420 - val_rmse: 0.8751
# Epoch 86/100
#  - 131s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8758 - val_loss: 0.8403 - val_mean_absolute_error: 0.7752 - val_mean_squared_error: 0.8403 - val_rmse: 0.8743
# Epoch 87/100
#  - 145s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8349 - val_mean_absolute_error: 0.7728 - val_mean_squared_error: 0.8349 - val_rmse: 0.8717
# Epoch 88/100
#  - 135s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8755 - val_loss: 0.8451 - val_mean_absolute_error: 0.7774 - val_mean_squared_error: 0.8451 - val_rmse: 0.8767
# Epoch 89/100
#  - 126s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8335 - val_mean_absolute_error: 0.7717 - val_mean_squared_error: 0.8335 - val_rmse: 0.8710
# Epoch 90/100
#  - 125s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8399 - val_mean_absolute_error: 0.7750 - val_mean_squared_error: 0.8399 - val_rmse: 0.8741
# Epoch 91/100
#  - 127s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8389 - val_mean_absolute_error: 0.7743 - val_mean_squared_error: 0.8389 - val_rmse: 0.8736
# Epoch 92/100
#  - 117s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8431 - val_mean_absolute_error: 0.7772 - val_mean_squared_error: 0.8431 - val_rmse: 0.8760
# Epoch 93/100
#  - 106s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8756 - val_loss: 0.8328 - val_mean_absolute_error: 0.7712 - val_mean_squared_error: 0.8328 - val_rmse: 0.8705
# Epoch 94/100
#  - 94s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8416 - val_mean_absolute_error: 0.7759 - val_mean_squared_error: 0.8416 - val_rmse: 0.8750
# Epoch 95/100
#  - 89s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8340 - val_mean_absolute_error: 0.7719 - val_mean_squared_error: 0.8340 - val_rmse: 0.8712
# Epoch 96/100
#  - 82s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8757 - val_loss: 0.8350 - val_mean_absolute_error: 0.7726 - val_mean_squared_error: 0.8350 - val_rmse: 0.8718
# Epoch 97/100
#  - 91s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8758 - val_loss: 0.8347 - val_mean_absolute_error: 0.7723 - val_mean_squared_error: 0.8347 - val_rmse: 0.8715
# Epoch 98/100
#  - 76s - loss: 0.7958 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7958 - rmse: 0.8757 - val_loss: 0.8399 - val_mean_absolute_error: 0.7745 - val_mean_squared_error: 0.8399 - val_rmse: 0.8739
# Epoch 99/100
#  - 93s - loss: 0.7957 - mean_absolute_error: 0.7521 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8385 - val_mean_absolute_error: 0.7743 - val_mean_squared_error: 0.8385 - val_rmse: 0.8735
# Epoch 100/100
#  - 101s - loss: 0.7957 - mean_absolute_error: 0.7522 - mean_squared_error: 0.7957 - rmse: 0.8756 - val_loss: 0.8322 - val_mean_absolute_error: 0.7714 - val_mean_squared_error: 0.8322 - val_rmse: 0.8705
# Test loss: 0.8322118881443012
# val_mean_absolute_error: 0.7713889912400821
# score
# [0.8322118881443012, 0.7713889912400821, 0.8322118881443012, 0.884386774622221]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
