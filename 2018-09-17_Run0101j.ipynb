# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Same as before but all layers are wider and an extra hidden layer is added.

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-09-17_Run0101j.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-09-17_Run0101j
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal, Ones
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
import pandas
import numpy
import sys
import os
from copy import deepcopy

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# Define custon LateFusionActivation function
def custom_activation(LateFusionActivation):
    return TODO

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(7,))
hidden1 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))

visible_branch2_fixed = Dense(1,
                kernel_initializer='Ones',
                trainable=False)(visible_branch2)

hidden2_merged = concatenate([visible_branch2_fixed, hidden2])

hidden3 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden2_merged)

hidden3_merged = concatenate([visible_branch2_fixed, hidden3])

hidden4 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden3_merged)

hidden4_merged = concatenate([visible_branch2_fixed, hidden4])


# Model 2
# visible_branch1 = Input(shape=(7,))
M2_hidden1 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
M2_hidden2 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(M2_hidden1)
M2_hidden3 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(M2_hidden2)
M2_hidden4 = Dense(60,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(M2_hidden3)

# Combining Model 1 & Model 2
models_merged = concatenate([hidden4_merged, M2_hidden4])

# interpretation model
output = Dense(1, activation='linear')(models_merged)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 7)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 60)           480         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 60)           3660        dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 61)           0           dense_3[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 60)           3720        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 60)           480         input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 61)           0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 60)           3660        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 60)           3720        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 60)           3660        dense_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 61)           0           dense_3[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 60)           3660        dense_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 121)          0           concatenate_3[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            122         concatenate_4[0][0]
# ==================================================================================================
# Total params: 23,164
# Trainable params: 23,162
# Non-trainable params: 2
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    validation_data=([x_test, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

score = model.evaluate([x_test, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 152s - loss: 0.1529 - mean_absolute_error: 0.2491 - mean_squared_error: 0.1300 - rmse: 0.3343 - val_loss: 0.1695 - val_mean_absolute_error: 0.2791 - val_mean_squared_error: 0.1477 - val_rmse: 0.3432
# Epoch 2/100
#  - 153s - loss: 0.1185 - mean_absolute_error: 0.2137 - mean_squared_error: 0.0973 - rmse: 0.2916 - val_loss: 0.1353 - val_mean_absolute_error: 0.2340 - val_mean_squared_error: 0.1145 - val_rmse: 0.2952
# Epoch 3/100
#  - 163s - loss: 0.1122 - mean_absolute_error: 0.2066 - mean_squared_error: 0.0918 - rmse: 0.2829 - val_loss: 0.1398 - val_mean_absolute_error: 0.2423 - val_mean_squared_error: 0.1196 - val_rmse: 0.3034
# Epoch 4/100
#  - 144s - loss: 0.1090 - mean_absolute_error: 0.2028 - mean_squared_error: 0.0891 - rmse: 0.2783 - val_loss: 0.1409 - val_mean_absolute_error: 0.2397 - val_mean_squared_error: 0.1212 - val_rmse: 0.3032
# Epoch 5/100
#  - 126s - loss: 0.1069 - mean_absolute_error: 0.2004 - mean_squared_error: 0.0873 - rmse: 0.2754 - val_loss: 0.1324 - val_mean_absolute_error: 0.2330 - val_mean_squared_error: 0.1130 - val_rmse: 0.2953
# Epoch 6/100
#  - 131s - loss: 0.1054 - mean_absolute_error: 0.1987 - mean_squared_error: 0.0861 - rmse: 0.2735 - val_loss: 0.1348 - val_mean_absolute_error: 0.2407 - val_mean_squared_error: 0.1157 - val_rmse: 0.2990
# Epoch 7/100
#  - 128s - loss: 0.1044 - mean_absolute_error: 0.1976 - mean_squared_error: 0.0854 - rmse: 0.2721 - val_loss: 0.1246 - val_mean_absolute_error: 0.2205 - val_mean_squared_error: 0.1057 - val_rmse: 0.2820
# Epoch 8/100
#  - 130s - loss: 0.1031 - mean_absolute_error: 0.1963 - mean_squared_error: 0.0844 - rmse: 0.2705 - val_loss: 0.1260 - val_mean_absolute_error: 0.2268 - val_mean_squared_error: 0.1074 - val_rmse: 0.2870
# Epoch 9/100
#  - 126s - loss: 0.1023 - mean_absolute_error: 0.1954 - mean_squared_error: 0.0839 - rmse: 0.2697 - val_loss: 0.1223 - val_mean_absolute_error: 0.2229 - val_mean_squared_error: 0.1040 - val_rmse: 0.2809
# Epoch 10/100
#  - 128s - loss: 0.1015 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0833 - rmse: 0.2685 - val_loss: 0.1410 - val_mean_absolute_error: 0.2384 - val_mean_squared_error: 0.1229 - val_rmse: 0.3019
# Epoch 11/100
#  - 129s - loss: 0.1008 - mean_absolute_error: 0.1937 - mean_squared_error: 0.0829 - rmse: 0.2677 - val_loss: 0.1257 - val_mean_absolute_error: 0.2251 - val_mean_squared_error: 0.1077 - val_rmse: 0.2844
# Epoch 12/100
#  - 129s - loss: 0.1002 - mean_absolute_error: 0.1931 - mean_squared_error: 0.0824 - rmse: 0.2669 - val_loss: 0.1245 - val_mean_absolute_error: 0.2217 - val_mean_squared_error: 0.1067 - val_rmse: 0.2826
# Epoch 13/100
#  - 126s - loss: 0.1000 - mean_absolute_error: 0.1928 - mean_squared_error: 0.0822 - rmse: 0.2668 - val_loss: 0.1267 - val_mean_absolute_error: 0.2313 - val_mean_squared_error: 0.1090 - val_rmse: 0.2899
# Epoch 14/100
#  - 127s - loss: 0.0996 - mean_absolute_error: 0.1924 - mean_squared_error: 0.0820 - rmse: 0.2662 - val_loss: 0.1253 - val_mean_absolute_error: 0.2239 - val_mean_squared_error: 0.1077 - val_rmse: 0.2847
# Epoch 15/100
#  - 125s - loss: 0.0992 - mean_absolute_error: 0.1920 - mean_squared_error: 0.0817 - rmse: 0.2657 - val_loss: 0.1325 - val_mean_absolute_error: 0.2350 - val_mean_squared_error: 0.1150 - val_rmse: 0.2933
# Epoch 16/100
#  - 122s - loss: 0.0991 - mean_absolute_error: 0.1918 - mean_squared_error: 0.0816 - rmse: 0.2656 - val_loss: 0.1341 - val_mean_absolute_error: 0.2311 - val_mean_squared_error: 0.1165 - val_rmse: 0.2969
# Epoch 17/100
#  - 125s - loss: 0.0989 - mean_absolute_error: 0.1917 - mean_squared_error: 0.0815 - rmse: 0.2655 - val_loss: 0.1251 - val_mean_absolute_error: 0.2236 - val_mean_squared_error: 0.1076 - val_rmse: 0.2844
# Epoch 18/100
#  - 119s - loss: 0.0983 - mean_absolute_error: 0.1909 - mean_squared_error: 0.0808 - rmse: 0.2642 - val_loss: 0.1254 - val_mean_absolute_error: 0.2279 - val_mean_squared_error: 0.1080 - val_rmse: 0.2876
# Epoch 19/100
#  - 125s - loss: 0.0983 - mean_absolute_error: 0.1908 - mean_squared_error: 0.0809 - rmse: 0.2645 - val_loss: 0.1351 - val_mean_absolute_error: 0.2305 - val_mean_squared_error: 0.1178 - val_rmse: 0.2929
# Epoch 20/100
#  - 126s - loss: 0.0982 - mean_absolute_error: 0.1906 - mean_squared_error: 0.0808 - rmse: 0.2641 - val_loss: 0.1213 - val_mean_absolute_error: 0.2180 - val_mean_squared_error: 0.1040 - val_rmse: 0.2781
# Epoch 21/100
#  - 126s - loss: 0.0982 - mean_absolute_error: 0.1906 - mean_squared_error: 0.0809 - rmse: 0.2641 - val_loss: 0.1263 - val_mean_absolute_error: 0.2259 - val_mean_squared_error: 0.1089 - val_rmse: 0.2879
# Epoch 22/100
#  - 131s - loss: 0.0979 - mean_absolute_error: 0.1901 - mean_squared_error: 0.0805 - rmse: 0.2636 - val_loss: 0.1298 - val_mean_absolute_error: 0.2287 - val_mean_squared_error: 0.1124 - val_rmse: 0.2882
# Epoch 23/100
#  - 130s - loss: 0.0978 - mean_absolute_error: 0.1903 - mean_squared_error: 0.0805 - rmse: 0.2637 - val_loss: 0.1308 - val_mean_absolute_error: 0.2329 - val_mean_squared_error: 0.1135 - val_rmse: 0.2928
# Epoch 24/100
#  - 127s - loss: 0.0976 - mean_absolute_error: 0.1897 - mean_squared_error: 0.0803 - rmse: 0.2633 - val_loss: 0.1252 - val_mean_absolute_error: 0.2228 - val_mean_squared_error: 0.1080 - val_rmse: 0.2830
# Epoch 25/100
#  - 127s - loss: 0.0976 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0804 - rmse: 0.2633 - val_loss: 0.1351 - val_mean_absolute_error: 0.2386 - val_mean_squared_error: 0.1180 - val_rmse: 0.2988
# Epoch 26/100
#  - 128s - loss: 0.0973 - mean_absolute_error: 0.1896 - mean_squared_error: 0.0802 - rmse: 0.2631 - val_loss: 0.1362 - val_mean_absolute_error: 0.2357 - val_mean_squared_error: 0.1190 - val_rmse: 0.2979
# Epoch 27/100
#  - 127s - loss: 0.0973 - mean_absolute_error: 0.1896 - mean_squared_error: 0.0801 - rmse: 0.2630 - val_loss: 0.1336 - val_mean_absolute_error: 0.2441 - val_mean_squared_error: 0.1164 - val_rmse: 0.3041
# Epoch 28/100
#  - 126s - loss: 0.0972 - mean_absolute_error: 0.1899 - mean_squared_error: 0.0800 - rmse: 0.2630 - val_loss: 0.1316 - val_mean_absolute_error: 0.2312 - val_mean_squared_error: 0.1145 - val_rmse: 0.2926
# Epoch 29/100
#  - 129s - loss: 0.0971 - mean_absolute_error: 0.1896 - mean_squared_error: 0.0800 - rmse: 0.2628 - val_loss: 0.1324 - val_mean_absolute_error: 0.2312 - val_mean_squared_error: 0.1153 - val_rmse: 0.2940
# Epoch 30/100
#  - 128s - loss: 0.0970 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0799 - rmse: 0.2626 - val_loss: 0.1331 - val_mean_absolute_error: 0.2318 - val_mean_squared_error: 0.1159 - val_rmse: 0.2938
# Epoch 31/100
#  - 129s - loss: 0.0969 - mean_absolute_error: 0.1892 - mean_squared_error: 0.0799 - rmse: 0.2625 - val_loss: 0.1201 - val_mean_absolute_error: 0.2171 - val_mean_squared_error: 0.1030 - val_rmse: 0.2789
# Epoch 32/100
#  - 127s - loss: 0.0968 - mean_absolute_error: 0.1891 - mean_squared_error: 0.0798 - rmse: 0.2625 - val_loss: 0.1376 - val_mean_absolute_error: 0.2385 - val_mean_squared_error: 0.1207 - val_rmse: 0.3006
# Epoch 33/100
#  - 126s - loss: 0.0970 - mean_absolute_error: 0.1895 - mean_squared_error: 0.0800 - rmse: 0.2629 - val_loss: 0.1282 - val_mean_absolute_error: 0.2275 - val_mean_squared_error: 0.1113 - val_rmse: 0.2892
# Epoch 34/100
#  - 122s - loss: 0.0969 - mean_absolute_error: 0.1894 - mean_squared_error: 0.0800 - rmse: 0.2627 - val_loss: 0.1338 - val_mean_absolute_error: 0.2367 - val_mean_squared_error: 0.1169 - val_rmse: 0.2981
# Epoch 35/100
#  - 125s - loss: 0.0967 - mean_absolute_error: 0.1890 - mean_squared_error: 0.0799 - rmse: 0.2624 - val_loss: 0.1490 - val_mean_absolute_error: 0.2518 - val_mean_squared_error: 0.1322 - val_rmse: 0.3147
# Test loss: 0.14904320411656918
# val_mean_absolute_error: 0.25178564765505435
# score
# [0.14904320411656918, 0.25178564765505435, 0.1321925403620743, 0.3257058999471408]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
