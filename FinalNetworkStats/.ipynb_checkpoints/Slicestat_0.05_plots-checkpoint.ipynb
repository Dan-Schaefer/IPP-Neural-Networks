# %%
#import python packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib as mpl
import pandas as pd

# %matplotlib inline

# %%
#Serifenschrift, sieht in LaTeX-Dokumenten uU besser aus
plt.rc('font', family='sans-serif')
#Labelgrösssen, bringen nur was wenn man die figsize nicht gross ändert
plt.rc('figure', figsize = [5,3])
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
#Schriftgrösse
plt.rc('legend', fontsize='x-small')
# Damit kann man die Labels auch vom LaTeX-Backend generieren lassen. Passt wieder etwas besser ins Dokument, dauert aber viel länger.
plt.rc('text', usetex=False)
#Schriftart beim Text zwsichen '$'
plt.rc('mathtext', default='regular')
#Auflösung in der abgespeichert wird. Ansonsten in plt.savefig('blabla.png', dpi = 100)
plt.rc('figure', dpi = 80)

# %%
df = pd.read_csv('slicestat_results_0.05.csv')

# %%
df
# Out:
#    network_label target_names  thresh_rel_mis_median  thresh_rel_mis_95width  \
# 0      0161h-Mk3    efeETG_GB              -0.054160                0.594690
# 1      0161x-Mk5    efeETG_GB              -0.058901                0.609526
# 2      0161x-Mk4    efeETG_GB              -0.054160                0.603663
# 3      0161g-Mk4    efeETG_GB              -0.054160                0.596348
# 4      0161x-Mk3    efeETG_GB              -0.054160                0.557186
# 5      0161f-Mk5    efeETG_GB              -0.061977                0.514207
# 6          0161h    efeETG_GB              -0.054160                0.621819
# 7          0161c    efeETG_GB              -0.343384                0.694964
# 8      0161h-Mk2    efeETG_GB              -0.054160                0.570220
# 9          0161f    efeETG_GB              -0.054160                0.623600
# 10     0161h-Mk5    efeETG_GB              -0.054160                0.597801
# 11     0161e-Mk5    efeETG_GB              -0.089265                0.495511
# 12     0161h-Mk4    efeETG_GB              -0.054160                0.625719
# 13     0161f-Mk2    efeETG_GB              -0.058566                0.549198
# 14     0161g-Mk3    efeETG_GB              -0.054160                0.659085
# 15     0161e-Mk4    efeETG_GB              -0.054160                0.621819
# 16         0161e    efeETG_GB              -0.074080                0.546460
# 17     0161g-Mk5    efeETG_GB              -0.054160                0.539909
# 18     0161f-Mk4    efeETG_GB              -0.054160                0.605887
# 19     0161e-Mk3    efeETG_GB              -0.054160                0.599841
# 20     0161f-Mk3    efeETG_GB              -0.044525                0.635067
# 21     0161e-Mk2    efeETG_GB              -0.054160                0.629463
# 22     0161g-Mk2    efeETG_GB              -0.054160                0.551323
# 23     0161x-Mk2    efeETG_GB              -0.058901                0.534046
# 24         0161d    efeETG_GB              -0.127064                0.718526
# 25         0161g    efeETG_GB              -0.054160                0.551323
# 26     0161x-Mk1    efeETG_GB              -0.054160                0.585508
#
#     pop_rel_mis_median  pop_rel_mis_95width  thresh_abs_mis_median  \
# 0                  NaN                  NaN              -0.487437
# 1                  NaN                  NaN              -0.487437
# 2                  NaN                  NaN              -0.449121
# 3                  NaN                  NaN              -0.380025
# 4                  NaN                  NaN              -0.487437
# 5                  NaN                  NaN              -0.487437
# 6                  NaN                  NaN              -0.449121
# 7                  NaN                  NaN              -2.560930
# 8                  NaN                  NaN              -0.487437
# 9                  NaN                  NaN              -0.426508
# 10                 NaN                  NaN              -0.357412
# 11                 NaN                  NaN              -0.628141
# 12                 NaN                  NaN              -0.403894
# 13                 NaN                  NaN              -0.487437
# 14                 NaN                  NaN              -0.333543
# 15                 NaN                  NaN              -0.472990
# 16                 NaN                  NaN              -0.557789
# 17                 NaN                  NaN              -0.487437
# 18                 NaN                  NaN              -0.332286
# 19                 NaN                  NaN              -0.487437
# 20                 NaN                  NaN              -0.263191
# 21                 NaN                  NaN              -0.472990
# 22                 NaN                  NaN              -0.487437
# 23                 NaN                  NaN              -0.487437
# 24                 NaN                  NaN              -0.909548
# 25                 NaN                  NaN              -0.487437
# 26                 NaN                  NaN              -0.487437
#
#     thresh_abs_mis_95width  no_thresh_frac  pop_abs_mis_median  \
# 0                 4.866206        0.022995                 NaN
# 1                 4.843593        0.035494                 NaN
# 2                 4.888819        0.027243                 NaN
# 3                 4.843593        0.048202                 NaN
# 4                 4.748116        0.055821                 NaN
# 5                 4.588756        0.035459                 NaN
# 6                 4.913945        0.033773                 NaN
# 7                 7.656407        0.023241                 NaN
# 8                 4.843593        0.027068                 NaN
# 9                 4.935302        0.025734                 NaN
# 10                4.890075        0.051292                 NaN
# 11                4.445352        0.025488                 NaN
# 12                5.029523        0.037495                 NaN
# 13                4.702889        0.031526                 NaN
# 14                5.054648        0.027735                 NaN
# 15                5.065861        0.033141                 NaN
# 16                4.771985        0.027805                 NaN
# 17                4.655151        0.038267                 NaN
# 18                4.984296        0.035529                 NaN
# 19                4.795854        0.021837                 NaN
# 20                5.123775        0.031035                 NaN
# 21                4.983040        0.022574                 NaN
# 22                4.748116        0.041005                 NaN
# 23                4.584799        0.037073                 NaN
# 24                5.873744        0.032861                 NaN
# 25                4.655151        0.021977                 NaN
# 26                4.912688        0.023978                 NaN
#
#     pop_abs_mis_95width  no_pop_frac  wobble_unstab  wobble_qlkunstab  \
# 0                   NaN          1.0       0.007038          0.011764
# 1                   NaN          1.0       0.007971          0.011047
# 2                   NaN          1.0       0.008225          0.011851
# 3                   NaN          1.0       0.009097          0.013120
# 4                   NaN          1.0       0.006353          0.010599
# 5                   NaN          1.0       0.007530          0.009798
# 6                   NaN          1.0       0.009387          0.012196
# 7                   NaN          1.0       0.004349          0.003202
# 8                   NaN          1.0       0.007622          0.010715
# 9                   NaN          1.0       0.006694          0.011162
# 10                  NaN          1.0       0.007994          0.012043
# 11                  NaN          1.0       0.007273          0.008246
# 12                  NaN          1.0       0.007716          0.011232
# 13                  NaN          1.0       0.009239          0.013052
# 14                  NaN          1.0       0.009025          0.014458
# 15                  NaN          1.0       0.008481          0.012387
# 16                  NaN          1.0       0.008992          0.011506
# 17                  NaN          1.0       0.008680          0.010884
# 18                  NaN          1.0       0.008015          0.012476
# 19                  NaN          1.0       0.007549          0.012012
# 20                  NaN          1.0       0.008548          0.013067
# 21                  NaN          1.0       0.008655          0.016952
# 22                  NaN          1.0       0.007115          0.011356
# 23                  NaN          1.0       0.007247          0.011145
# 24                  NaN          1.0       0.007969          0.009942
# 25                  NaN          1.0       0.009711          0.012768
# 26                  NaN          1.0       0.008552          0.015005
#
#     wobble_tot
# 0     0.007800
# 1     0.008271
# 2     0.007424
# 3     0.008491
# 4     0.007703
# 5     0.007070
# 6     0.007520
# 7     0.003205
# 8     0.006994
# 9     0.007379
# 10    0.007738
# 11    0.006987
# 12    0.007352
# 13    0.009157
# 14    0.008772
# 15    0.007590
# 16    0.008126
# 17    0.007353
# 18    0.008073
# 19    0.008332
# 20    0.007990
# 21    0.011153
# 22    0.008212
# 23    0.008569
# 24    0.007874
# 25    0.007934
# 26    0.010492

# %%
plt.hist(df['thresh_abs_mis_median'].values.astype(float) )
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  2., 23.]),
#  array([-2.56092965, -2.33115578, -2.10138191, -1.87160804, -1.64183417,
#         -1.4120603 , -1.18228643, -0.95251256, -0.72273869, -0.49296482,
#         -0.26319095]),
#  <a list of 10 Patch objects>)
