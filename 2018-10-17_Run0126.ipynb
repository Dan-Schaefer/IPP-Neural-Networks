# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0120 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
# -  TR layer (originally stood for "Thresholded Relu" is now a standard `Relu` instead of a `ThresholdedRelu`

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-17_Run0126.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-17_Run0126
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)
theta_branch1 = Dense(1, activation='linear')(hidden2_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)

# addition_pooling
addition_pooling = keras.layers.Add()([theta_branch1, visible_branch2_feeder])


TR = Dense(1, activation='relu')(addition_pooling)

# merge input models
#merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(TR)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            31          dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           add_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            2           dense_5[0][0]
# ==================================================================================================
# Total params: 1,177
# Trainable params: 1,177
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 113s - loss: 0.2411 - mean_absolute_error: 0.3499 - mean_squared_error: 0.2366 - rmse: 0.4580 - val_loss: 0.2585 - val_mean_absolute_error: 0.3709 - val_mean_squared_error: 0.2532 - val_rmse: 0.4510
# Epoch 2/100
#  - 79s - loss: 0.1939 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1884 - rmse: 0.4133 - val_loss: 0.2519 - val_mean_absolute_error: 0.3657 - val_mean_squared_error: 0.2462 - val_rmse: 0.4485
# Epoch 3/100
#  - 83s - loss: 0.1906 - mean_absolute_error: 0.3111 - mean_squared_error: 0.1847 - rmse: 0.4092 - val_loss: 0.2525 - val_mean_absolute_error: 0.3649 - val_mean_squared_error: 0.2464 - val_rmse: 0.4472
# Epoch 4/100
#  - 95s - loss: 0.1888 - mean_absolute_error: 0.3089 - mean_squared_error: 0.1825 - rmse: 0.4066 - val_loss: 0.2728 - val_mean_absolute_error: 0.3826 - val_mean_squared_error: 0.2664 - val_rmse: 0.4604
# Epoch 5/100
#  - 89s - loss: 0.1876 - mean_absolute_error: 0.3072 - mean_squared_error: 0.1810 - rmse: 0.4048 - val_loss: 0.2534 - val_mean_absolute_error: 0.3648 - val_mean_squared_error: 0.2467 - val_rmse: 0.4471
# Epoch 6/100
#  - 96s - loss: 0.1867 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1798 - rmse: 0.4036 - val_loss: 0.2556 - val_mean_absolute_error: 0.3595 - val_mean_squared_error: 0.2486 - val_rmse: 0.4433
# Epoch 7/100
#  - 83s - loss: 0.1859 - mean_absolute_error: 0.3051 - mean_squared_error: 0.1788 - rmse: 0.4023 - val_loss: 0.2432 - val_mean_absolute_error: 0.3536 - val_mean_squared_error: 0.2360 - val_rmse: 0.4354
# Epoch 8/100
#  - 87s - loss: 0.1852 - mean_absolute_error: 0.3043 - mean_squared_error: 0.1780 - rmse: 0.4013 - val_loss: 0.2561 - val_mean_absolute_error: 0.3678 - val_mean_squared_error: 0.2488 - val_rmse: 0.4474
# Epoch 9/100
#  - 87s - loss: 0.1845 - mean_absolute_error: 0.3035 - mean_squared_error: 0.1771 - rmse: 0.4003 - val_loss: 0.2430 - val_mean_absolute_error: 0.3523 - val_mean_squared_error: 0.2356 - val_rmse: 0.4344
# Epoch 10/100
#  - 84s - loss: 0.1839 - mean_absolute_error: 0.3026 - mean_squared_error: 0.1764 - rmse: 0.3994 - val_loss: 0.2589 - val_mean_absolute_error: 0.3643 - val_mean_squared_error: 0.2513 - val_rmse: 0.4470
# Epoch 11/100
#  - 89s - loss: 0.1835 - mean_absolute_error: 0.3022 - mean_squared_error: 0.1759 - rmse: 0.3987 - val_loss: 0.2386 - val_mean_absolute_error: 0.3504 - val_mean_squared_error: 0.2309 - val_rmse: 0.4301
# Epoch 12/100
#  - 99s - loss: 0.1834 - mean_absolute_error: 0.3019 - mean_squared_error: 0.1756 - rmse: 0.3984 - val_loss: 0.2494 - val_mean_absolute_error: 0.3639 - val_mean_squared_error: 0.2416 - val_rmse: 0.4437
# Epoch 13/100
#  - 101s - loss: 0.1831 - mean_absolute_error: 0.3016 - mean_squared_error: 0.1753 - rmse: 0.3980 - val_loss: 0.2694 - val_mean_absolute_error: 0.3751 - val_mean_squared_error: 0.2615 - val_rmse: 0.4544
# Epoch 14/100
#  - 99s - loss: 0.1828 - mean_absolute_error: 0.3013 - mean_squared_error: 0.1749 - rmse: 0.3976 - val_loss: 0.2447 - val_mean_absolute_error: 0.3589 - val_mean_squared_error: 0.2368 - val_rmse: 0.4402
# Epoch 15/100
#  - 88s - loss: 0.1825 - mean_absolute_error: 0.3010 - mean_squared_error: 0.1746 - rmse: 0.3974 - val_loss: 0.2351 - val_mean_absolute_error: 0.3522 - val_mean_squared_error: 0.2271 - val_rmse: 0.4312
# Epoch 16/100
#  - 85s - loss: 0.1823 - mean_absolute_error: 0.3006 - mean_squared_error: 0.1743 - rmse: 0.3969 - val_loss: 0.2418 - val_mean_absolute_error: 0.3492 - val_mean_squared_error: 0.2338 - val_rmse: 0.4298
# Epoch 17/100
#  - 90s - loss: 0.1822 - mean_absolute_error: 0.3006 - mean_squared_error: 0.1741 - rmse: 0.3967 - val_loss: 0.2525 - val_mean_absolute_error: 0.3685 - val_mean_squared_error: 0.2444 - val_rmse: 0.4500
# Epoch 18/100
#  - 91s - loss: 0.1820 - mean_absolute_error: 0.3004 - mean_squared_error: 0.1739 - rmse: 0.3965 - val_loss: 0.2391 - val_mean_absolute_error: 0.3571 - val_mean_squared_error: 0.2310 - val_rmse: 0.4359
# Epoch 19/100
#  - 88s - loss: 0.1821 - mean_absolute_error: 0.3002 - mean_squared_error: 0.1740 - rmse: 0.3964 - val_loss: 0.2533 - val_mean_absolute_error: 0.3628 - val_mean_squared_error: 0.2452 - val_rmse: 0.4447
# Epoch 20/100
#  - 110s - loss: 0.1819 - mean_absolute_error: 0.3003 - mean_squared_error: 0.1738 - rmse: 0.3965 - val_loss: 0.2411 - val_mean_absolute_error: 0.3552 - val_mean_squared_error: 0.2330 - val_rmse: 0.4359
# Epoch 21/100
#  - 95s - loss: 0.1818 - mean_absolute_error: 0.3000 - mean_squared_error: 0.1736 - rmse: 0.3961 - val_loss: 0.2419 - val_mean_absolute_error: 0.3565 - val_mean_squared_error: 0.2338 - val_rmse: 0.4365
# Epoch 22/100
#  - 93s - loss: 0.1818 - mean_absolute_error: 0.2998 - mean_squared_error: 0.1736 - rmse: 0.3961 - val_loss: 0.2405 - val_mean_absolute_error: 0.3497 - val_mean_squared_error: 0.2324 - val_rmse: 0.4270
# Epoch 23/100
#  - 85s - loss: 0.1817 - mean_absolute_error: 0.2998 - mean_squared_error: 0.1735 - rmse: 0.3959 - val_loss: 0.2444 - val_mean_absolute_error: 0.3588 - val_mean_squared_error: 0.2362 - val_rmse: 0.4367
# Epoch 24/100
#  - 88s - loss: 0.1818 - mean_absolute_error: 0.2999 - mean_squared_error: 0.1736 - rmse: 0.3959 - val_loss: 0.2389 - val_mean_absolute_error: 0.3500 - val_mean_squared_error: 0.2307 - val_rmse: 0.4315
# Epoch 25/100
#  - 90s - loss: 0.1816 - mean_absolute_error: 0.2998 - mean_squared_error: 0.1734 - rmse: 0.3959 - val_loss: 0.2358 - val_mean_absolute_error: 0.3524 - val_mean_squared_error: 0.2276 - val_rmse: 0.4342
# Epoch 26/100
#  - 89s - loss: 0.1814 - mean_absolute_error: 0.2995 - mean_squared_error: 0.1732 - rmse: 0.3954 - val_loss: 0.2287 - val_mean_absolute_error: 0.3441 - val_mean_squared_error: 0.2205 - val_rmse: 0.4250
# Epoch 27/100
#  - 83s - loss: 0.1816 - mean_absolute_error: 0.2996 - mean_squared_error: 0.1733 - rmse: 0.3956 - val_loss: 0.2443 - val_mean_absolute_error: 0.3597 - val_mean_squared_error: 0.2361 - val_rmse: 0.4394
# Epoch 28/100
#  - 102s - loss: 0.1814 - mean_absolute_error: 0.2995 - mean_squared_error: 0.1732 - rmse: 0.3954 - val_loss: 0.2437 - val_mean_absolute_error: 0.3614 - val_mean_squared_error: 0.2354 - val_rmse: 0.4428
# Epoch 29/100
#  - 121s - loss: 0.1813 - mean_absolute_error: 0.2994 - mean_squared_error: 0.1730 - rmse: 0.3953 - val_loss: 0.2379 - val_mean_absolute_error: 0.3507 - val_mean_squared_error: 0.2296 - val_rmse: 0.4305
# Epoch 30/100
#  - 109s - loss: 0.1814 - mean_absolute_error: 0.2992 - mean_squared_error: 0.1731 - rmse: 0.3956 - val_loss: 0.2317 - val_mean_absolute_error: 0.3439 - val_mean_squared_error: 0.2234 - val_rmse: 0.4236
# Epoch 31/100
#  - 92s - loss: 0.1811 - mean_absolute_error: 0.2991 - mean_squared_error: 0.1728 - rmse: 0.3951 - val_loss: 0.2447 - val_mean_absolute_error: 0.3566 - val_mean_squared_error: 0.2364 - val_rmse: 0.4357
# Epoch 32/100
#  - 97s - loss: 0.1812 - mean_absolute_error: 0.2990 - mean_squared_error: 0.1729 - rmse: 0.3952 - val_loss: 0.2424 - val_mean_absolute_error: 0.3604 - val_mean_squared_error: 0.2341 - val_rmse: 0.4406
# Epoch 33/100
#  - 109s - loss: 0.1810 - mean_absolute_error: 0.2989 - mean_squared_error: 0.1727 - rmse: 0.3949 - val_loss: 0.2332 - val_mean_absolute_error: 0.3482 - val_mean_squared_error: 0.2248 - val_rmse: 0.4285
# Epoch 34/100
#  - 96s - loss: 0.1810 - mean_absolute_error: 0.2989 - mean_squared_error: 0.1726 - rmse: 0.3949 - val_loss: 0.2442 - val_mean_absolute_error: 0.3558 - val_mean_squared_error: 0.2358 - val_rmse: 0.4373
# Epoch 35/100
#  - 98s - loss: 0.1809 - mean_absolute_error: 0.2986 - mean_squared_error: 0.1724 - rmse: 0.3946 - val_loss: 0.2302 - val_mean_absolute_error: 0.3466 - val_mean_squared_error: 0.2217 - val_rmse: 0.4279
# Epoch 36/100
#  - 96s - loss: 0.1809 - mean_absolute_error: 0.2986 - mean_squared_error: 0.1724 - rmse: 0.3946 - val_loss: 0.2284 - val_mean_absolute_error: 0.3395 - val_mean_squared_error: 0.2199 - val_rmse: 0.4202
# Epoch 37/100
#  - 95s - loss: 0.1808 - mean_absolute_error: 0.2985 - mean_squared_error: 0.1723 - rmse: 0.3947 - val_loss: 0.2339 - val_mean_absolute_error: 0.3502 - val_mean_squared_error: 0.2255 - val_rmse: 0.4313
# Epoch 38/100
#  - 92s - loss: 0.1807 - mean_absolute_error: 0.2984 - mean_squared_error: 0.1722 - rmse: 0.3943 - val_loss: 0.2360 - val_mean_absolute_error: 0.3488 - val_mean_squared_error: 0.2275 - val_rmse: 0.4314
# Epoch 39/100
#  - 89s - loss: 0.1807 - mean_absolute_error: 0.2983 - mean_squared_error: 0.1722 - rmse: 0.3943 - val_loss: 0.2384 - val_mean_absolute_error: 0.3528 - val_mean_squared_error: 0.2298 - val_rmse: 0.4330
# Epoch 40/100
#  - 93s - loss: 0.1807 - mean_absolute_error: 0.2983 - mean_squared_error: 0.1722 - rmse: 0.3945 - val_loss: 0.2403 - val_mean_absolute_error: 0.3559 - val_mean_squared_error: 0.2317 - val_rmse: 0.4341
# Epoch 41/100
#  - 113s - loss: 0.1806 - mean_absolute_error: 0.2981 - mean_squared_error: 0.1720 - rmse: 0.3943 - val_loss: 0.2376 - val_mean_absolute_error: 0.3520 - val_mean_squared_error: 0.2291 - val_rmse: 0.4328
# Epoch 42/100
#  - 148s - loss: 0.1804 - mean_absolute_error: 0.2981 - mean_squared_error: 0.1719 - rmse: 0.3940 - val_loss: 0.2463 - val_mean_absolute_error: 0.3558 - val_mean_squared_error: 0.2377 - val_rmse: 0.4364
# Epoch 43/100
#  - 118s - loss: 0.1804 - mean_absolute_error: 0.2979 - mean_squared_error: 0.1719 - rmse: 0.3941 - val_loss: 0.2326 - val_mean_absolute_error: 0.3465 - val_mean_squared_error: 0.2240 - val_rmse: 0.4266
# Epoch 44/100
#  - 99s - loss: 0.1803 - mean_absolute_error: 0.2979 - mean_squared_error: 0.1717 - rmse: 0.3937 - val_loss: 0.2315 - val_mean_absolute_error: 0.3460 - val_mean_squared_error: 0.2229 - val_rmse: 0.4285
# Epoch 45/100
#  - 114s - loss: 0.1804 - mean_absolute_error: 0.2980 - mean_squared_error: 0.1718 - rmse: 0.3942 - val_loss: 0.2324 - val_mean_absolute_error: 0.3443 - val_mean_squared_error: 0.2237 - val_rmse: 0.4241
# Epoch 46/100
#  - 129s - loss: 0.1803 - mean_absolute_error: 0.2978 - mean_squared_error: 0.1716 - rmse: 0.3936 - val_loss: 0.2603 - val_mean_absolute_error: 0.3776 - val_mean_squared_error: 0.2516 - val_rmse: 0.4617
# Epoch 47/100
#  - 90s - loss: 0.1803 - mean_absolute_error: 0.2978 - mean_squared_error: 0.1717 - rmse: 0.3938 - val_loss: 0.2272 - val_mean_absolute_error: 0.3408 - val_mean_squared_error: 0.2185 - val_rmse: 0.4208
# Epoch 48/100
#  - 98s - loss: 0.1803 - mean_absolute_error: 0.2977 - mean_squared_error: 0.1716 - rmse: 0.3936 - val_loss: 0.2381 - val_mean_absolute_error: 0.3540 - val_mean_squared_error: 0.2294 - val_rmse: 0.4351
# Epoch 49/100
#  - 85s - loss: 0.1802 - mean_absolute_error: 0.2977 - mean_squared_error: 0.1715 - rmse: 0.3935 - val_loss: 0.2547 - val_mean_absolute_error: 0.3661 - val_mean_squared_error: 0.2460 - val_rmse: 0.4466
# Epoch 50/100
#  - 87s - loss: 0.1802 - mean_absolute_error: 0.2975 - mean_squared_error: 0.1715 - rmse: 0.3936 - val_loss: 0.2412 - val_mean_absolute_error: 0.3503 - val_mean_squared_error: 0.2325 - val_rmse: 0.4311
# Epoch 51/100
#  - 99s - loss: 0.1804 - mean_absolute_error: 0.2977 - mean_squared_error: 0.1716 - rmse: 0.3937 - val_loss: 0.2346 - val_mean_absolute_error: 0.3491 - val_mean_squared_error: 0.2259 - val_rmse: 0.4270
# Test loss: 0.23456889448561485
# val_mean_absolute_error: 0.34906470169610176
# score
# [0.23456889448561485, 0.34906470169610176, 0.2258542943366814, 0.4434115279398264]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
