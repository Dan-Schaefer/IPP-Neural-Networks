# %% [markdown]
# # Run Objective:

# %% [markdown]
# ### Run0165
#
# Same as `Run0164` but with `output = efiITG_GB`

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2019-02-20_Run0165.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2019-02-20_Run0165
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal, Constant
from keras.utils import plot_model
from keras.models import Model
from keras.layers.core import Lambda
from keras.layers import Input
from keras.layers import Dense
from keras.layers import MaxoutDense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
#from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

#keras.backend.clear_session()
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
epochs = 100
L2_regularization = 5E-7

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efiITG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efiITG_GB'] = (joined_dataFrame['efiITG_GB'] - joined_dataFrame['efiITG_GB'].mean()) / joined_dataFrame['efiITG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efiITG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efiITG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean   2.878281e-15  2.272818e-15  4.304522e-15 -1.613474e-14 -2.575743e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.639065e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00
# 25%   -7.928000e-01 -7.898708e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01
# 50%   -1.059360e-01 -9.507533e-02  1.347799e-01 -3.983652e-01 -1.936629e-01
# 75%    5.809279e-01  5.997202e-01  6.437252e-01  1.976217e-01  9.108525e-01
# max    2.641520e+00  2.684107e+00  1.831264e+00  2.581570e+00  1.739239e+00
#
#                   x         Ti_Te
# count  6.479137e+06  6.479137e+06
# mean   1.979498e-15 -2.589595e-15
# std    1.000000e+00  1.000000e+00
# min   -1.405340e+00 -1.235044e+00
# 25%   -9.907529e-01 -8.817246e-01
# 50%   -1.615792e-01 -1.750863e-01
# 75%    6.675945e-01  7.576761e-01
# max    1.704062e+00  1.944828e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean   2.878281e-15  4.304522e-15 -1.613474e-14 -2.575743e-15  1.979498e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00 -1.405340e+00
# 25%   -7.928000e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01 -9.907529e-01
# 50%   -1.059360e-01  1.347799e-01 -3.983652e-01 -1.936629e-01 -1.615792e-01
# 75%    5.809279e-01  6.437252e-01  1.976217e-01  9.108525e-01  6.675945e-01
# max    2.641520e+00  1.831264e+00  2.581570e+00  1.739239e+00  1.704062e+00
#
#               Ti_Te
# count  6.479137e+06
# mean  -2.589595e-15
# std    1.000000e+00
# min   -1.235044e+00
# 25%   -8.817246e-01
# 50%   -1.750863e-01
# 75%    7.576761e-01
# max    1.944828e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (6479137, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.479137e+06
# mean   2.272818e-15
# std    1.000000e+00
# min   -1.639065e+00
# 25%   -7.898708e-01
# 50%   -9.507533e-02
# 75%    5.997202e-01
# max    2.684107e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (6479137, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6, ), name="6D_INPUTS")
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden1_branch1")(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden2_branch1")(hidden1_branch1)
theta_branch1 = Dense(1,
        activation='linear',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="theta_branch1")(hidden2_branch1)
theta_branch1_feeder = Dense(1,
        activation='linear',
        kernel_initializer=Constant(value=-1),
        bias_initializer='Zeros',
        trainable=False,
        name="theta_branch1_feeder")(theta_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1, ), name="Ate_INPUT")

# Addition_Operator (effectively subtraction though...)
addition_operator = keras.layers.Add(name="Addition_Operator")([theta_branch1_feeder, visible_branch2])

# ReLU Layer
TR = Dense(1, activation='relu',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=False,
           name="TR")(addition_operator)

# branch 3 (for c_3)
hidden1_branch3 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden1_branch3")(visible_branch1)
hidden2_branch3 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden2_branch3")(hidden1_branch3)
c_3_branch3 = Dense(1,
        activation='linear',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        trainable=True,
        name="c_3_branch3")(hidden2_branch3)

# Power_Operator    
power_layer = Lambda(lambda x: (K.clip(K.abs(x[0]), 0.00001, 1000)) ** (K.clip(x[1], -2., 4.)), name="Power_Operator")
power_operator = power_layer([addition_operator, c_3_branch3])

# branch 4 (for the gradient)
hidden1_branch4 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden1_branch4")(visible_branch1)
hidden2_branch4 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden2_branch4")(hidden1_branch4)
m_branch4 = Dense(1,
        activation='linear',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        trainable=True,
        name="m_branch4")(hidden2_branch4)   

# Multiplication_Operator_1
multiplication_operator_1 = keras.layers.Multiply(name="Multiplication_Operator_1")([TR, power_operator])

# Multiplication_Operator_2
multiplication_operator_2 = keras.layers.Multiply(name="Multiplication_Operator_2")([m_branch4, multiplication_operator_1])

# Output_Layer
output = Dense(1, activation='linear',
           kernel_initializer='Ones',
           kernel_regularizer=regularizers.l2(L2_regularization),
           bias_initializer='Zeros',
           trainable=True,
           name="Output_Layer")(multiplication_operator_2)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# 6D_INPUTS (InputLayer)          (None, 6)            0
# __________________________________________________________________________________________________
# hidden1_branch1 (Dense)         (None, 30)           210         6D_INPUTS[0][0]
# __________________________________________________________________________________________________
# hidden2_branch1 (Dense)         (None, 30)           930         hidden1_branch1[0][0]
# __________________________________________________________________________________________________
# theta_branch1 (Dense)           (None, 1)            31          hidden2_branch1[0][0]
# __________________________________________________________________________________________________
# hidden1_branch3 (Dense)         (None, 30)           210         6D_INPUTS[0][0]
# __________________________________________________________________________________________________
# theta_branch1_feeder (Dense)    (None, 1)            2           theta_branch1[0][0]
# __________________________________________________________________________________________________
# Ate_INPUT (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# hidden2_branch3 (Dense)         (None, 30)           930         hidden1_branch3[0][0]
# __________________________________________________________________________________________________
# hidden1_branch4 (Dense)         (None, 30)           210         6D_INPUTS[0][0]
# __________________________________________________________________________________________________
# Addition_Operator (Add)         (None, 1)            0           theta_branch1_feeder[0][0]
#                                                                  Ate_INPUT[0][0]
# __________________________________________________________________________________________________
# c_3_branch3 (Dense)             (None, 1)            31          hidden2_branch3[0][0]
# __________________________________________________________________________________________________
# hidden2_branch4 (Dense)         (None, 30)           930         hidden1_branch4[0][0]
# __________________________________________________________________________________________________
# TR (Dense)                      (None, 1)            2           Addition_Operator[0][0]
# __________________________________________________________________________________________________
# Power_Operator (Lambda)         (None, 1)            0           Addition_Operator[0][0]
#                                                                  c_3_branch3[0][0]
# __________________________________________________________________________________________________
# m_branch4 (Dense)               (None, 1)            31          hidden2_branch4[0][0]
# __________________________________________________________________________________________________
# Multiplication_Operator_1 (Mult (None, 1)            0           TR[0][0]
#                                                                  Power_Operator[0][0]
# __________________________________________________________________________________________________
# Multiplication_Operator_2 (Mult (None, 1)            0           m_branch4[0][0]
#                                                                  Multiplication_Operator_1[0][0]
# __________________________________________________________________________________________________
# Output_Layer (Dense)            (None, 1)            2           Multiplication_Operator_2[0][0]
# ==================================================================================================
# Total params: 3,519
# Trainable params: 3,515
# Non-trainable params: 4
# __________________________________________________________________________________________________
# None

# %%
# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    #callbacks=[tbCallBack, EarlyStoppingCallBack, NBatchLogger(5e4)])
                    callbacks=[tbCallBack, EarlyStoppingCallBack])
#5e4

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 5831223 samples, validate on 647914 samples
# Epoch 1/100
#  - 1198s - loss: 0.1761 - mean_absolute_error: 0.1569 - mean_squared_error: 0.1756 - rmse: 0.3092 - val_loss: 0.1747 - val_mean_absolute_error: 0.1543 - val_mean_squared_error: 0.1740 - val_rmse: 0.3055
# Epoch 2/100
#  - 1162s - loss: 0.1467 - mean_absolute_error: 0.1328 - mean_squared_error: 0.1459 - rmse: 0.2708 - val_loss: 0.1302 - val_mean_absolute_error: 0.1330 - val_mean_squared_error: 0.1293 - val_rmse: 0.2669
# Epoch 3/100
#  - 1093s - loss: 0.1542 - mean_absolute_error: 0.1251 - mean_squared_error: 0.1532 - rmse: 0.2599 - val_loss: 0.1340 - val_mean_absolute_error: 0.1217 - val_mean_squared_error: 0.1329 - val_rmse: 0.2599
# Epoch 4/100
#  - 1081s - loss: 0.1381 - mean_absolute_error: 0.1211 - mean_squared_error: 0.1369 - rmse: 0.2548 - val_loss: 0.1264 - val_mean_absolute_error: 0.1180 - val_mean_squared_error: 0.1251 - val_rmse: 0.2522
# Epoch 5/100
#  - 1086s - loss: 0.1730 - mean_absolute_error: 0.1180 - mean_squared_error: 0.1716 - rmse: 0.2495 - val_loss: 0.1108 - val_mean_absolute_error: 0.1077 - val_mean_squared_error: 0.1093 - val_rmse: 0.2332
# Epoch 6/100
#  - 1084s - loss: 0.1274 - mean_absolute_error: 0.1156 - mean_squared_error: 0.1258 - rmse: 0.2463 - val_loss: 0.1457 - val_mean_absolute_error: 0.1230 - val_mean_squared_error: 0.1441 - val_rmse: 0.2695
# Epoch 7/100
#  - 1086s - loss: 0.1211 - mean_absolute_error: 0.1148 - mean_squared_error: 0.1194 - rmse: 0.2446 - val_loss: 0.1166 - val_mean_absolute_error: 0.1149 - val_mean_squared_error: 0.1148 - val_rmse: 0.2431
# Epoch 8/100
#  - 1083s - loss: 0.1189 - mean_absolute_error: 0.1131 - mean_squared_error: 0.1171 - rmse: 0.2414 - val_loss: 0.1229 - val_mean_absolute_error: 0.1166 - val_mean_squared_error: 0.1210 - val_rmse: 0.2468
# Epoch 9/100
#  - 1080s - loss: 0.1203 - mean_absolute_error: 0.1133 - mean_squared_error: 0.1184 - rmse: 0.2418 - val_loss: 0.1221 - val_mean_absolute_error: 0.1164 - val_mean_squared_error: 0.1201 - val_rmse: 0.2446
# Epoch 10/100
#  - 1088s - loss: 0.1196 - mean_absolute_error: 0.1132 - mean_squared_error: 0.1176 - rmse: 0.2416 - val_loss: 0.1240 - val_mean_absolute_error: 0.1153 - val_mean_squared_error: 0.1219 - val_rmse: 0.2454
# Epoch 11/100
#  - 1081s - loss: 0.1196 - mean_absolute_error: 0.1127 - mean_squared_error: 0.1175 - rmse: 0.2399 - val_loss: 0.1074 - val_mean_absolute_error: 0.1083 - val_mean_squared_error: 0.1053 - val_rmse: 0.2291
# Epoch 12/100
#  - 1086s - loss: 0.1237 - mean_absolute_error: 0.1124 - mean_squared_error: 0.1215 - rmse: 0.2402 - val_loss: 0.1316 - val_mean_absolute_error: 0.1172 - val_mean_squared_error: 0.1294 - val_rmse: 0.2506
# Epoch 13/100
#  - 1089s - loss: 0.1210 - mean_absolute_error: 0.1124 - mean_squared_error: 0.1188 - rmse: 0.2408 - val_loss: 0.1076 - val_mean_absolute_error: 0.1084 - val_mean_squared_error: 0.1053 - val_rmse: 0.2315
# Epoch 14/100
#  - 1089s - loss: 0.1151 - mean_absolute_error: 0.1101 - mean_squared_error: 0.1129 - rmse: 0.2364 - val_loss: 0.1090 - val_mean_absolute_error: 0.1037 - val_mean_squared_error: 0.1067 - val_rmse: 0.2275
# Epoch 15/100
#  - 1090s - loss: 0.1158 - mean_absolute_error: 0.1100 - mean_squared_error: 0.1135 - rmse: 0.2361 - val_loss: 0.1242 - val_mean_absolute_error: 0.1136 - val_mean_squared_error: 0.1219 - val_rmse: 0.2486
# Epoch 16/100
#  - 1087s - loss: 0.1151 - mean_absolute_error: 0.1091 - mean_squared_error: 0.1127 - rmse: 0.2348 - val_loss: 0.1603 - val_mean_absolute_error: 0.1245 - val_mean_squared_error: 0.1580 - val_rmse: 0.2763
# Epoch 17/100
#  - 1095s - loss: 0.1190 - mean_absolute_error: 0.1098 - mean_squared_error: 0.1166 - rmse: 0.2368 - val_loss: 0.1123 - val_mean_absolute_error: 0.1081 - val_mean_squared_error: 0.1098 - val_rmse: 0.2329
# Epoch 18/100
#  - 1086s - loss: 0.1155 - mean_absolute_error: 0.1087 - mean_squared_error: 0.1130 - rmse: 0.2350 - val_loss: 0.1323 - val_mean_absolute_error: 0.1178 - val_mean_squared_error: 0.1299 - val_rmse: 0.2576
# Epoch 19/100
#  - 1092s - loss: 0.1159 - mean_absolute_error: 0.1088 - mean_squared_error: 0.1134 - rmse: 0.2351 - val_loss: 0.1092 - val_mean_absolute_error: 0.1089 - val_mean_squared_error: 0.1067 - val_rmse: 0.2298
# Epoch 20/100
#  - 1093s - loss: 0.1169 - mean_absolute_error: 0.1083 - mean_squared_error: 0.1144 - rmse: 0.2344 - val_loss: 0.1376 - val_mean_absolute_error: 0.1166 - val_mean_squared_error: 0.1350 - val_rmse: 0.2598
# Epoch 21/100
#  - 1091s - loss: 0.1155 - mean_absolute_error: 0.1077 - mean_squared_error: 0.1130 - rmse: 0.2340 - val_loss: 0.0998 - val_mean_absolute_error: 0.1017 - val_mean_squared_error: 0.0973 - val_rmse: 0.2190
# Epoch 22/100
#  - 1094s - loss: 0.1137 - mean_absolute_error: 0.1074 - mean_squared_error: 0.1112 - rmse: 0.2332 - val_loss: 0.1035 - val_mean_absolute_error: 0.1026 - val_mean_squared_error: 0.1009 - val_rmse: 0.2222
# Epoch 23/100
#  - 1095s - loss: 0.1187 - mean_absolute_error: 0.1085 - mean_squared_error: 0.1161 - rmse: 0.2352 - val_loss: 0.1197 - val_mean_absolute_error: 0.1126 - val_mean_squared_error: 0.1171 - val_rmse: 0.2442
# Epoch 24/100
#  - 1093s - loss: 0.1143 - mean_absolute_error: 0.1069 - mean_squared_error: 0.1117 - rmse: 0.2329 - val_loss: 0.1025 - val_mean_absolute_error: 0.1019 - val_mean_squared_error: 0.0999 - val_rmse: 0.2207
# Epoch 25/100
#  - 1095s - loss: 0.1306 - mean_absolute_error: 0.1085 - mean_squared_error: 0.1281 - rmse: 0.2369 - val_loss: 0.1336 - val_mean_absolute_error: 0.1127 - val_mean_squared_error: 0.1310 - val_rmse: 0.2526
# Epoch 26/100
#  - 1096s - loss: 0.1152 - mean_absolute_error: 0.1072 - mean_squared_error: 0.1126 - rmse: 0.2336 - val_loss: 0.0992 - val_mean_absolute_error: 0.1020 - val_mean_squared_error: 0.0966 - val_rmse: 0.2167
# Epoch 27/100
#  - 1098s - loss: 0.1166 - mean_absolute_error: 0.1066 - mean_squared_error: 0.1139 - rmse: 0.2324 - val_loss: 0.1039 - val_mean_absolute_error: 0.1005 - val_mean_squared_error: 0.1013 - val_rmse: 0.2217
# Epoch 28/100
#  - 1094s - loss: 0.1152 - mean_absolute_error: 0.1072 - mean_squared_error: 0.1126 - rmse: 0.2330 - val_loss: 0.1059 - val_mean_absolute_error: 0.1028 - val_mean_squared_error: 0.1032 - val_rmse: 0.2257
# Epoch 29/100
#  - 1097s - loss: 0.1177 - mean_absolute_error: 0.1072 - mean_squared_error: 0.1151 - rmse: 0.2335 - val_loss: 0.0981 - val_mean_absolute_error: 0.1006 - val_mean_squared_error: 0.0954 - val_rmse: 0.2182
# Epoch 30/100
#  - 1102s - loss: 0.1151 - mean_absolute_error: 0.1072 - mean_squared_error: 0.1124 - rmse: 0.2332 - val_loss: 0.1388 - val_mean_absolute_error: 0.1156 - val_mean_squared_error: 0.1362 - val_rmse: 0.2539
# Epoch 31/100
#  - 1096s - loss: 0.1255 - mean_absolute_error: 0.1080 - mean_squared_error: 0.1228 - rmse: 0.2342 - val_loss: 0.1080 - val_mean_absolute_error: 0.1041 - val_mean_squared_error: 0.1054 - val_rmse: 0.2287
# Epoch 32/100
#  - 1096s - loss: 0.1166 - mean_absolute_error: 0.1080 - mean_squared_error: 0.1139 - rmse: 0.2339 - val_loss: 0.1304 - val_mean_absolute_error: 0.1151 - val_mean_squared_error: 0.1278 - val_rmse: 0.2493
# Epoch 33/100
#  - 1101s - loss: 0.1177 - mean_absolute_error: 0.1079 - mean_squared_error: 0.1150 - rmse: 0.2338 - val_loss: 0.1025 - val_mean_absolute_error: 0.1018 - val_mean_squared_error: 0.0998 - val_rmse: 0.2203
# Epoch 34/100
#  - 1098s - loss: 0.1287 - mean_absolute_error: 0.1081 - mean_squared_error: 0.1259 - rmse: 0.2339 - val_loss: 0.1223 - val_mean_absolute_error: 0.1081 - val_mean_squared_error: 0.1195 - val_rmse: 0.2408
# Epoch 35/100
#  - 1099s - loss: 0.1162 - mean_absolute_error: 0.1082 - mean_squared_error: 0.1134 - rmse: 0.2344 - val_loss: 0.1172 - val_mean_absolute_error: 0.1061 - val_mean_squared_error: 0.1144 - val_rmse: 0.2347
# Epoch 36/100
#  - 1096s - loss: 0.1138 - mean_absolute_error: 0.1073 - mean_squared_error: 0.1110 - rmse: 0.2326 - val_loss: 0.1215 - val_mean_absolute_error: 0.1134 - val_mean_squared_error: 0.1187 - val_rmse: 0.2460
# Epoch 37/100
#  - 1088s - loss: 0.1178 - mean_absolute_error: 0.1079 - mean_squared_error: 0.1150 - rmse: 0.2332 - val_loss: 0.1118 - val_mean_absolute_error: 0.1073 - val_mean_squared_error: 0.1089 - val_rmse: 0.2310
# Epoch 38/100
#  - 1096s - loss: 0.1148 - mean_absolute_error: 0.1071 - mean_squared_error: 0.1119 - rmse: 0.2324 - val_loss: 0.1108 - val_mean_absolute_error: 0.1070 - val_mean_squared_error: 0.1079 - val_rmse: 0.2315
# Epoch 39/100
#  - 1092s - loss: 0.1189 - mean_absolute_error: 0.1079 - mean_squared_error: 0.1160 - rmse: 0.2335 - val_loss: 0.1166 - val_mean_absolute_error: 0.1086 - val_mean_squared_error: 0.1137 - val_rmse: 0.2357
# Epoch 40/100
#  - 1098s - loss: 0.1141 - mean_absolute_error: 0.1076 - mean_squared_error: 0.1112 - rmse: 0.2326 - val_loss: 0.1040 - val_mean_absolute_error: 0.1016 - val_mean_squared_error: 0.1011 - val_rmse: 0.2207
# Epoch 41/100
#  - 1250s - loss: 0.1159 - mean_absolute_error: 0.1083 - mean_squared_error: 0.1130 - rmse: 0.2330 - val_loss: 0.4219 - val_mean_absolute_error: 0.1063 - val_mean_squared_error: 0.4190 - val_rmse: 0.2303
# Test loss: 0.4218899808325704
# val_mean_absolute_error: 0.10628612681153375
# score
# [0.4218899808325704, 0.10628612681153375, 0.41896386642066924, 0.2818333995999115]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
