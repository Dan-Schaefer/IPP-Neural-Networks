# %% [markdown]
# # Run Objective:

# %% [markdown]
# ### Run0129-SERIES
#
# After the last series of runs, I want to find out the best architecture for matching the threshold only. I'll then add the variable gradient from `Run0127`. I'm starting with `Run0126e` and testing the following:
#
# >  Dataset: **"unstable" (unstable_training_gen3_7D_nions0_flat_filter8.h5)** vs. **"unstable + stable" (training_gen3_7D_nions0_flat_filter8.h5)**
#
# -  `Run0129a`

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-23_Run0129a.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-23_Run0129a
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal, Constant
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -6.179115e-11  1.066159e-11 -2.500561e-13  1.163540e-13  2.223047e-12
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.639065e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00
# 25%   -7.928000e-01 -7.898708e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01
# 50%   -1.059360e-01 -9.507533e-02  1.347799e-01 -3.983652e-01 -1.936629e-01
# 75%    5.809279e-01  5.997202e-01  6.437252e-01  1.976217e-01  9.108525e-01
# max    2.641520e+00  2.684107e+00  1.831264e+00  2.581570e+00  1.739239e+00
#
#                   x         Ti_Te
# count  6.479137e+06  6.479137e+06
# mean   7.274219e-13  4.194752e-14
# std    1.000000e+00  1.000000e+00
# min   -1.405340e+00 -1.235044e+00
# 25%   -9.907529e-01 -8.817246e-01
# 50%   -1.615792e-01 -1.750863e-01
# 75%    6.675945e-01  7.576761e-01
# max    1.704062e+00  1.944828e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -6.179115e-11 -2.500561e-13  1.163540e-13  2.223047e-12  7.274219e-13
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00 -1.405340e+00
# 25%   -7.928000e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01 -9.907529e-01
# 50%   -1.059360e-01  1.347799e-01 -3.983652e-01 -1.936629e-01 -1.615792e-01
# 75%    5.809279e-01  6.437252e-01  1.976217e-01  9.108525e-01  6.675945e-01
# max    2.641520e+00  1.831264e+00  2.581570e+00  1.739239e+00  1.704062e+00
#
#               Ti_Te
# count  6.479137e+06
# mean   4.194752e-14
# std    1.000000e+00
# min   -1.235044e+00
# 25%   -8.817246e-01
# 50%   -1.750863e-01
# 75%    7.576761e-01
# max    1.944828e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (6479137, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.479137e+06
# mean   1.066159e-11
# std    1.000000e+00
# min   -1.639065e+00
# 25%   -7.898708e-01
# 50%   -9.507533e-02
# 75%    5.997202e-01
# max    2.684107e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (6479137, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)
theta_branch1 = Dense(1,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden2_branch1)
theta_branch1_feeder = Dense(1,
        activation='linear',
        kernel_initializer=Constant(value=-1),
        bias_initializer='Zeros',
        trainable=False)(theta_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)

# addition_pooling (effectively subtraction though...)
addition_pooling = keras.layers.Add()([theta_branch1_feeder, visible_branch2_feeder])


TR = Dense(1, activation='relu',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=True)(addition_pooling)

# merge input models
#merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=True)(TR)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            31          dense_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            2           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            2           add_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            2           dense_6[0][0]
# ==================================================================================================
# Total params: 1,179
# Trainable params: 1,177
# Non-trainable params: 2
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 5831223 samples, validate on 647914 samples
# Epoch 1/100
#  - 321s - loss: 0.1380 - mean_absolute_error: 0.0947 - mean_squared_error: 0.1313 - rmse: 0.2313 - val_loss: 0.1923 - val_mean_absolute_error: 0.1241 - val_mean_squared_error: 0.1846 - val_rmse: 0.1786
# Epoch 2/100
#  - 322s - loss: 0.1212 - mean_absolute_error: 0.0870 - mean_squared_error: 0.1131 - rmse: 0.2137 - val_loss: 0.1595 - val_mean_absolute_error: 0.1064 - val_mean_squared_error: 0.1511 - val_rmse: 0.1554
# Epoch 3/100
#  - 319s - loss: 0.1190 - mean_absolute_error: 0.0859 - mean_squared_error: 0.1104 - rmse: 0.2109 - val_loss: 0.1869 - val_mean_absolute_error: 0.1215 - val_mean_squared_error: 0.1780 - val_rmse: 0.1768
# Epoch 4/100
#  - 315s - loss: 0.1179 - mean_absolute_error: 0.0855 - mean_squared_error: 0.1091 - rmse: 0.2099 - val_loss: 0.1474 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.1385 - val_rmse: 0.1416
# Epoch 5/100
#  - 314s - loss: 0.1173 - mean_absolute_error: 0.0853 - mean_squared_error: 0.1082 - rmse: 0.2089 - val_loss: 0.1708 - val_mean_absolute_error: 0.1072 - val_mean_squared_error: 0.1616 - val_rmse: 0.1545
# Epoch 6/100
#  - 314s - loss: 0.1171 - mean_absolute_error: 0.0850 - mean_squared_error: 0.1078 - rmse: 0.2085 - val_loss: 0.1381 - val_mean_absolute_error: 0.1014 - val_mean_squared_error: 0.1288 - val_rmse: 0.1485
# Epoch 7/100
#  - 315s - loss: 0.1169 - mean_absolute_error: 0.0849 - mean_squared_error: 0.1076 - rmse: 0.2083 - val_loss: 0.1476 - val_mean_absolute_error: 0.1003 - val_mean_squared_error: 0.1382 - val_rmse: 0.1498
# Epoch 8/100
#  - 315s - loss: 0.1165 - mean_absolute_error: 0.0846 - mean_squared_error: 0.1070 - rmse: 0.2077 - val_loss: 0.1413 - val_mean_absolute_error: 0.0992 - val_mean_squared_error: 0.1318 - val_rmse: 0.1453
# Epoch 9/100
#  - 314s - loss: 0.1164 - mean_absolute_error: 0.0844 - mean_squared_error: 0.1068 - rmse: 0.2072 - val_loss: 0.1565 - val_mean_absolute_error: 0.1059 - val_mean_squared_error: 0.1469 - val_rmse: 0.1566
# Epoch 10/100
#  - 313s - loss: 0.1159 - mean_absolute_error: 0.0840 - mean_squared_error: 0.1063 - rmse: 0.2065 - val_loss: 0.1775 - val_mean_absolute_error: 0.1140 - val_mean_squared_error: 0.1679 - val_rmse: 0.1674
# Epoch 11/100
#  - 313s - loss: 0.1157 - mean_absolute_error: 0.0840 - mean_squared_error: 0.1060 - rmse: 0.2064 - val_loss: 0.1530 - val_mean_absolute_error: 0.1035 - val_mean_squared_error: 0.1433 - val_rmse: 0.1543
# Epoch 12/100
#  - 315s - loss: 0.1153 - mean_absolute_error: 0.0836 - mean_squared_error: 0.1055 - rmse: 0.2057 - val_loss: 0.1412 - val_mean_absolute_error: 0.1007 - val_mean_squared_error: 0.1313 - val_rmse: 0.1463
# Epoch 13/100
#  - 312s - loss: 0.1149 - mean_absolute_error: 0.0833 - mean_squared_error: 0.1050 - rmse: 0.2051 - val_loss: 0.1539 - val_mean_absolute_error: 0.1067 - val_mean_squared_error: 0.1440 - val_rmse: 0.1578
# Epoch 14/100
#  - 313s - loss: 0.1147 - mean_absolute_error: 0.0833 - mean_squared_error: 0.1048 - rmse: 0.2050 - val_loss: 0.1439 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.1340 - val_rmse: 0.1403
# Epoch 15/100
#  - 312s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2047 - val_loss: 0.1571 - val_mean_absolute_error: 0.1092 - val_mean_squared_error: 0.1472 - val_rmse: 0.1580
# Epoch 16/100
#  - 314s - loss: 0.1146 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1046 - rmse: 0.2046 - val_loss: 0.1480 - val_mean_absolute_error: 0.1068 - val_mean_squared_error: 0.1378 - val_rmse: 0.1538
# Epoch 17/100
#  - 313s - loss: 0.1147 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1046 - rmse: 0.2047 - val_loss: 0.1973 - val_mean_absolute_error: 0.1295 - val_mean_squared_error: 0.1872 - val_rmse: 0.1862
# Epoch 18/100
#  - 312s - loss: 0.1146 - mean_absolute_error: 0.0831 - mean_squared_error: 0.1045 - rmse: 0.2046 - val_loss: 0.1400 - val_mean_absolute_error: 0.0939 - val_mean_squared_error: 0.1300 - val_rmse: 0.1390
# Epoch 19/100
#  - 314s - loss: 0.1146 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2046 - val_loss: 0.1396 - val_mean_absolute_error: 0.0981 - val_mean_squared_error: 0.1294 - val_rmse: 0.1443
# Epoch 20/100
#  - 314s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1044 - rmse: 0.2047 - val_loss: 0.1486 - val_mean_absolute_error: 0.0977 - val_mean_squared_error: 0.1385 - val_rmse: 0.1440
# Epoch 21/100
#  - 313s - loss: 0.1145 - mean_absolute_error: 0.0831 - mean_squared_error: 0.1044 - rmse: 0.2044 - val_loss: 0.1655 - val_mean_absolute_error: 0.1041 - val_mean_squared_error: 0.1554 - val_rmse: 0.1510
# Epoch 22/100
#  - 315s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1044 - rmse: 0.2046 - val_loss: 0.1538 - val_mean_absolute_error: 0.1050 - val_mean_squared_error: 0.1438 - val_rmse: 0.1515
# Epoch 23/100
#  - 311s - loss: 0.1145 - mean_absolute_error: 0.0834 - mean_squared_error: 0.1044 - rmse: 0.2047 - val_loss: 0.1513 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.1413 - val_rmse: 0.1503
# Epoch 24/100
#  - 314s - loss: 0.1144 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1044 - rmse: 0.2047 - val_loss: 0.1455 - val_mean_absolute_error: 0.0966 - val_mean_squared_error: 0.1354 - val_rmse: 0.1454
# Epoch 25/100
#  - 313s - loss: 0.1145 - mean_absolute_error: 0.0831 - mean_squared_error: 0.1044 - rmse: 0.2045 - val_loss: 0.1427 - val_mean_absolute_error: 0.1058 - val_mean_squared_error: 0.1327 - val_rmse: 0.1530
# Epoch 26/100
#  - 314s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2046 - val_loss: 0.1816 - val_mean_absolute_error: 0.1195 - val_mean_squared_error: 0.1716 - val_rmse: 0.1706
# Epoch 27/100
#  - 314s - loss: 0.1146 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1046 - rmse: 0.2047 - val_loss: 0.1847 - val_mean_absolute_error: 0.1185 - val_mean_squared_error: 0.1747 - val_rmse: 0.1727
# Epoch 28/100
#  - 314s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2046 - val_loss: 0.1416 - val_mean_absolute_error: 0.1009 - val_mean_squared_error: 0.1315 - val_rmse: 0.1490
# Epoch 29/100
#  - 314s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2047 - val_loss: 0.1391 - val_mean_absolute_error: 0.0972 - val_mean_squared_error: 0.1291 - val_rmse: 0.1453
# Epoch 30/100
#  - 313s - loss: 0.1146 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1046 - rmse: 0.2046 - val_loss: 0.1592 - val_mean_absolute_error: 0.1129 - val_mean_squared_error: 0.1492 - val_rmse: 0.1674
# Epoch 31/100
#  - 313s - loss: 0.1143 - mean_absolute_error: 0.0831 - mean_squared_error: 0.1043 - rmse: 0.2045 - val_loss: 0.1874 - val_mean_absolute_error: 0.1315 - val_mean_squared_error: 0.1774 - val_rmse: 0.1904
# Epoch 32/100
#  - 313s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1045 - rmse: 0.2047 - val_loss: 0.1546 - val_mean_absolute_error: 0.1078 - val_mean_squared_error: 0.1445 - val_rmse: 0.1563
# Epoch 33/100
#  - 313s - loss: 0.1145 - mean_absolute_error: 0.0832 - mean_squared_error: 0.1044 - rmse: 0.2046 - val_loss: 0.1560 - val_mean_absolute_error: 0.1019 - val_mean_squared_error: 0.1459 - val_rmse: 0.1526
# Test loss: 0.15597985675966589
# val_mean_absolute_error: 0.10193796170306334
# score
# [0.15597985675966589, 0.10193796170306334, 0.14589866714507058, 0.17180553408643265]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
