# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0104 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
#
# -  This series contains Run0115 - Run0125
#
#
# Settings:
# -  theta = 0.6

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-11_Run0120.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-11_Run0120
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.6)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 88s - loss: 0.2707 - mean_absolute_error: 0.3733 - mean_squared_error: 0.2658 - rmse: 0.4848 - val_loss: 0.3125 - val_mean_absolute_error: 0.4091 - val_mean_squared_error: 0.3065 - val_rmse: 0.4860
# Epoch 2/100
#  - 75s - loss: 0.2117 - mean_absolute_error: 0.3276 - mean_squared_error: 0.2054 - rmse: 0.4302 - val_loss: 0.2734 - val_mean_absolute_error: 0.3702 - val_mean_squared_error: 0.2669 - val_rmse: 0.4530
# Epoch 3/100
#  - 83s - loss: 0.2080 - mean_absolute_error: 0.3240 - mean_squared_error: 0.2012 - rmse: 0.4260 - val_loss: 0.2745 - val_mean_absolute_error: 0.3751 - val_mean_squared_error: 0.2676 - val_rmse: 0.4560
# Epoch 4/100
#  - 91s - loss: 0.2062 - mean_absolute_error: 0.3221 - mean_squared_error: 0.1992 - rmse: 0.4236 - val_loss: 0.2566 - val_mean_absolute_error: 0.3576 - val_mean_squared_error: 0.2494 - val_rmse: 0.4397
# Epoch 5/100
#  - 105s - loss: 0.2053 - mean_absolute_error: 0.3210 - mean_squared_error: 0.1981 - rmse: 0.4222 - val_loss: 0.2486 - val_mean_absolute_error: 0.3604 - val_mean_squared_error: 0.2412 - val_rmse: 0.4421
# Epoch 6/100
#  - 94s - loss: 0.2045 - mean_absolute_error: 0.3200 - mean_squared_error: 0.1970 - rmse: 0.4210 - val_loss: 0.2567 - val_mean_absolute_error: 0.3584 - val_mean_squared_error: 0.2492 - val_rmse: 0.4387
# Epoch 7/100
#  - 101s - loss: 0.2039 - mean_absolute_error: 0.3192 - mean_squared_error: 0.1963 - rmse: 0.4202 - val_loss: 0.2525 - val_mean_absolute_error: 0.3570 - val_mean_squared_error: 0.2448 - val_rmse: 0.4407
# Epoch 8/100
#  - 96s - loss: 0.2035 - mean_absolute_error: 0.3188 - mean_squared_error: 0.1959 - rmse: 0.4198 - val_loss: 0.2656 - val_mean_absolute_error: 0.3794 - val_mean_squared_error: 0.2579 - val_rmse: 0.4607
# Epoch 9/100
#  - 93s - loss: 0.2034 - mean_absolute_error: 0.3185 - mean_squared_error: 0.1956 - rmse: 0.4194 - val_loss: 0.2791 - val_mean_absolute_error: 0.3801 - val_mean_squared_error: 0.2712 - val_rmse: 0.4638
# Epoch 10/100
#  - 89s - loss: 0.2029 - mean_absolute_error: 0.3180 - mean_squared_error: 0.1951 - rmse: 0.4188 - val_loss: 0.2643 - val_mean_absolute_error: 0.3631 - val_mean_squared_error: 0.2564 - val_rmse: 0.4458
# Epoch 11/100
#  - 83s - loss: 0.2026 - mean_absolute_error: 0.3177 - mean_squared_error: 0.1947 - rmse: 0.4185 - val_loss: 0.2569 - val_mean_absolute_error: 0.3663 - val_mean_squared_error: 0.2490 - val_rmse: 0.4483
# Epoch 12/100
#  - 92s - loss: 0.2025 - mean_absolute_error: 0.3173 - mean_squared_error: 0.1945 - rmse: 0.4180 - val_loss: 0.2593 - val_mean_absolute_error: 0.3572 - val_mean_squared_error: 0.2513 - val_rmse: 0.4386
# Epoch 13/100
#  - 98s - loss: 0.2023 - mean_absolute_error: 0.3171 - mean_squared_error: 0.1942 - rmse: 0.4177 - val_loss: 0.2551 - val_mean_absolute_error: 0.3712 - val_mean_squared_error: 0.2470 - val_rmse: 0.4512
# Epoch 14/100
#  - 84s - loss: 0.2018 - mean_absolute_error: 0.3167 - mean_squared_error: 0.1938 - rmse: 0.4173 - val_loss: 0.2549 - val_mean_absolute_error: 0.3588 - val_mean_squared_error: 0.2468 - val_rmse: 0.4393
# Epoch 15/100
#  - 76s - loss: 0.2020 - mean_absolute_error: 0.3166 - mean_squared_error: 0.1939 - rmse: 0.4173 - val_loss: 0.2527 - val_mean_absolute_error: 0.3626 - val_mean_squared_error: 0.2446 - val_rmse: 0.4438
# Epoch 16/100
#  - 80s - loss: 0.2018 - mean_absolute_error: 0.3165 - mean_squared_error: 0.1937 - rmse: 0.4172 - val_loss: 0.2723 - val_mean_absolute_error: 0.3734 - val_mean_squared_error: 0.2641 - val_rmse: 0.4526
# Epoch 17/100
#  - 83s - loss: 0.2019 - mean_absolute_error: 0.3166 - mean_squared_error: 0.1937 - rmse: 0.4171 - val_loss: 0.2628 - val_mean_absolute_error: 0.3614 - val_mean_squared_error: 0.2546 - val_rmse: 0.4418
# Epoch 18/100
#  - 76s - loss: 0.2017 - mean_absolute_error: 0.3163 - mean_squared_error: 0.1934 - rmse: 0.4169 - val_loss: 0.2590 - val_mean_absolute_error: 0.3543 - val_mean_squared_error: 0.2508 - val_rmse: 0.4357
# Epoch 19/100
#  - 87s - loss: 0.2017 - mean_absolute_error: 0.3163 - mean_squared_error: 0.1935 - rmse: 0.4171 - val_loss: 0.2511 - val_mean_absolute_error: 0.3566 - val_mean_squared_error: 0.2429 - val_rmse: 0.4371
# Epoch 20/100
#  - 86s - loss: 0.2016 - mean_absolute_error: 0.3161 - mean_squared_error: 0.1933 - rmse: 0.4167 - val_loss: 0.2518 - val_mean_absolute_error: 0.3555 - val_mean_squared_error: 0.2436 - val_rmse: 0.4383
# Epoch 21/100
#  - 74s - loss: 0.2015 - mean_absolute_error: 0.3161 - mean_squared_error: 0.1932 - rmse: 0.4168 - val_loss: 0.2802 - val_mean_absolute_error: 0.3783 - val_mean_squared_error: 0.2719 - val_rmse: 0.4570
# Epoch 22/100
#  - 90s - loss: 0.2015 - mean_absolute_error: 0.3160 - mean_squared_error: 0.1933 - rmse: 0.4167 - val_loss: 0.2629 - val_mean_absolute_error: 0.3648 - val_mean_squared_error: 0.2546 - val_rmse: 0.4485
# Epoch 23/100
#  - 84s - loss: 0.2015 - mean_absolute_error: 0.3162 - mean_squared_error: 0.1932 - rmse: 0.4167 - val_loss: 0.2593 - val_mean_absolute_error: 0.3549 - val_mean_squared_error: 0.2510 - val_rmse: 0.4380
# Epoch 24/100
#  - 83s - loss: 0.2013 - mean_absolute_error: 0.3160 - mean_squared_error: 0.1930 - rmse: 0.4164 - val_loss: 0.2515 - val_mean_absolute_error: 0.3587 - val_mean_squared_error: 0.2432 - val_rmse: 0.4390
# Epoch 25/100
#  - 84s - loss: 0.2015 - mean_absolute_error: 0.3160 - mean_squared_error: 0.1932 - rmse: 0.4165 - val_loss: 0.2572 - val_mean_absolute_error: 0.3627 - val_mean_squared_error: 0.2489 - val_rmse: 0.4444
# Epoch 26/100
#  - 86s - loss: 0.2014 - mean_absolute_error: 0.3158 - mean_squared_error: 0.1931 - rmse: 0.4166 - val_loss: 0.2451 - val_mean_absolute_error: 0.3482 - val_mean_squared_error: 0.2367 - val_rmse: 0.4298
# Epoch 27/100
#  - 87s - loss: 0.2013 - mean_absolute_error: 0.3158 - mean_squared_error: 0.1930 - rmse: 0.4165 - val_loss: 0.2524 - val_mean_absolute_error: 0.3535 - val_mean_squared_error: 0.2441 - val_rmse: 0.4335
# Epoch 28/100
#  - 81s - loss: 0.2013 - mean_absolute_error: 0.3157 - mean_squared_error: 0.1930 - rmse: 0.4165 - val_loss: 0.2666 - val_mean_absolute_error: 0.3678 - val_mean_squared_error: 0.2582 - val_rmse: 0.4449
# Epoch 29/100
#  - 97s - loss: 0.2012 - mean_absolute_error: 0.3158 - mean_squared_error: 0.1929 - rmse: 0.4164 - val_loss: 0.2551 - val_mean_absolute_error: 0.3642 - val_mean_squared_error: 0.2468 - val_rmse: 0.4450
# Epoch 30/100
#  - 92s - loss: 0.2012 - mean_absolute_error: 0.3158 - mean_squared_error: 0.1929 - rmse: 0.4163 - val_loss: 0.2507 - val_mean_absolute_error: 0.3633 - val_mean_squared_error: 0.2424 - val_rmse: 0.4433
# Epoch 31/100
#  - 120s - loss: 0.2011 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1929 - rmse: 0.4161 - val_loss: 0.2536 - val_mean_absolute_error: 0.3583 - val_mean_squared_error: 0.2453 - val_rmse: 0.4399
# Epoch 32/100
#  - 81s - loss: 0.2011 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1928 - rmse: 0.4163 - val_loss: 0.2629 - val_mean_absolute_error: 0.3698 - val_mean_squared_error: 0.2546 - val_rmse: 0.4527
# Epoch 33/100
#  - 77s - loss: 0.2012 - mean_absolute_error: 0.3156 - mean_squared_error: 0.1928 - rmse: 0.4161 - val_loss: 0.2525 - val_mean_absolute_error: 0.3627 - val_mean_squared_error: 0.2441 - val_rmse: 0.4433
# Epoch 34/100
#  - 84s - loss: 0.2010 - mean_absolute_error: 0.3153 - mean_squared_error: 0.1926 - rmse: 0.4160 - val_loss: 0.2501 - val_mean_absolute_error: 0.3599 - val_mean_squared_error: 0.2418 - val_rmse: 0.4409
# Epoch 35/100
#  - 79s - loss: 0.2010 - mean_absolute_error: 0.3153 - mean_squared_error: 0.1926 - rmse: 0.4160 - val_loss: 0.2563 - val_mean_absolute_error: 0.3642 - val_mean_squared_error: 0.2480 - val_rmse: 0.4472
# Epoch 36/100
#  - 76s - loss: 0.2010 - mean_absolute_error: 0.3154 - mean_squared_error: 0.1926 - rmse: 0.4160 - val_loss: 0.2415 - val_mean_absolute_error: 0.3463 - val_mean_squared_error: 0.2332 - val_rmse: 0.4285
# Epoch 37/100
#  - 82s - loss: 0.2010 - mean_absolute_error: 0.3156 - mean_squared_error: 0.1926 - rmse: 0.4161 - val_loss: 0.2599 - val_mean_absolute_error: 0.3659 - val_mean_squared_error: 0.2515 - val_rmse: 0.4459
# Epoch 38/100
#  - 78s - loss: 0.2010 - mean_absolute_error: 0.3152 - mean_squared_error: 0.1926 - rmse: 0.4159 - val_loss: 0.2465 - val_mean_absolute_error: 0.3543 - val_mean_squared_error: 0.2381 - val_rmse: 0.4344
# Epoch 39/100
#  - 77s - loss: 0.2009 - mean_absolute_error: 0.3151 - mean_squared_error: 0.1925 - rmse: 0.4158 - val_loss: 0.2646 - val_mean_absolute_error: 0.3580 - val_mean_squared_error: 0.2562 - val_rmse: 0.4391
# Epoch 40/100
#  - 83s - loss: 0.2009 - mean_absolute_error: 0.3153 - mean_squared_error: 0.1925 - rmse: 0.4159 - val_loss: 0.2505 - val_mean_absolute_error: 0.3532 - val_mean_squared_error: 0.2420 - val_rmse: 0.4344
# Epoch 41/100
#  - 78s - loss: 0.2007 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1922 - rmse: 0.4157 - val_loss: 0.2616 - val_mean_absolute_error: 0.3679 - val_mean_squared_error: 0.2532 - val_rmse: 0.4508
# Epoch 42/100
#  - 76s - loss: 0.2010 - mean_absolute_error: 0.3153 - mean_squared_error: 0.1926 - rmse: 0.4158 - val_loss: 0.2495 - val_mean_absolute_error: 0.3487 - val_mean_squared_error: 0.2411 - val_rmse: 0.4302
# Epoch 43/100
#  - 84s - loss: 0.2008 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1923 - rmse: 0.4158 - val_loss: 0.2479 - val_mean_absolute_error: 0.3473 - val_mean_squared_error: 0.2395 - val_rmse: 0.4285
# Epoch 44/100
#  - 79s - loss: 0.2008 - mean_absolute_error: 0.3151 - mean_squared_error: 0.1924 - rmse: 0.4158 - val_loss: 0.2448 - val_mean_absolute_error: 0.3518 - val_mean_squared_error: 0.2364 - val_rmse: 0.4349
# Epoch 45/100
#  - 78s - loss: 0.2008 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1923 - rmse: 0.4155 - val_loss: 0.2557 - val_mean_absolute_error: 0.3595 - val_mean_squared_error: 0.2472 - val_rmse: 0.4401
# Epoch 46/100
#  - 81s - loss: 0.2008 - mean_absolute_error: 0.3152 - mean_squared_error: 0.1923 - rmse: 0.4157 - val_loss: 0.2437 - val_mean_absolute_error: 0.3460 - val_mean_squared_error: 0.2352 - val_rmse: 0.4282
# Epoch 47/100
#  - 77s - loss: 0.2008 - mean_absolute_error: 0.3151 - mean_squared_error: 0.1923 - rmse: 0.4156 - val_loss: 0.2516 - val_mean_absolute_error: 0.3544 - val_mean_squared_error: 0.2431 - val_rmse: 0.4377
# Epoch 48/100
#  - 81s - loss: 0.2006 - mean_absolute_error: 0.3148 - mean_squared_error: 0.1921 - rmse: 0.4152 - val_loss: 0.2411 - val_mean_absolute_error: 0.3434 - val_mean_squared_error: 0.2326 - val_rmse: 0.4263
# Epoch 49/100
#  - 84s - loss: 0.2007 - mean_absolute_error: 0.3148 - mean_squared_error: 0.1923 - rmse: 0.4154 - val_loss: 0.2469 - val_mean_absolute_error: 0.3478 - val_mean_squared_error: 0.2385 - val_rmse: 0.4294
# Epoch 50/100
#  - 80s - loss: 0.2007 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1923 - rmse: 0.4156 - val_loss: 0.2491 - val_mean_absolute_error: 0.3486 - val_mean_squared_error: 0.2406 - val_rmse: 0.4309
# Epoch 51/100
#  - 76s - loss: 0.2008 - mean_absolute_error: 0.3150 - mean_squared_error: 0.1923 - rmse: 0.4155 - val_loss: 0.2511 - val_mean_absolute_error: 0.3590 - val_mean_squared_error: 0.2426 - val_rmse: 0.4408
# Epoch 52/100
#  - 87s - loss: 0.2008 - mean_absolute_error: 0.3149 - mean_squared_error: 0.1923 - rmse: 0.4157 - val_loss: 0.2581 - val_mean_absolute_error: 0.3619 - val_mean_squared_error: 0.2496 - val_rmse: 0.4438
# Epoch 53/100
#  - 80s - loss: 0.2008 - mean_absolute_error: 0.3148 - mean_squared_error: 0.1923 - rmse: 0.4155 - val_loss: 0.2512 - val_mean_absolute_error: 0.3537 - val_mean_squared_error: 0.2427 - val_rmse: 0.4344
# Epoch 54/100
#  - 77s - loss: 0.2006 - mean_absolute_error: 0.3148 - mean_squared_error: 0.1921 - rmse: 0.4154 - val_loss: 0.2527 - val_mean_absolute_error: 0.3550 - val_mean_squared_error: 0.2442 - val_rmse: 0.4352
# Epoch 55/100
#  - 85s - loss: 0.2005 - mean_absolute_error: 0.3146 - mean_squared_error: 0.1920 - rmse: 0.4151 - val_loss: 0.2557 - val_mean_absolute_error: 0.3522 - val_mean_squared_error: 0.2472 - val_rmse: 0.4350
# Epoch 56/100
#  - 80s - loss: 0.2006 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1921 - rmse: 0.4154 - val_loss: 0.2690 - val_mean_absolute_error: 0.3667 - val_mean_squared_error: 0.2604 - val_rmse: 0.4476
# Epoch 57/100
#  - 76s - loss: 0.2006 - mean_absolute_error: 0.3149 - mean_squared_error: 0.1920 - rmse: 0.4153 - val_loss: 0.2465 - val_mean_absolute_error: 0.3522 - val_mean_squared_error: 0.2379 - val_rmse: 0.4357
# Epoch 58/100
#  - 84s - loss: 0.2007 - mean_absolute_error: 0.3148 - mean_squared_error: 0.1921 - rmse: 0.4154 - val_loss: 0.2478 - val_mean_absolute_error: 0.3507 - val_mean_squared_error: 0.2392 - val_rmse: 0.4292
# Epoch 59/100
#  - 84s - loss: 0.2004 - mean_absolute_error: 0.3146 - mean_squared_error: 0.1918 - rmse: 0.4150 - val_loss: 0.2641 - val_mean_absolute_error: 0.3619 - val_mean_squared_error: 0.2555 - val_rmse: 0.4456
# Epoch 60/100
#  - 79s - loss: 0.2005 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1919 - rmse: 0.4153 - val_loss: 0.2789 - val_mean_absolute_error: 0.3729 - val_mean_squared_error: 0.2703 - val_rmse: 0.4522
# Epoch 61/100
#  - 84s - loss: 0.2003 - mean_absolute_error: 0.3145 - mean_squared_error: 0.1917 - rmse: 0.4151 - val_loss: 0.2618 - val_mean_absolute_error: 0.3681 - val_mean_squared_error: 0.2532 - val_rmse: 0.4511
# Epoch 62/100
#  - 82s - loss: 0.2004 - mean_absolute_error: 0.3147 - mean_squared_error: 0.1918 - rmse: 0.4152 - val_loss: 0.2565 - val_mean_absolute_error: 0.3532 - val_mean_squared_error: 0.2479 - val_rmse: 0.4364
# Epoch 63/100
#  - 76s - loss: 0.2003 - mean_absolute_error: 0.3145 - mean_squared_error: 0.1917 - rmse: 0.4149 - val_loss: 0.2543 - val_mean_absolute_error: 0.3515 - val_mean_squared_error: 0.2456 - val_rmse: 0.4342
# Test loss: 0.25431717721594715
# val_mean_absolute_error: 0.35150348393955455
# score
# [0.25431717721594715, 0.35150348393955455, 0.24564725303426896, 0.45255046779810737]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
