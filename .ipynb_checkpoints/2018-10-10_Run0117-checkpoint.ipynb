# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0104 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
#
# -  This series contains Run0115 - Run0125
#
#
# Settings:
# -  theta = 0.2

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-10_Run0116.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-10_Run0116
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.2)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 83s - loss: 0.2488 - mean_absolute_error: 0.3543 - mean_squared_error: 0.2437 - rmse: 0.4643 - val_loss: 0.2825 - val_mean_absolute_error: 0.3921 - val_mean_squared_error: 0.2762 - val_rmse: 0.4753
# Epoch 2/100
#  - 82s - loss: 0.2027 - mean_absolute_error: 0.3198 - mean_squared_error: 0.1961 - rmse: 0.4205 - val_loss: 0.2975 - val_mean_absolute_error: 0.3965 - val_mean_squared_error: 0.2905 - val_rmse: 0.4791
# Epoch 3/100
#  - 78s - loss: 0.1987 - mean_absolute_error: 0.3155 - mean_squared_error: 0.1915 - rmse: 0.4153 - val_loss: 0.2615 - val_mean_absolute_error: 0.3626 - val_mean_squared_error: 0.2540 - val_rmse: 0.4449
# Epoch 4/100
#  - 80s - loss: 0.1966 - mean_absolute_error: 0.3134 - mean_squared_error: 0.1889 - rmse: 0.4123 - val_loss: 0.2639 - val_mean_absolute_error: 0.3632 - val_mean_squared_error: 0.2561 - val_rmse: 0.4461
# Epoch 5/100
#  - 87s - loss: 0.1955 - mean_absolute_error: 0.3123 - mean_squared_error: 0.1876 - rmse: 0.4108 - val_loss: 0.2680 - val_mean_absolute_error: 0.3684 - val_mean_squared_error: 0.2600 - val_rmse: 0.4521
# Epoch 6/100
#  - 74s - loss: 0.1948 - mean_absolute_error: 0.3112 - mean_squared_error: 0.1867 - rmse: 0.4098 - val_loss: 0.2678 - val_mean_absolute_error: 0.3712 - val_mean_squared_error: 0.2596 - val_rmse: 0.4541
# Epoch 7/100
#  - 90s - loss: 0.1941 - mean_absolute_error: 0.3107 - mean_squared_error: 0.1859 - rmse: 0.4088 - val_loss: 0.2758 - val_mean_absolute_error: 0.3745 - val_mean_squared_error: 0.2676 - val_rmse: 0.4568
# Epoch 8/100
#  - 95s - loss: 0.1936 - mean_absolute_error: 0.3102 - mean_squared_error: 0.1853 - rmse: 0.4083 - val_loss: 0.3041 - val_mean_absolute_error: 0.4041 - val_mean_squared_error: 0.2958 - val_rmse: 0.4835
# Epoch 9/100
#  - 82s - loss: 0.1934 - mean_absolute_error: 0.3097 - mean_squared_error: 0.1851 - rmse: 0.4078 - val_loss: 0.2671 - val_mean_absolute_error: 0.3679 - val_mean_squared_error: 0.2588 - val_rmse: 0.4489
# Epoch 10/100
#  - 77s - loss: 0.1932 - mean_absolute_error: 0.3096 - mean_squared_error: 0.1848 - rmse: 0.4075 - val_loss: 0.2648 - val_mean_absolute_error: 0.3659 - val_mean_squared_error: 0.2564 - val_rmse: 0.4476
# Epoch 11/100
#  - 83s - loss: 0.1926 - mean_absolute_error: 0.3090 - mean_squared_error: 0.1842 - rmse: 0.4069 - val_loss: 0.2744 - val_mean_absolute_error: 0.3677 - val_mean_squared_error: 0.2660 - val_rmse: 0.4501
# Epoch 12/100
#  - 82s - loss: 0.1924 - mean_absolute_error: 0.3087 - mean_squared_error: 0.1840 - rmse: 0.4067 - val_loss: 0.2586 - val_mean_absolute_error: 0.3613 - val_mean_squared_error: 0.2501 - val_rmse: 0.4402
# Epoch 13/100
#  - 76s - loss: 0.1922 - mean_absolute_error: 0.3085 - mean_squared_error: 0.1837 - rmse: 0.4064 - val_loss: 0.2708 - val_mean_absolute_error: 0.3668 - val_mean_squared_error: 0.2623 - val_rmse: 0.4485
# Epoch 14/100
#  - 84s - loss: 0.1922 - mean_absolute_error: 0.3085 - mean_squared_error: 0.1836 - rmse: 0.4064 - val_loss: 0.2569 - val_mean_absolute_error: 0.3603 - val_mean_squared_error: 0.2483 - val_rmse: 0.4386
# Epoch 15/100
#  - 81s - loss: 0.1918 - mean_absolute_error: 0.3081 - mean_squared_error: 0.1832 - rmse: 0.4058 - val_loss: 0.2636 - val_mean_absolute_error: 0.3641 - val_mean_squared_error: 0.2551 - val_rmse: 0.4451
# Epoch 16/100
#  - 77s - loss: 0.1918 - mean_absolute_error: 0.3080 - mean_squared_error: 0.1832 - rmse: 0.4060 - val_loss: 0.2630 - val_mean_absolute_error: 0.3691 - val_mean_squared_error: 0.2545 - val_rmse: 0.4510
# Epoch 17/100
#  - 86s - loss: 0.1913 - mean_absolute_error: 0.3076 - mean_squared_error: 0.1827 - rmse: 0.4051 - val_loss: 0.2577 - val_mean_absolute_error: 0.3616 - val_mean_squared_error: 0.2492 - val_rmse: 0.4425
# Epoch 18/100
#  - 88s - loss: 0.1912 - mean_absolute_error: 0.3075 - mean_squared_error: 0.1826 - rmse: 0.4051 - val_loss: 0.2699 - val_mean_absolute_error: 0.3674 - val_mean_squared_error: 0.2614 - val_rmse: 0.4497
# Epoch 19/100
#  - 77s - loss: 0.1909 - mean_absolute_error: 0.3073 - mean_squared_error: 0.1824 - rmse: 0.4050 - val_loss: 0.2681 - val_mean_absolute_error: 0.3759 - val_mean_squared_error: 0.2595 - val_rmse: 0.4541
# Epoch 20/100
#  - 82s - loss: 0.1909 - mean_absolute_error: 0.3071 - mean_squared_error: 0.1823 - rmse: 0.4048 - val_loss: 0.2550 - val_mean_absolute_error: 0.3606 - val_mean_squared_error: 0.2464 - val_rmse: 0.4414
# Epoch 21/100
#  - 84s - loss: 0.1906 - mean_absolute_error: 0.3070 - mean_squared_error: 0.1820 - rmse: 0.4045 - val_loss: 0.2497 - val_mean_absolute_error: 0.3539 - val_mean_squared_error: 0.2412 - val_rmse: 0.4340
# Epoch 22/100
#  - 76s - loss: 0.1904 - mean_absolute_error: 0.3068 - mean_squared_error: 0.1818 - rmse: 0.4042 - val_loss: 0.3018 - val_mean_absolute_error: 0.4019 - val_mean_squared_error: 0.2932 - val_rmse: 0.4808
# Epoch 23/100
#  - 78s - loss: 0.1903 - mean_absolute_error: 0.3069 - mean_squared_error: 0.1817 - rmse: 0.4042 - val_loss: 0.2677 - val_mean_absolute_error: 0.3742 - val_mean_squared_error: 0.2591 - val_rmse: 0.4579
# Epoch 24/100
#  - 83s - loss: 0.1903 - mean_absolute_error: 0.3067 - mean_squared_error: 0.1817 - rmse: 0.4042 - val_loss: 0.2563 - val_mean_absolute_error: 0.3571 - val_mean_squared_error: 0.2476 - val_rmse: 0.4413
# Epoch 25/100
#  - 79s - loss: 0.1903 - mean_absolute_error: 0.3067 - mean_squared_error: 0.1816 - rmse: 0.4040 - val_loss: 0.2652 - val_mean_absolute_error: 0.3665 - val_mean_squared_error: 0.2565 - val_rmse: 0.4466
# Epoch 26/100
#  - 79s - loss: 0.1900 - mean_absolute_error: 0.3064 - mean_squared_error: 0.1813 - rmse: 0.4036 - val_loss: 0.2589 - val_mean_absolute_error: 0.3620 - val_mean_squared_error: 0.2502 - val_rmse: 0.4421
# Epoch 27/100
#  - 83s - loss: 0.1899 - mean_absolute_error: 0.3062 - mean_squared_error: 0.1812 - rmse: 0.4036 - val_loss: 0.2404 - val_mean_absolute_error: 0.3461 - val_mean_squared_error: 0.2316 - val_rmse: 0.4273
# Epoch 28/100
#  - 76s - loss: 0.1900 - mean_absolute_error: 0.3063 - mean_squared_error: 0.1813 - rmse: 0.4036 - val_loss: 0.2446 - val_mean_absolute_error: 0.3440 - val_mean_squared_error: 0.2359 - val_rmse: 0.4262
# Epoch 29/100
#  - 77s - loss: 0.1898 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1811 - rmse: 0.4032 - val_loss: 0.2490 - val_mean_absolute_error: 0.3471 - val_mean_squared_error: 0.2403 - val_rmse: 0.4292
# Epoch 30/100
#  - 82s - loss: 0.1897 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1810 - rmse: 0.4032 - val_loss: 0.2652 - val_mean_absolute_error: 0.3666 - val_mean_squared_error: 0.2565 - val_rmse: 0.4505
# Epoch 31/100
#  - 75s - loss: 0.1897 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1809 - rmse: 0.4031 - val_loss: 0.2540 - val_mean_absolute_error: 0.3580 - val_mean_squared_error: 0.2453 - val_rmse: 0.4408
# Epoch 32/100
#  - 79s - loss: 0.1897 - mean_absolute_error: 0.3061 - mean_squared_error: 0.1810 - rmse: 0.4032 - val_loss: 0.2532 - val_mean_absolute_error: 0.3556 - val_mean_squared_error: 0.2444 - val_rmse: 0.4389
# Epoch 33/100
#  - 82s - loss: 0.1895 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1808 - rmse: 0.4030 - val_loss: 0.2502 - val_mean_absolute_error: 0.3532 - val_mean_squared_error: 0.2414 - val_rmse: 0.4373
# Epoch 34/100
#  - 76s - loss: 0.1895 - mean_absolute_error: 0.3060 - mean_squared_error: 0.1807 - rmse: 0.4030 - val_loss: 0.2454 - val_mean_absolute_error: 0.3484 - val_mean_squared_error: 0.2366 - val_rmse: 0.4286
# Epoch 35/100
#  - 83s - loss: 0.1895 - mean_absolute_error: 0.3058 - mean_squared_error: 0.1807 - rmse: 0.4029 - val_loss: 0.2459 - val_mean_absolute_error: 0.3460 - val_mean_squared_error: 0.2372 - val_rmse: 0.4277
# Epoch 36/100
#  - 83s - loss: 0.1894 - mean_absolute_error: 0.3058 - mean_squared_error: 0.1806 - rmse: 0.4029 - val_loss: 0.2620 - val_mean_absolute_error: 0.3615 - val_mean_squared_error: 0.2532 - val_rmse: 0.4453
# Epoch 37/100
#  - 77s - loss: 0.1894 - mean_absolute_error: 0.3056 - mean_squared_error: 0.1806 - rmse: 0.4029 - val_loss: 0.2589 - val_mean_absolute_error: 0.3594 - val_mean_squared_error: 0.2501 - val_rmse: 0.4404
# Epoch 38/100
#  - 82s - loss: 0.1896 - mean_absolute_error: 0.3059 - mean_squared_error: 0.1808 - rmse: 0.4030 - val_loss: 0.2557 - val_mean_absolute_error: 0.3594 - val_mean_squared_error: 0.2469 - val_rmse: 0.4426
# Epoch 39/100
#  - 82s - loss: 0.1894 - mean_absolute_error: 0.3056 - mean_squared_error: 0.1805 - rmse: 0.4028 - val_loss: 0.2710 - val_mean_absolute_error: 0.3719 - val_mean_squared_error: 0.2622 - val_rmse: 0.4529
# Epoch 40/100
#  - 76s - loss: 0.1894 - mean_absolute_error: 0.3057 - mean_squared_error: 0.1806 - rmse: 0.4028 - val_loss: 0.2654 - val_mean_absolute_error: 0.3641 - val_mean_squared_error: 0.2566 - val_rmse: 0.4457
# Epoch 41/100
#  - 81s - loss: 0.1893 - mean_absolute_error: 0.3056 - mean_squared_error: 0.1804 - rmse: 0.4027 - val_loss: 0.2647 - val_mean_absolute_error: 0.3642 - val_mean_squared_error: 0.2558 - val_rmse: 0.4448
# Epoch 42/100
#  - 79s - loss: 0.1894 - mean_absolute_error: 0.3056 - mean_squared_error: 0.1805 - rmse: 0.4028 - val_loss: 0.2510 - val_mean_absolute_error: 0.3535 - val_mean_squared_error: 0.2421 - val_rmse: 0.4367
# Epoch 43/100
#  - 77s - loss: 0.1894 - mean_absolute_error: 0.3055 - mean_squared_error: 0.1805 - rmse: 0.4030 - val_loss: 0.2481 - val_mean_absolute_error: 0.3555 - val_mean_squared_error: 0.2393 - val_rmse: 0.4362
# Test loss: 0.24814870405694617
# val_mean_absolute_error: 0.35549900262259926
# score
# [0.24814870405694617, 0.35549900262259926, 0.2392702213166483, 0.4538715727437438]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
