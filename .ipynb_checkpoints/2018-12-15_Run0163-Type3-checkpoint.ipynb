# %% [markdown]
# # Run Objective:

# %% [markdown]
# ### Run0163-SERIES
#
#
# -  This is: `Run0163-Type3`
# -  Basic network architecture/functionality design is complete (`Run0160` Pattern).
# -  Current objectice: Hyper-parameter scanning (`Run0163-SERIES` aims see if merging the hidden layers of the separate neural network sub-modules does anything of note).
#
# Type 1 - Zero shared hidden layers
#
# Type 2 - One shared hidden layer
#
# Type 3 - Two shared hidden layers
# ![image.png](attachment:image.png)

# %% [markdown]
# -  Based on `Run0161f`.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-12-15_Run0163-Type3.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-12-15_Run0163-Type3
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal, Constant
from keras.utils import plot_model
from keras.models import Model
from keras.layers.core import Lambda
from keras.layers import Input
from keras.layers import Dense
from keras.layers import MaxoutDense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
#from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

#keras.backend.clear_session()
K.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
epochs = 100
L2_regularization = 5E-7

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -1.409146e-16  2.632122e-16  2.265222e-16  8.719839e-17 -1.763625e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.639065e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00
# 25%   -7.928000e-01 -7.898708e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01
# 50%   -1.059360e-01 -9.507533e-02  1.347799e-01 -3.983652e-01 -1.936629e-01
# 75%    5.809279e-01  5.997202e-01  6.437252e-01  1.976217e-01  9.108525e-01
# max    2.641520e+00  2.684107e+00  1.831264e+00  2.581570e+00  1.739239e+00
#
#                   x         Ti_Te
# count  6.479137e+06  6.479137e+06
# mean  -8.619768e-19  5.197303e-17
# std    1.000000e+00  1.000000e+00
# min   -1.405340e+00 -1.235044e+00
# 25%   -9.907529e-01 -8.817246e-01
# 50%   -1.615792e-01 -1.750863e-01
# 75%    6.675945e-01  7.576761e-01
# max    1.704062e+00  1.944828e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -1.409146e-16  2.265222e-16  8.719839e-17 -1.763625e-17 -8.619768e-19
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00 -1.405340e+00
# 25%   -7.928000e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01 -9.907529e-01
# 50%   -1.059360e-01  1.347799e-01 -3.983652e-01 -1.936629e-01 -1.615792e-01
# 75%    5.809279e-01  6.437252e-01  1.976217e-01  9.108525e-01  6.675945e-01
# max    2.641520e+00  1.831264e+00  2.581570e+00  1.739239e+00  1.704062e+00
#
#               Ti_Te
# count  6.479137e+06
# mean   5.197303e-17
# std    1.000000e+00
# min   -1.235044e+00
# 25%   -8.817246e-01
# 50%   -1.750863e-01
# 75%    7.576761e-01
# max    1.944828e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (6479137, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.479137e+06
# mean   2.632122e-16
# std    1.000000e+00
# min   -1.639065e+00
# 25%   -7.898708e-01
# 50%   -9.507533e-02
# 75%    5.997202e-01
# max    2.684107e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (6479137, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6, ), name="6D_INPUTS")
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden1_branch1")(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="hidden2_branch1")(hidden1_branch1)
theta_branch1 = Dense(1,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        name="theta_branch1")(hidden2_branch1)
theta_branch1_feeder = Dense(1,
        activation='linear',
        kernel_initializer=Constant(value=-1),
        bias_initializer='Zeros',
        trainable=False,
        name="theta_branch1_feeder")(theta_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1, ), name="Ate_INPUT")

# Addition_Operator (effectively subtraction though...)
addition_operator = keras.layers.Add(name="Addition_Operator")([theta_branch1_feeder, visible_branch2])

# ReLU Layer
TR = Dense(1, activation='relu',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=False,
           name="TR")(addition_operator)

# branch 3 (for c_3)
#hidden1_branch3 = Dense(30,
#        activation='tanh',
#        kernel_initializer='glorot_normal',
#        kernel_regularizer=regularizers.l2(L2_regularization),
#        use_bias=True, bias_initializer='glorot_normal',
#        name="hidden1_branch3")(visible_branch1)
#hidden2_branch3 = Dense(30,
#        activation='tanh',
#        kernel_initializer='glorot_normal',
#        kernel_regularizer=regularizers.l2(L2_regularization),
#        use_bias=True, bias_initializer='glorot_normal',
#        name="hidden2_branch3")(hidden1_branch1)
c_3_branch3 = Dense(1,
        activation='linear',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        trainable=True,
        name="c_3_branch3")(hidden2_branch1)

# Power_Operator    
power_layer = Lambda(lambda x: (K.clip(K.abs(x[0]), 0.00001, 1000)) ** (K.clip(x[1], -2., 4.)), name="Power_Operator")
power_operator = power_layer([addition_operator, c_3_branch3])

# branch 4 (for the gradient)
#hidden1_branch4 = Dense(30,
#        activation='tanh',
#        kernel_initializer='glorot_normal',
#        kernel_regularizer=regularizers.l2(L2_regularization),
#        use_bias=True, bias_initializer='glorot_normal',
#        name="hidden1_branch4")(visible_branch1)
#hidden2_branch4 = Dense(30,
#        activation='tanh',
#        kernel_initializer='glorot_normal',
#        kernel_regularizer=regularizers.l2(L2_regularization),
#        use_bias=True, bias_initializer='glorot_normal',
#        name="hidden2_branch4")(hidden1_branch1)
m_branch4 = Dense(1,
        activation='linear',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(L2_regularization),
        use_bias=True, bias_initializer='glorot_normal',
        trainable=True,
        name="m_branch4")(hidden2_branch1)   

# Multiplication_Operator_1
multiplication_operator_1 = keras.layers.Multiply(name="Multiplication_Operator_1")([TR, power_operator])

# Multiplication_Operator_2
multiplication_operator_2 = keras.layers.Multiply(name="Multiplication_Operator_2")([m_branch4, multiplication_operator_1])

# Output_Layer
output = Dense(1, activation='linear',
           kernel_initializer='Ones',
           kernel_regularizer=regularizers.l2(L2_regularization),
           bias_initializer='Zeros',
           trainable=True,
           name="Output_Layer")(multiplication_operator_2)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# 6D_INPUTS (InputLayer)          (None, 6)            0
# __________________________________________________________________________________________________
# hidden1_branch1 (Dense)         (None, 30)           210         6D_INPUTS[0][0]
# __________________________________________________________________________________________________
# hidden2_branch1 (Dense)         (None, 30)           930         hidden1_branch1[0][0]
# __________________________________________________________________________________________________
# theta_branch1 (Dense)           (None, 1)            31          hidden2_branch1[0][0]
# __________________________________________________________________________________________________
# theta_branch1_feeder (Dense)    (None, 1)            2           theta_branch1[0][0]
# __________________________________________________________________________________________________
# Ate_INPUT (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# Addition_Operator (Add)         (None, 1)            0           theta_branch1_feeder[0][0]
#                                                                  Ate_INPUT[0][0]
# __________________________________________________________________________________________________
# c_3_branch3 (Dense)             (None, 1)            31          hidden2_branch1[0][0]
# __________________________________________________________________________________________________
# TR (Dense)                      (None, 1)            2           Addition_Operator[0][0]
# __________________________________________________________________________________________________
# Power_Operator (Lambda)         (None, 1)            0           Addition_Operator[0][0]
#                                                                  c_3_branch3[0][0]
# __________________________________________________________________________________________________
# m_branch4 (Dense)               (None, 1)            31          hidden2_branch1[0][0]
# __________________________________________________________________________________________________
# Multiplication_Operator_1 (Mult (None, 1)            0           TR[0][0]
#                                                                  Power_Operator[0][0]
# __________________________________________________________________________________________________
# Multiplication_Operator_2 (Mult (None, 1)            0           m_branch4[0][0]
#                                                                  Multiplication_Operator_1[0][0]
# __________________________________________________________________________________________________
# Output_Layer (Dense)            (None, 1)            2           Multiplication_Operator_2[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,235
# Non-trainable params: 4
# __________________________________________________________________________________________________
# None

# %%
# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    #callbacks=[tbCallBack, EarlyStoppingCallBack, NBatchLogger(5e4)])
                    callbacks=[tbCallBack, EarlyStoppingCallBack])
#5e4

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 5831223 samples, validate on 647914 samples
# Epoch 1/100
#  - 460s - loss: 0.1042 - mean_absolute_error: 0.0935 - mean_squared_error: 0.1040 - rmse: 0.2174 - val_loss: 0.0748 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0746 - val_rmse: 0.1812
# Epoch 2/100
#  - 461s - loss: 0.0774 - mean_absolute_error: 0.0802 - mean_squared_error: 0.0771 - rmse: 0.1861 - val_loss: 0.0705 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0702 - val_rmse: 0.1775
# Epoch 3/100
#  - 462s - loss: 0.0734 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0730 - rmse: 0.1798 - val_loss: 0.0667 - val_mean_absolute_error: 0.0702 - val_mean_squared_error: 0.0663 - val_rmse: 0.1707
# Epoch 4/100
#  - 462s - loss: 0.0715 - mean_absolute_error: 0.0761 - mean_squared_error: 0.0711 - rmse: 0.1769 - val_loss: 0.0767 - val_mean_absolute_error: 0.0743 - val_mean_squared_error: 0.0763 - val_rmse: 0.1811
# Epoch 5/100
#  - 461s - loss: 0.0704 - mean_absolute_error: 0.0747 - mean_squared_error: 0.0699 - rmse: 0.1746 - val_loss: 0.0637 - val_mean_absolute_error: 0.0712 - val_mean_squared_error: 0.0633 - val_rmse: 0.1672
# Epoch 6/100
#  - 462s - loss: 0.0700 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0696 - rmse: 0.1735 - val_loss: 0.0644 - val_mean_absolute_error: 0.0698 - val_mean_squared_error: 0.0639 - val_rmse: 0.1677
# Epoch 7/100
#  - 460s - loss: 0.0690 - mean_absolute_error: 0.0727 - mean_squared_error: 0.0685 - rmse: 0.1715 - val_loss: 0.0596 - val_mean_absolute_error: 0.0696 - val_mean_squared_error: 0.0591 - val_rmse: 0.1600
# Epoch 8/100
#  - 462s - loss: 0.0685 - mean_absolute_error: 0.0723 - mean_squared_error: 0.0679 - rmse: 0.1707 - val_loss: 0.0643 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0638 - val_rmse: 0.1616
# Epoch 9/100
#  - 460s - loss: 0.0680 - mean_absolute_error: 0.0719 - mean_squared_error: 0.0674 - rmse: 0.1699 - val_loss: 0.0629 - val_mean_absolute_error: 0.0711 - val_mean_squared_error: 0.0623 - val_rmse: 0.1640
# Epoch 10/100
#  - 462s - loss: 0.0676 - mean_absolute_error: 0.0715 - mean_squared_error: 0.0670 - rmse: 0.1691 - val_loss: 0.0610 - val_mean_absolute_error: 0.0723 - val_mean_squared_error: 0.0604 - val_rmse: 0.1621
# Epoch 11/100
#  - 461s - loss: 0.0675 - mean_absolute_error: 0.0712 - mean_squared_error: 0.0669 - rmse: 0.1686 - val_loss: 0.0632 - val_mean_absolute_error: 0.0709 - val_mean_squared_error: 0.0626 - val_rmse: 0.1644
# Epoch 12/100
#  - 461s - loss: 0.0673 - mean_absolute_error: 0.0711 - mean_squared_error: 0.0667 - rmse: 0.1684 - val_loss: 0.0616 - val_mean_absolute_error: 0.0725 - val_mean_squared_error: 0.0610 - val_rmse: 0.1619
# Epoch 13/100
#  - 461s - loss: 0.0669 - mean_absolute_error: 0.0705 - mean_squared_error: 0.0662 - rmse: 0.1676 - val_loss: 0.0740 - val_mean_absolute_error: 0.0720 - val_mean_squared_error: 0.0734 - val_rmse: 0.1742
# Epoch 14/100
#  - 462s - loss: 0.0672 - mean_absolute_error: 0.0703 - mean_squared_error: 0.0666 - rmse: 0.1675 - val_loss: 0.0681 - val_mean_absolute_error: 0.0694 - val_mean_squared_error: 0.0674 - val_rmse: 0.1684
# Epoch 15/100
#  - 461s - loss: 0.0673 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0666 - rmse: 0.1671 - val_loss: 0.0608 - val_mean_absolute_error: 0.0639 - val_mean_squared_error: 0.0602 - val_rmse: 0.1562
# Epoch 16/100
#  - 461s - loss: 0.0671 - mean_absolute_error: 0.0686 - mean_squared_error: 0.0664 - rmse: 0.1663 - val_loss: 0.0719 - val_mean_absolute_error: 0.0729 - val_mean_squared_error: 0.0712 - val_rmse: 0.1698
# Epoch 17/100
#  - 461s - loss: 0.0668 - mean_absolute_error: 0.0682 - mean_squared_error: 0.0661 - rmse: 0.1657 - val_loss: 0.0682 - val_mean_absolute_error: 0.0676 - val_mean_squared_error: 0.0675 - val_rmse: 0.1686
# Epoch 18/100
#  - 463s - loss: 0.0669 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0661 - rmse: 0.1658 - val_loss: 0.0655 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0648 - val_rmse: 0.1576
# Epoch 19/100
#  - 461s - loss: 0.0664 - mean_absolute_error: 0.0680 - mean_squared_error: 0.0656 - rmse: 0.1652 - val_loss: 0.0707 - val_mean_absolute_error: 0.0690 - val_mean_squared_error: 0.0700 - val_rmse: 0.1714
# Epoch 20/100
#  - 461s - loss: 0.0664 - mean_absolute_error: 0.0680 - mean_squared_error: 0.0656 - rmse: 0.1651 - val_loss: 0.0641 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0633 - val_rmse: 0.1602
# Epoch 22/100
#  - 462s - loss: 0.0659 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0651 - rmse: 0.1644 - val_loss: 0.0642 - val_mean_absolute_error: 0.0687 - val_mean_squared_error: 0.0634 - val_rmse: 0.1617
# Epoch 23/100
#  - 459s - loss: 0.0660 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0652 - rmse: 0.1643 - val_loss: 0.0590 - val_mean_absolute_error: 0.0607 - val_mean_squared_error: 0.0581 - val_rmse: 0.1535
# Epoch 24/100
#  - 461s - loss: 0.0659 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0651 - rmse: 0.1645 - val_loss: 0.0685 - val_mean_absolute_error: 0.0674 - val_mean_squared_error: 0.0677 - val_rmse: 0.1654
# Epoch 25/100
#  - 460s - loss: 0.0661 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0652 - rmse: 0.1644 - val_loss: 0.0621 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0613 - val_rmse: 0.1582
# Epoch 26/100
#  - 461s - loss: 0.0658 - mean_absolute_error: 0.0675 - mean_squared_error: 0.0649 - rmse: 0.1641 - val_loss: 0.0785 - val_mean_absolute_error: 0.0774 - val_mean_squared_error: 0.0776 - val_rmse: 0.1820
# Epoch 27/100
#  - 460s - loss: 0.0661 - mean_absolute_error: 0.0677 - mean_squared_error: 0.0652 - rmse: 0.1645 - val_loss: 0.0683 - val_mean_absolute_error: 0.0656 - val_mean_squared_error: 0.0674 - val_rmse: 0.1647
# Epoch 28/100
#  - 461s - loss: 0.0659 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0650 - rmse: 0.1641 - val_loss: 0.0585 - val_mean_absolute_error: 0.0627 - val_mean_squared_error: 0.0576 - val_rmse: 0.1548
# Epoch 29/100
#  - 459s - loss: 0.0664 - mean_absolute_error: 0.0681 - mean_squared_error: 0.0655 - rmse: 0.1651 - val_loss: 0.0758 - val_mean_absolute_error: 0.0675 - val_mean_squared_error: 0.0749 - val_rmse: 0.1731
# Epoch 30/100
#  - 460s - loss: 0.0657 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0648 - rmse: 0.1641 - val_loss: 0.0718 - val_mean_absolute_error: 0.0751 - val_mean_squared_error: 0.0709 - val_rmse: 0.1730
# Epoch 31/100
#  - 459s - loss: 0.0656 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0647 - rmse: 0.1640 - val_loss: 0.0791 - val_mean_absolute_error: 0.0798 - val_mean_squared_error: 0.0782 - val_rmse: 0.1807
# Epoch 32/100
#  - 461s - loss: 0.0658 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0648 - rmse: 0.1639 - val_loss: 0.0668 - val_mean_absolute_error: 0.0671 - val_mean_squared_error: 0.0659 - val_rmse: 0.1661
# Epoch 33/100
#  - 460s - loss: 0.0663 - mean_absolute_error: 0.0679 - mean_squared_error: 0.0653 - rmse: 0.1647 - val_loss: 0.0748 - val_mean_absolute_error: 0.0761 - val_mean_squared_error: 0.0738 - val_rmse: 0.1790
# Epoch 34/100
#  - 461s - loss: 0.0668 - mean_absolute_error: 0.0683 - mean_squared_error: 0.0659 - rmse: 0.1652 - val_loss: 0.0621 - val_mean_absolute_error: 0.0669 - val_mean_squared_error: 0.0611 - val_rmse: 0.1548
# Epoch 35/100
#  - 459s - loss: 0.0658 - mean_absolute_error: 0.0675 - mean_squared_error: 0.0648 - rmse: 0.1639 - val_loss: 0.0616 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0607 - val_rmse: 0.1581
# Epoch 36/100
#  - 460s - loss: 0.0658 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0649 - rmse: 0.1637 - val_loss: 0.0598 - val_mean_absolute_error: 0.0644 - val_mean_squared_error: 0.0588 - val_rmse: 0.1555
# Epoch 37/100
#  - 460s - loss: 0.0661 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0651 - rmse: 0.1641 - val_loss: 0.0632 - val_mean_absolute_error: 0.0716 - val_mean_squared_error: 0.0622 - val_rmse: 0.1644
# Epoch 38/100
#  - 460s - loss: 0.0655 - mean_absolute_error: 0.0675 - mean_squared_error: 0.0645 - rmse: 0.1637 - val_loss: 0.0666 - val_mean_absolute_error: 0.0647 - val_mean_squared_error: 0.0656 - val_rmse: 0.1603
# Test loss: 0.06662282924324396
# val_mean_absolute_error: 0.06468734568390497
# score
# [0.06662282924324396, 0.06468734568390497, 0.06560531676125474, 0.20930175867316375]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
