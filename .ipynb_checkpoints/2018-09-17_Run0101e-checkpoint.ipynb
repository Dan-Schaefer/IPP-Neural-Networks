# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Another new fully connected hidden layer added after concatinate.
#
# `hidden1_mergedbranch = Dense(30,
#         activation='tanh',
#         kernel_initializer='glorot_normal',
#         kernel_regularizer=regularizers.l2(0.00005),
#         use_bias=True, bias_initializer='glorot_normal')(merge)`
#
# `hidden2_mergedbranch = Dense(30,
#         activation='tanh',
#         kernel_initializer='glorot_normal',
#         kernel_regularizer=regularizers.l2(0.00005),
#         use_bias=True, bias_initializer='glorot_normal')(hidden1_mergedbranch)`

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-09-16_Run0101d.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-09-16_Run0101d
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
import pandas
import numpy
import sys
import os
from copy import deepcopy

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# Define custon LateFusionActivation function
def custom_activation(LateFusionActivation):
    return TODO

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2
visible_branch2 = Input(shape=(1,))

# merge input models
merge = concatenate([hidden2_branch1, visible_branch2])
hidden1_mergedbranch = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(merge)
hidden2_mergedbranch = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_mergedbranch)

# interpretation model
output = Dense(1, activation='linear')(hidden2_mergedbranch)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           960         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            31          dense_3[0][0]
# ==================================================================================================
# Total params: 2,131
# Trainable params: 2,131
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 77s - loss: 0.1593 - mean_absolute_error: 0.2686 - mean_squared_error: 0.1519 - rmse: 0.3600 - val_loss: 0.1600 - val_mean_absolute_error: 0.2695 - val_mean_squared_error: 0.1509 - val_rmse: 0.3380
# Epoch 2/100
#  - 73s - loss: 0.1120 - mean_absolute_error: 0.2202 - mean_squared_error: 0.1022 - rmse: 0.2997 - val_loss: 0.1646 - val_mean_absolute_error: 0.2692 - val_mean_squared_error: 0.1541 - val_rmse: 0.3351
# Epoch 3/100
#  - 81s - loss: 0.1069 - mean_absolute_error: 0.2122 - mean_squared_error: 0.0961 - rmse: 0.2902 - val_loss: 0.1350 - val_mean_absolute_error: 0.2440 - val_mean_squared_error: 0.1239 - val_rmse: 0.3061
# Epoch 4/100
#  - 83s - loss: 0.1044 - mean_absolute_error: 0.2079 - mean_squared_error: 0.0930 - rmse: 0.2850 - val_loss: 0.1416 - val_mean_absolute_error: 0.2489 - val_mean_squared_error: 0.1300 - val_rmse: 0.3132
# Epoch 5/100
#  - 76s - loss: 0.1029 - mean_absolute_error: 0.2053 - mean_squared_error: 0.0911 - rmse: 0.2820 - val_loss: 0.1338 - val_mean_absolute_error: 0.2391 - val_mean_squared_error: 0.1219 - val_rmse: 0.3057
# Epoch 6/100
#  - 82s - loss: 0.1017 - mean_absolute_error: 0.2033 - mean_squared_error: 0.0897 - rmse: 0.2794 - val_loss: 0.1261 - val_mean_absolute_error: 0.2358 - val_mean_squared_error: 0.1141 - val_rmse: 0.2963
# Epoch 7/100
#  - 83s - loss: 0.1010 - mean_absolute_error: 0.2021 - mean_squared_error: 0.0889 - rmse: 0.2781 - val_loss: 0.1335 - val_mean_absolute_error: 0.2367 - val_mean_squared_error: 0.1213 - val_rmse: 0.2995
# Epoch 8/100
#  - 81s - loss: 0.1003 - mean_absolute_error: 0.2012 - mean_squared_error: 0.0881 - rmse: 0.2768 - val_loss: 0.1227 - val_mean_absolute_error: 0.2297 - val_mean_squared_error: 0.1104 - val_rmse: 0.2916
# Epoch 9/100
#  - 83s - loss: 0.0999 - mean_absolute_error: 0.2004 - mean_squared_error: 0.0875 - rmse: 0.2759 - val_loss: 0.1327 - val_mean_absolute_error: 0.2353 - val_mean_squared_error: 0.1202 - val_rmse: 0.2986
# Epoch 10/100
#  - 85s - loss: 0.0993 - mean_absolute_error: 0.1996 - mean_squared_error: 0.0868 - rmse: 0.2748 - val_loss: 0.1402 - val_mean_absolute_error: 0.2479 - val_mean_squared_error: 0.1276 - val_rmse: 0.3128
# Epoch 11/100
#  - 79s - loss: 0.0991 - mean_absolute_error: 0.1993 - mean_squared_error: 0.0865 - rmse: 0.2743 - val_loss: 0.1369 - val_mean_absolute_error: 0.2457 - val_mean_squared_error: 0.1243 - val_rmse: 0.3089
# Epoch 12/100
#  - 81s - loss: 0.0987 - mean_absolute_error: 0.1987 - mean_squared_error: 0.0862 - rmse: 0.2736 - val_loss: 0.1269 - val_mean_absolute_error: 0.2316 - val_mean_squared_error: 0.1143 - val_rmse: 0.2944
# Epoch 13/100
#  - 86s - loss: 0.0983 - mean_absolute_error: 0.1983 - mean_squared_error: 0.0858 - rmse: 0.2732 - val_loss: 0.1225 - val_mean_absolute_error: 0.2313 - val_mean_squared_error: 0.1099 - val_rmse: 0.2907
# Epoch 14/100
#  - 81s - loss: 0.0980 - mean_absolute_error: 0.1978 - mean_squared_error: 0.0855 - rmse: 0.2727 - val_loss: 0.1486 - val_mean_absolute_error: 0.2504 - val_mean_squared_error: 0.1361 - val_rmse: 0.3131
# Epoch 15/100
#  - 87s - loss: 0.0980 - mean_absolute_error: 0.1977 - mean_squared_error: 0.0854 - rmse: 0.2723 - val_loss: 0.1285 - val_mean_absolute_error: 0.2368 - val_mean_squared_error: 0.1158 - val_rmse: 0.2975
# Epoch 16/100
#  - 84s - loss: 0.0978 - mean_absolute_error: 0.1973 - mean_squared_error: 0.0852 - rmse: 0.2720 - val_loss: 0.1396 - val_mean_absolute_error: 0.2519 - val_mean_squared_error: 0.1270 - val_rmse: 0.3145
# Epoch 17/100
#  - 81s - loss: 0.0977 - mean_absolute_error: 0.1974 - mean_squared_error: 0.0851 - rmse: 0.2719 - val_loss: 0.1357 - val_mean_absolute_error: 0.2448 - val_mean_squared_error: 0.1230 - val_rmse: 0.3050
# Epoch 18/100
#  - 76s - loss: 0.0976 - mean_absolute_error: 0.1971 - mean_squared_error: 0.0850 - rmse: 0.2717 - val_loss: 0.1303 - val_mean_absolute_error: 0.2334 - val_mean_squared_error: 0.1176 - val_rmse: 0.2947
# Epoch 19/100
#  - 83s - loss: 0.0974 - mean_absolute_error: 0.1970 - mean_squared_error: 0.0847 - rmse: 0.2714 - val_loss: 0.1248 - val_mean_absolute_error: 0.2271 - val_mean_squared_error: 0.1120 - val_rmse: 0.2901
# Epoch 20/100
#  - 80s - loss: 0.0975 - mean_absolute_error: 0.1967 - mean_squared_error: 0.0848 - rmse: 0.2713 - val_loss: 0.1282 - val_mean_absolute_error: 0.2336 - val_mean_squared_error: 0.1155 - val_rmse: 0.2949
# Epoch 21/100
#  - 75s - loss: 0.0974 - mean_absolute_error: 0.1967 - mean_squared_error: 0.0847 - rmse: 0.2712 - val_loss: 0.1239 - val_mean_absolute_error: 0.2292 - val_mean_squared_error: 0.1112 - val_rmse: 0.2915
# Epoch 22/100
#  - 82s - loss: 0.0971 - mean_absolute_error: 0.1964 - mean_squared_error: 0.0845 - rmse: 0.2709 - val_loss: 0.1236 - val_mean_absolute_error: 0.2263 - val_mean_squared_error: 0.1109 - val_rmse: 0.2872
# Epoch 23/100
#  - 81s - loss: 0.0972 - mean_absolute_error: 0.1964 - mean_squared_error: 0.0845 - rmse: 0.2709 - val_loss: 0.1386 - val_mean_absolute_error: 0.2407 - val_mean_squared_error: 0.1258 - val_rmse: 0.3056
# Epoch 24/100
#  - 78s - loss: 0.0971 - mean_absolute_error: 0.1960 - mean_squared_error: 0.0843 - rmse: 0.2704 - val_loss: 0.1226 - val_mean_absolute_error: 0.2278 - val_mean_squared_error: 0.1098 - val_rmse: 0.2875
# Epoch 25/100
#  - 81s - loss: 0.0972 - mean_absolute_error: 0.1962 - mean_squared_error: 0.0844 - rmse: 0.2707 - val_loss: 0.1314 - val_mean_absolute_error: 0.2369 - val_mean_squared_error: 0.1186 - val_rmse: 0.2992
# Epoch 26/100
#  - 80s - loss: 0.0970 - mean_absolute_error: 0.1960 - mean_squared_error: 0.0842 - rmse: 0.2704 - val_loss: 0.1461 - val_mean_absolute_error: 0.2552 - val_mean_squared_error: 0.1333 - val_rmse: 0.3174
# Epoch 27/100
#  - 75s - loss: 0.0970 - mean_absolute_error: 0.1958 - mean_squared_error: 0.0841 - rmse: 0.2701 - val_loss: 0.1213 - val_mean_absolute_error: 0.2256 - val_mean_squared_error: 0.1084 - val_rmse: 0.2878
# Epoch 28/100
#  - 81s - loss: 0.0967 - mean_absolute_error: 0.1956 - mean_squared_error: 0.0838 - rmse: 0.2697 - val_loss: 0.1522 - val_mean_absolute_error: 0.2609 - val_mean_squared_error: 0.1393 - val_rmse: 0.3232
# Epoch 29/100
#  - 76s - loss: 0.0968 - mean_absolute_error: 0.1953 - mean_squared_error: 0.0839 - rmse: 0.2699 - val_loss: 0.1328 - val_mean_absolute_error: 0.2347 - val_mean_squared_error: 0.1198 - val_rmse: 0.2985
# Epoch 30/100
#  - 78s - loss: 0.0967 - mean_absolute_error: 0.1955 - mean_squared_error: 0.0837 - rmse: 0.2697 - val_loss: 0.1594 - val_mean_absolute_error: 0.2602 - val_mean_squared_error: 0.1464 - val_rmse: 0.3289
# Epoch 31/100
#  - 81s - loss: 0.0969 - mean_absolute_error: 0.1955 - mean_squared_error: 0.0839 - rmse: 0.2698 - val_loss: 0.1297 - val_mean_absolute_error: 0.2362 - val_mean_squared_error: 0.1167 - val_rmse: 0.2978
# Epoch 32/100
#  - 75s - loss: 0.0966 - mean_absolute_error: 0.1952 - mean_squared_error: 0.0837 - rmse: 0.2695 - val_loss: 0.1277 - val_mean_absolute_error: 0.2308 - val_mean_squared_error: 0.1148 - val_rmse: 0.2933
# Epoch 33/100
#  - 76s - loss: 0.0965 - mean_absolute_error: 0.1950 - mean_squared_error: 0.0835 - rmse: 0.2693 - val_loss: 0.1228 - val_mean_absolute_error: 0.2253 - val_mean_squared_error: 0.1099 - val_rmse: 0.2876
# Epoch 34/100
#  - 81s - loss: 0.0964 - mean_absolute_error: 0.1952 - mean_squared_error: 0.0835 - rmse: 0.2691 - val_loss: 0.1318 - val_mean_absolute_error: 0.2346 - val_mean_squared_error: 0.1188 - val_rmse: 0.2968
# Epoch 35/100
#  - 74s - loss: 0.0965 - mean_absolute_error: 0.1950 - mean_squared_error: 0.0835 - rmse: 0.2693 - val_loss: 0.1230 - val_mean_absolute_error: 0.2241 - val_mean_squared_error: 0.1100 - val_rmse: 0.2863
# Epoch 36/100
#  - 80s - loss: 0.0963 - mean_absolute_error: 0.1947 - mean_squared_error: 0.0833 - rmse: 0.2688 - val_loss: 0.1359 - val_mean_absolute_error: 0.2437 - val_mean_squared_error: 0.1230 - val_rmse: 0.3051
# Epoch 37/100
#  - 81s - loss: 0.0964 - mean_absolute_error: 0.1946 - mean_squared_error: 0.0834 - rmse: 0.2691 - val_loss: 0.1196 - val_mean_absolute_error: 0.2225 - val_mean_squared_error: 0.1067 - val_rmse: 0.2834
# Epoch 38/100
#  - 75s - loss: 0.0964 - mean_absolute_error: 0.1949 - mean_squared_error: 0.0834 - rmse: 0.2691 - val_loss: 0.1236 - val_mean_absolute_error: 0.2253 - val_mean_squared_error: 0.1107 - val_rmse: 0.2873
# Epoch 39/100
#  - 81s - loss: 0.0964 - mean_absolute_error: 0.1948 - mean_squared_error: 0.0834 - rmse: 0.2691 - val_loss: 0.1289 - val_mean_absolute_error: 0.2338 - val_mean_squared_error: 0.1159 - val_rmse: 0.2966
# Epoch 40/100
#  - 81s - loss: 0.0963 - mean_absolute_error: 0.1947 - mean_squared_error: 0.0834 - rmse: 0.2690 - val_loss: 0.1391 - val_mean_absolute_error: 0.2449 - val_mean_squared_error: 0.1262 - val_rmse: 0.3074
# Epoch 41/100
#  - 74s - loss: 0.0961 - mean_absolute_error: 0.1946 - mean_squared_error: 0.0832 - rmse: 0.2688 - val_loss: 0.1285 - val_mean_absolute_error: 0.2401 - val_mean_squared_error: 0.1156 - val_rmse: 0.3008
# Epoch 42/100
#  - 80s - loss: 0.0961 - mean_absolute_error: 0.1945 - mean_squared_error: 0.0832 - rmse: 0.2688 - val_loss: 0.1162 - val_mean_absolute_error: 0.2182 - val_mean_squared_error: 0.1033 - val_rmse: 0.2789
# Epoch 43/100
#  - 80s - loss: 0.0961 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0832 - rmse: 0.2687 - val_loss: 0.1357 - val_mean_absolute_error: 0.2409 - val_mean_squared_error: 0.1228 - val_rmse: 0.3033
# Epoch 44/100
#  - 75s - loss: 0.0961 - mean_absolute_error: 0.1946 - mean_squared_error: 0.0832 - rmse: 0.2688 - val_loss: 0.1428 - val_mean_absolute_error: 0.2475 - val_mean_squared_error: 0.1300 - val_rmse: 0.3126
# Epoch 45/100
#  - 81s - loss: 0.0962 - mean_absolute_error: 0.1948 - mean_squared_error: 0.0833 - rmse: 0.2690 - val_loss: 0.1237 - val_mean_absolute_error: 0.2294 - val_mean_squared_error: 0.1107 - val_rmse: 0.2901
# Epoch 46/100
#  - 81s - loss: 0.0960 - mean_absolute_error: 0.1945 - mean_squared_error: 0.0831 - rmse: 0.2685 - val_loss: 0.1365 - val_mean_absolute_error: 0.2440 - val_mean_squared_error: 0.1236 - val_rmse: 0.3050
# Epoch 47/100
#  - 76s - loss: 0.0960 - mean_absolute_error: 0.1945 - mean_squared_error: 0.0831 - rmse: 0.2686 - val_loss: 0.1474 - val_mean_absolute_error: 0.2559 - val_mean_squared_error: 0.1344 - val_rmse: 0.3174
# Epoch 48/100
#  - 82s - loss: 0.0959 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0830 - rmse: 0.2685 - val_loss: 0.1203 - val_mean_absolute_error: 0.2225 - val_mean_squared_error: 0.1074 - val_rmse: 0.2839
# Epoch 49/100
#  - 81s - loss: 0.0960 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0831 - rmse: 0.2685 - val_loss: 0.1261 - val_mean_absolute_error: 0.2335 - val_mean_squared_error: 0.1132 - val_rmse: 0.2948
# Epoch 50/100
#  - 75s - loss: 0.0959 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0830 - rmse: 0.2684 - val_loss: 0.1292 - val_mean_absolute_error: 0.2414 - val_mean_squared_error: 0.1163 - val_rmse: 0.3029
# Epoch 51/100
#  - 83s - loss: 0.0961 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0832 - rmse: 0.2686 - val_loss: 0.1281 - val_mean_absolute_error: 0.2347 - val_mean_squared_error: 0.1152 - val_rmse: 0.2969
# Epoch 52/100
#  - 80s - loss: 0.0959 - mean_absolute_error: 0.1943 - mean_squared_error: 0.0829 - rmse: 0.2683 - val_loss: 0.1464 - val_mean_absolute_error: 0.2642 - val_mean_squared_error: 0.1335 - val_rmse: 0.3256
# Epoch 53/100
#  - 76s - loss: 0.0959 - mean_absolute_error: 0.1942 - mean_squared_error: 0.0829 - rmse: 0.2684 - val_loss: 0.1333 - val_mean_absolute_error: 0.2349 - val_mean_squared_error: 0.1203 - val_rmse: 0.2983
# Epoch 54/100
#  - 81s - loss: 0.0960 - mean_absolute_error: 0.1943 - mean_squared_error: 0.0830 - rmse: 0.2686 - val_loss: 0.1253 - val_mean_absolute_error: 0.2255 - val_mean_squared_error: 0.1124 - val_rmse: 0.2887
# Epoch 55/100
#  - 78s - loss: 0.0958 - mean_absolute_error: 0.1942 - mean_squared_error: 0.0829 - rmse: 0.2682 - val_loss: 0.1276 - val_mean_absolute_error: 0.2364 - val_mean_squared_error: 0.1147 - val_rmse: 0.2963
# Epoch 56/100
#  - 75s - loss: 0.0959 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0830 - rmse: 0.2684 - val_loss: 0.1574 - val_mean_absolute_error: 0.2653 - val_mean_squared_error: 0.1445 - val_rmse: 0.3324
# Epoch 57/100
#  - 83s - loss: 0.0959 - mean_absolute_error: 0.1943 - mean_squared_error: 0.0829 - rmse: 0.2682 - val_loss: 0.1347 - val_mean_absolute_error: 0.2381 - val_mean_squared_error: 0.1219 - val_rmse: 0.3012
# Test loss: 0.13473840407485158
# val_mean_absolute_error: 0.23813766050185475
# score
# [0.13473840407485158, 0.23813766050185475, 0.12185314553790158, 0.31335311317899556]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
