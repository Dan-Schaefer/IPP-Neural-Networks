# %% [markdown]
# # Run Objective:

# %% [markdown]
# Added the following:
# -  Based on Run0104 but with the following changes:
#
# > ```# branch2 (Ate input)
#    visible_branch2 = Input(shape=(1,))
#    visible_branch2_feeder = Dense(1,
#        activation='relu')(visible_branch2)```
#
# > `relu` is replaced by `linear`
#
#
# -  This series contains Run0115 - Run0125
#
#
# Settings:
# -  theta = 0.7

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-12_Run0122.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-12_Run0122
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("unstable_training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -6.496300e-13 -4.409594e-14  3.983713e-14 -8.762553e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -2.151511e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00
# 25%   -6.585430e-01 -6.647545e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01
# 50%   -1.486741e-01 -1.691691e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02
# 75%    6.161291e-01  4.916113e-01  5.456303e-01  1.523511e-01  4.619831e-01
# max    2.910539e+00  1.813172e+00  2.315942e+00  2.515826e+00  3.914455e+00
#
#                   x         Ti_Te
# count  6.393280e+05  6.393280e+05
# mean   2.687112e-14  5.456717e-14
# std    1.000000e+00  1.000000e+00
# min   -1.375717e+00 -1.667450e+00
# 25%   -9.568879e-01 -9.268335e-01
# 50%   -1.192290e-01 -6.771858e-02
# 75%    7.184299e-01  4.210880e-01
# max    1.765503e+00  1.665323e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05  6.393280e+05
# mean   1.633424e-12 -4.409594e-14  3.983713e-14 -8.762553e-14  2.687112e-14
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.848237e+00 -4.175202e+00 -8.733971e-01 -1.264253e+00 -1.375717e+00
# 25%   -6.585430e-01 -6.345777e-01 -6.748652e-01 -3.148231e-01 -9.568879e-01
# 50%   -1.486741e-01 -4.447369e-02 -4.385177e-01 -5.588771e-02 -1.192290e-01
# 75%    6.161291e-01  5.456303e-01  1.523511e-01  4.619831e-01  7.184299e-01
# max    2.910539e+00  2.315942e+00  2.515826e+00  3.914455e+00  1.765503e+00
#
#               Ti_Te
# count  6.393280e+05
# mean   5.456717e-14
# std    1.000000e+00
# min   -1.667450e+00
# 25%   -9.268335e-01
# 50%   -6.771858e-02
# 75%    4.210880e-01
# max    1.665323e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (639328, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.393280e+05
# mean  -6.496300e-13
# std    1.000000e+00
# min   -2.151511e+00
# 25%   -6.647545e-01
# 50%   -1.691691e-01
# 75%    4.916113e-01
# max    1.813172e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (639328, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)
#TR = Dense(1, activation='relu')(visible_branch2_feeder)
#TR = Dense(1, activation=ThresholdedReLU(theta=0.8))(visible_branch2_feeder)
TR = ThresholdedReLU(theta=0.7)(visible_branch2_feeder)

# merge input models
merge = concatenate([hidden2_branch1, TR])

# interpretation model
output = Dense(1, activation='linear')(merge)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# thresholded_re_lu_1 (Thresholde (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 31)           0           dense_2[0][0]
#                                                                  thresholded_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            32          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,174
# Trainable params: 1,174
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 575395 samples, validate on 63933 samples
# Epoch 1/100
#  - 346s - loss: 0.3643 - mean_absolute_error: 0.4256 - mean_squared_error: 0.3598 - rmse: 0.5685 - val_loss: 0.5234 - val_mean_absolute_error: 0.5438 - val_mean_squared_error: 0.5179 - val_rmse: 0.6342
# Epoch 2/100
#  - 258s - loss: 0.3300 - mean_absolute_error: 0.4006 - mean_squared_error: 0.3239 - rmse: 0.5397 - val_loss: 0.5142 - val_mean_absolute_error: 0.5341 - val_mean_squared_error: 0.5076 - val_rmse: 0.6265
# Epoch 3/100
#  - 131s - loss: 0.3251 - mean_absolute_error: 0.3959 - mean_squared_error: 0.3182 - rmse: 0.5346 - val_loss: 0.5283 - val_mean_absolute_error: 0.5389 - val_mean_squared_error: 0.5211 - val_rmse: 0.6299
# Epoch 4/100
#  - 103s - loss: 0.3214 - mean_absolute_error: 0.3918 - mean_squared_error: 0.3139 - rmse: 0.5301 - val_loss: 0.4879 - val_mean_absolute_error: 0.5068 - val_mean_squared_error: 0.4801 - val_rmse: 0.6016
# Epoch 5/100
#  - 103s - loss: 0.3178 - mean_absolute_error: 0.3877 - mean_squared_error: 0.3098 - rmse: 0.5258 - val_loss: 0.5164 - val_mean_absolute_error: 0.5225 - val_mean_squared_error: 0.5081 - val_rmse: 0.6194
# Epoch 6/100
#  - 107s - loss: 0.3157 - mean_absolute_error: 0.3851 - mean_squared_error: 0.3072 - rmse: 0.5234 - val_loss: 0.5067 - val_mean_absolute_error: 0.5234 - val_mean_squared_error: 0.4980 - val_rmse: 0.6193
# Epoch 7/100
#  - 877s - loss: 0.3144 - mean_absolute_error: 0.3836 - mean_squared_error: 0.3055 - rmse: 0.5217 - val_loss: 0.4955 - val_mean_absolute_error: 0.5035 - val_mean_squared_error: 0.4864 - val_rmse: 0.6012
# Epoch 8/100
#  - 121s - loss: 0.3132 - mean_absolute_error: 0.3823 - mean_squared_error: 0.3040 - rmse: 0.5201 - val_loss: 0.4843 - val_mean_absolute_error: 0.4970 - val_mean_squared_error: 0.4750 - val_rmse: 0.5937
# Epoch 9/100
#  - 180s - loss: 0.3125 - mean_absolute_error: 0.3814 - mean_squared_error: 0.3030 - rmse: 0.5192 - val_loss: 0.5113 - val_mean_absolute_error: 0.5245 - val_mean_squared_error: 0.5017 - val_rmse: 0.6170
# Epoch 10/100
#  - 3792s - loss: 0.3117 - mean_absolute_error: 0.3808 - mean_squared_error: 0.3020 - rmse: 0.5186 - val_loss: 0.4913 - val_mean_absolute_error: 0.5020 - val_mean_squared_error: 0.4814 - val_rmse: 0.5980
# Epoch 11/100
#  - 101s - loss: 0.3114 - mean_absolute_error: 0.3803 - mean_squared_error: 0.3015 - rmse: 0.5180 - val_loss: 0.4814 - val_mean_absolute_error: 0.4968 - val_mean_squared_error: 0.4714 - val_rmse: 0.5925
# Epoch 12/100
#  - 80s - loss: 0.3109 - mean_absolute_error: 0.3799 - mean_squared_error: 0.3008 - rmse: 0.5174 - val_loss: 0.4916 - val_mean_absolute_error: 0.5010 - val_mean_squared_error: 0.4815 - val_rmse: 0.5961
# Epoch 13/100
#  - 78s - loss: 0.3107 - mean_absolute_error: 0.3794 - mean_squared_error: 0.3004 - rmse: 0.5170 - val_loss: 0.4873 - val_mean_absolute_error: 0.4988 - val_mean_squared_error: 0.4770 - val_rmse: 0.5946
# Epoch 14/100
#  - 89s - loss: 0.3106 - mean_absolute_error: 0.3794 - mean_squared_error: 0.3003 - rmse: 0.5167 - val_loss: 0.4792 - val_mean_absolute_error: 0.4991 - val_mean_squared_error: 0.4689 - val_rmse: 0.5936
# Epoch 15/100
#  - 89s - loss: 0.3103 - mean_absolute_error: 0.3791 - mean_squared_error: 0.2999 - rmse: 0.5163 - val_loss: 0.5060 - val_mean_absolute_error: 0.5165 - val_mean_squared_error: 0.4956 - val_rmse: 0.6115
# Epoch 16/100
#  - 86s - loss: 0.3101 - mean_absolute_error: 0.3788 - mean_squared_error: 0.2996 - rmse: 0.5162 - val_loss: 0.4756 - val_mean_absolute_error: 0.4898 - val_mean_squared_error: 0.4651 - val_rmse: 0.5867
# Epoch 17/100
#  - 86s - loss: 0.3102 - mean_absolute_error: 0.3788 - mean_squared_error: 0.2996 - rmse: 0.5162 - val_loss: 0.4983 - val_mean_absolute_error: 0.5016 - val_mean_squared_error: 0.4877 - val_rmse: 0.5972
# Epoch 18/100
#  - 77s - loss: 0.3098 - mean_absolute_error: 0.3785 - mean_squared_error: 0.2992 - rmse: 0.5159 - val_loss: 0.4886 - val_mean_absolute_error: 0.4973 - val_mean_squared_error: 0.4779 - val_rmse: 0.5953
# Epoch 19/100
#  - 87s - loss: 0.3098 - mean_absolute_error: 0.3785 - mean_squared_error: 0.2991 - rmse: 0.5157 - val_loss: 0.4757 - val_mean_absolute_error: 0.4930 - val_mean_squared_error: 0.4651 - val_rmse: 0.5886
# Epoch 20/100
#  - 80s - loss: 0.3095 - mean_absolute_error: 0.3781 - mean_squared_error: 0.2988 - rmse: 0.5152 - val_loss: 0.4863 - val_mean_absolute_error: 0.5010 - val_mean_squared_error: 0.4756 - val_rmse: 0.5989
# Epoch 21/100
#  - 75s - loss: 0.3095 - mean_absolute_error: 0.3781 - mean_squared_error: 0.2988 - rmse: 0.5153 - val_loss: 0.4752 - val_mean_absolute_error: 0.4927 - val_mean_squared_error: 0.4645 - val_rmse: 0.5893
# Epoch 22/100
#  - 127s - loss: 0.3094 - mean_absolute_error: 0.3781 - mean_squared_error: 0.2987 - rmse: 0.5153 - val_loss: 0.4787 - val_mean_absolute_error: 0.4931 - val_mean_squared_error: 0.4679 - val_rmse: 0.5915
# Epoch 23/100
#  - 76s - loss: 0.3094 - mean_absolute_error: 0.3779 - mean_squared_error: 0.2986 - rmse: 0.5150 - val_loss: 0.4812 - val_mean_absolute_error: 0.4989 - val_mean_squared_error: 0.4704 - val_rmse: 0.5960
# Epoch 24/100
#  - 84s - loss: 0.3093 - mean_absolute_error: 0.3779 - mean_squared_error: 0.2985 - rmse: 0.5151 - val_loss: 0.4794 - val_mean_absolute_error: 0.4974 - val_mean_squared_error: 0.4685 - val_rmse: 0.5935
# Epoch 25/100
#  - 79s - loss: 0.3090 - mean_absolute_error: 0.3775 - mean_squared_error: 0.2982 - rmse: 0.5149 - val_loss: 0.4901 - val_mean_absolute_error: 0.5043 - val_mean_squared_error: 0.4793 - val_rmse: 0.6002
# Epoch 26/100
#  - 75s - loss: 0.3091 - mean_absolute_error: 0.3777 - mean_squared_error: 0.2982 - rmse: 0.5149 - val_loss: 0.4774 - val_mean_absolute_error: 0.4938 - val_mean_squared_error: 0.4665 - val_rmse: 0.5903
# Epoch 27/100
#  - 79s - loss: 0.3088 - mean_absolute_error: 0.3774 - mean_squared_error: 0.2979 - rmse: 0.5145 - val_loss: 0.4689 - val_mean_absolute_error: 0.4865 - val_mean_squared_error: 0.4580 - val_rmse: 0.5838
# Epoch 28/100
#  - 77s - loss: 0.3088 - mean_absolute_error: 0.3772 - mean_squared_error: 0.2978 - rmse: 0.5143 - val_loss: 0.4892 - val_mean_absolute_error: 0.5032 - val_mean_squared_error: 0.4783 - val_rmse: 0.5987
# Epoch 29/100
#  - 83s - loss: 0.3086 - mean_absolute_error: 0.3772 - mean_squared_error: 0.2976 - rmse: 0.5141 - val_loss: 0.4752 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4642 - val_rmse: 0.5925
# Epoch 30/100
#  - 77s - loss: 0.3082 - mean_absolute_error: 0.3768 - mean_squared_error: 0.2972 - rmse: 0.5138 - val_loss: 0.4774 - val_mean_absolute_error: 0.4927 - val_mean_squared_error: 0.4664 - val_rmse: 0.5892
# Epoch 31/100
#  - 76s - loss: 0.3081 - mean_absolute_error: 0.3768 - mean_squared_error: 0.2971 - rmse: 0.5138 - val_loss: 0.4910 - val_mean_absolute_error: 0.5023 - val_mean_squared_error: 0.4800 - val_rmse: 0.5985
# Epoch 32/100
#  - 89s - loss: 0.3083 - mean_absolute_error: 0.3768 - mean_squared_error: 0.2972 - rmse: 0.5138 - val_loss: 0.4895 - val_mean_absolute_error: 0.5017 - val_mean_squared_error: 0.4784 - val_rmse: 0.5995
# Epoch 33/100
#  - 76s - loss: 0.3081 - mean_absolute_error: 0.3767 - mean_squared_error: 0.2970 - rmse: 0.5139 - val_loss: 0.4816 - val_mean_absolute_error: 0.4964 - val_mean_squared_error: 0.4704 - val_rmse: 0.5930
# Epoch 34/100
#  - 77s - loss: 0.3079 - mean_absolute_error: 0.3765 - mean_squared_error: 0.2968 - rmse: 0.5133 - val_loss: 0.4695 - val_mean_absolute_error: 0.4858 - val_mean_squared_error: 0.4584 - val_rmse: 0.5833
# Epoch 35/100
#  - 79s - loss: 0.3080 - mean_absolute_error: 0.3764 - mean_squared_error: 0.2968 - rmse: 0.5134 - val_loss: 0.4935 - val_mean_absolute_error: 0.5104 - val_mean_squared_error: 0.4823 - val_rmse: 0.6044
# Epoch 36/100
#  - 77s - loss: 0.3079 - mean_absolute_error: 0.3765 - mean_squared_error: 0.2968 - rmse: 0.5134 - val_loss: 0.4884 - val_mean_absolute_error: 0.4996 - val_mean_squared_error: 0.4773 - val_rmse: 0.5958
# Epoch 37/100
#  - 80s - loss: 0.3078 - mean_absolute_error: 0.3762 - mean_squared_error: 0.2966 - rmse: 0.5134 - val_loss: 0.4817 - val_mean_absolute_error: 0.4919 - val_mean_squared_error: 0.4705 - val_rmse: 0.5908
# Epoch 38/100
#  - 78s - loss: 0.3076 - mean_absolute_error: 0.3762 - mean_squared_error: 0.2964 - rmse: 0.5130 - val_loss: 0.4717 - val_mean_absolute_error: 0.4891 - val_mean_squared_error: 0.4605 - val_rmse: 0.5871
# Epoch 39/100
#  - 76s - loss: 0.3076 - mean_absolute_error: 0.3762 - mean_squared_error: 0.2964 - rmse: 0.5131 - val_loss: 0.4654 - val_mean_absolute_error: 0.4814 - val_mean_squared_error: 0.4542 - val_rmse: 0.5778
# Epoch 40/100
#  - 87s - loss: 0.3076 - mean_absolute_error: 0.3762 - mean_squared_error: 0.2964 - rmse: 0.5132 - val_loss: 0.4736 - val_mean_absolute_error: 0.4851 - val_mean_squared_error: 0.4624 - val_rmse: 0.5814
# Epoch 41/100
#  - 75s - loss: 0.3072 - mean_absolute_error: 0.3760 - mean_squared_error: 0.2959 - rmse: 0.5130 - val_loss: 0.4793 - val_mean_absolute_error: 0.4853 - val_mean_squared_error: 0.4680 - val_rmse: 0.5841
# Epoch 42/100
#  - 76s - loss: 0.3074 - mean_absolute_error: 0.3758 - mean_squared_error: 0.2961 - rmse: 0.5127 - val_loss: 0.5120 - val_mean_absolute_error: 0.5205 - val_mean_squared_error: 0.5008 - val_rmse: 0.6126
# Epoch 43/100
#  - 80s - loss: 0.3073 - mean_absolute_error: 0.3760 - mean_squared_error: 0.2960 - rmse: 0.5127 - val_loss: 0.4764 - val_mean_absolute_error: 0.4928 - val_mean_squared_error: 0.4651 - val_rmse: 0.5878
# Epoch 44/100
#  - 77s - loss: 0.3075 - mean_absolute_error: 0.3759 - mean_squared_error: 0.2961 - rmse: 0.5127 - val_loss: 0.4907 - val_mean_absolute_error: 0.4994 - val_mean_squared_error: 0.4795 - val_rmse: 0.5973
# Epoch 45/100
#  - 81s - loss: 0.3071 - mean_absolute_error: 0.3758 - mean_squared_error: 0.2958 - rmse: 0.5127 - val_loss: 0.4913 - val_mean_absolute_error: 0.5025 - val_mean_squared_error: 0.4800 - val_rmse: 0.6003
# Epoch 46/100
#  - 77s - loss: 0.3071 - mean_absolute_error: 0.3756 - mean_squared_error: 0.2958 - rmse: 0.5124 - val_loss: 0.5155 - val_mean_absolute_error: 0.5201 - val_mean_squared_error: 0.5042 - val_rmse: 0.6136
# Epoch 47/100
#  - 76s - loss: 0.3070 - mean_absolute_error: 0.3757 - mean_squared_error: 0.2956 - rmse: 0.5121 - val_loss: 0.4691 - val_mean_absolute_error: 0.4868 - val_mean_squared_error: 0.4578 - val_rmse: 0.5855
# Epoch 48/100
#  - 83s - loss: 0.3071 - mean_absolute_error: 0.3756 - mean_squared_error: 0.2957 - rmse: 0.5125 - val_loss: 0.4790 - val_mean_absolute_error: 0.4945 - val_mean_squared_error: 0.4676 - val_rmse: 0.5912
# Epoch 49/100
#  - 77s - loss: 0.3071 - mean_absolute_error: 0.3757 - mean_squared_error: 0.2957 - rmse: 0.5126 - val_loss: 0.4816 - val_mean_absolute_error: 0.5008 - val_mean_squared_error: 0.4702 - val_rmse: 0.5955
# Epoch 50/100
#  - 76s - loss: 0.3071 - mean_absolute_error: 0.3755 - mean_squared_error: 0.2957 - rmse: 0.5124 - val_loss: 0.4828 - val_mean_absolute_error: 0.4940 - val_mean_squared_error: 0.4714 - val_rmse: 0.5925
# Epoch 51/100
#  - 83s - loss: 0.3069 - mean_absolute_error: 0.3754 - mean_squared_error: 0.2954 - rmse: 0.5121 - val_loss: 0.4792 - val_mean_absolute_error: 0.4956 - val_mean_squared_error: 0.4678 - val_rmse: 0.5902
# Epoch 52/100
#  - 76s - loss: 0.3071 - mean_absolute_error: 0.3755 - mean_squared_error: 0.2957 - rmse: 0.5122 - val_loss: 0.4681 - val_mean_absolute_error: 0.4866 - val_mean_squared_error: 0.4566 - val_rmse: 0.5833
# Epoch 53/100
#  - 79s - loss: 0.3068 - mean_absolute_error: 0.3754 - mean_squared_error: 0.2953 - rmse: 0.5119 - val_loss: 0.4877 - val_mean_absolute_error: 0.5019 - val_mean_squared_error: 0.4762 - val_rmse: 0.5959
# Epoch 54/100
#  - 80s - loss: 0.3068 - mean_absolute_error: 0.3753 - mean_squared_error: 0.2953 - rmse: 0.5121 - val_loss: 0.4934 - val_mean_absolute_error: 0.5086 - val_mean_squared_error: 0.4819 - val_rmse: 0.6038
# Test loss: 0.4933725821248989
# val_mean_absolute_error: 0.5085840255053281
# score
# [0.4933725821248989, 0.5085840255053281, 0.4819063616563808, 0.6234641452668586]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
