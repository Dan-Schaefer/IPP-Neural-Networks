# %% [markdown]
# # Run Objective:

# %% [markdown]
# ### Run0130-SERIES
#
# This is Run0129d with the variable gradient from `Run0127` added.
#
# -  `Run0130`

# %%
# DO NOT RUN THIS PART

# %%
import os
import sys
import time

# Gets the current file name. Useful for procedurally generating output/log files.
file_name =  os.path.basename(sys.argv[0][:-3])
print(file_name)

if file_name == "ipykernel_launcher":
    print("This is the Jupyter version.")
    print("Now MANUALLY run the next two cells!")
    print("STOP! This should not be in your code!!")
    exit(0)
    time.sleep(10)
    print("Testing if script has really stopped.")
else:
    print("This is the Atom version")

# %%
# RUN ONLY IN JUPYTER!!
# Start here (manual)

# %%
# %%javascript
# IPython.notebook.kernel.execute('file_name = "' + IPython.notebook.notebook_name + '"');

# %%
print(file_name)
# Out:
# 2018-10-26_Run0130-Mk2.ipynb

# %%
file_name = file_name[:-6]
print(file_name)

is_Jupyter = True
print(is_Jupyter)
# Out:
# 2018-10-26_Run0130-Mk2
# True

# %%
# Same code for both ATOM & JUPYTER from now (Run all cells below now)

# %%
'''
Late Fusion Module (test) - Functional API
'''

# Multiple Inputs
import keras
from keras.optimizers import RMSprop, adam, Adam
from keras.initializers import TruncatedNormal, glorot_normal, Constant
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from keras import regularizers
from keras import backend as K
from keras.backend import switch
import pandas
import numpy
import sys
import os
from copy import deepcopy
import tensorflow as tf
from keras.utils.generic_utils import get_custom_objects
from keras.layers.advanced_activations import ThresholdedReLU

keras.backend.clear_session()
# Out:
# Using TensorFlow backend.

# %%
# Define new Metric: rmse = Root Mean Square Error
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square( y_true-y_pred )))

# %%
# Modify for ATOM use

# %%
if is_Jupyter == True:
    pass
else:
    # Gets the current file name. Useful for procedurally generating output/log files.
    file_name =  os.path.basename(sys.argv[0][:-3])

# %%
# Define neural network parameters
batch_size = 10
#num_classes = 1
epochs = 100

# %%
# Load Data (which is in HDF5 or .h5 format)
store = pandas.HDFStore("training_gen3_7D_nions0_flat_filter8.h5")
target_df = store['/output/efeETG_GB'].to_frame()  # This one is relatively easy to train
input_df = store['input']

# Puts inputs and outputs in the same pandas dataframe.
# Also only keeps overlapping entries.
joined_dataFrame = target_df.join(input_df)

# Make a copy of joined_dataFrame for later use
joined_dataFrame_original = deepcopy(joined_dataFrame)


# *************************************************************************** #
# Normalize data by standard deviation and mean-centering the data
# Standard configuration
joined_dataFrame['efeETG_GB'] = (joined_dataFrame['efeETG_GB'] - joined_dataFrame['efeETG_GB'].mean()) / joined_dataFrame['efeETG_GB'].std()
joined_dataFrame['Ati'] = (joined_dataFrame['Ati'] - joined_dataFrame['Ati'].mean()) / joined_dataFrame['Ati'].std()
joined_dataFrame['Ate'] = (joined_dataFrame['Ate'] - joined_dataFrame['Ate'].mean()) / joined_dataFrame['Ate'].std()
joined_dataFrame['An'] = (joined_dataFrame['An'] - joined_dataFrame['An'].mean()) / joined_dataFrame['An'].std()
joined_dataFrame['q'] = (joined_dataFrame['q'] - joined_dataFrame['q'].mean()) / joined_dataFrame['q'].std()
joined_dataFrame['smag'] = (joined_dataFrame['smag'] - joined_dataFrame['smag'].mean()) / joined_dataFrame['smag'].std()
joined_dataFrame['x'] = (joined_dataFrame['x'] - joined_dataFrame['x'].mean()) / joined_dataFrame['x'].std()
joined_dataFrame['Ti_Te'] = (joined_dataFrame['Ti_Te'] - joined_dataFrame['Ti_Te'].mean()) / joined_dataFrame['Ti_Te'].std()

# Shuffles dataset
shuffled_joined_dataFrame = joined_dataFrame.reindex(numpy.random.permutation(
                                                joined_dataFrame.index))

# Creates a pandas dataframe for the outputs
shuffled_clean_output_df = shuffled_joined_dataFrame['efeETG_GB']

# Make a copy of shuffled_joined_dataFrame for later use
shuffled_joined_dataFrame_base = deepcopy(shuffled_joined_dataFrame)



# *************************************************************************** #
# Creates a pandas dataframe for the inputs (7D)
shuffled_clean_input_df_7D = shuffled_joined_dataFrame.drop('efeETG_GB', axis=1)

# Creates training dataset (90% of total data) for outputs
y_train = shuffled_clean_output_df.iloc[:int(
    numpy.round(len(shuffled_clean_output_df)*0.9))]

# Creates training dataset (90% of total data) for inputs
x_train = shuffled_clean_input_df_7D.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9))]

# Creates testing dataset (10% of total data) for outputs
y_test = shuffled_clean_output_df.iloc[int(
    numpy.round(len(shuffled_clean_output_df)*0.9)):]

# Creates testing dataset (10% of total data) for inputs
x_test = shuffled_clean_input_df_7D.iloc[int(
    numpy.round(len(shuffled_clean_input_df_7D)*0.9)):]
# *************************************************************************** #


# Deletes pandas dataframes that are no longer needed
del target_df, input_df

# Closes the HDFStore. This is good practice.
store.close()

# %%
shuffled_clean_input_df_7D.describe(include='all')
# Out:
#                 Ati           Ate            An             q          smag  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -2.555908e-15 -4.941123e-17  2.201046e-16  3.881308e-17 -4.491930e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.639065e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00
# 25%   -7.928000e-01 -7.898708e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01
# 50%   -1.059360e-01 -9.507533e-02  1.347799e-01 -3.983652e-01 -1.936629e-01
# 75%    5.809279e-01  5.997202e-01  6.437252e-01  1.976217e-01  9.108525e-01
# max    2.641520e+00  2.684107e+00  1.831264e+00  2.581570e+00  1.739239e+00
#
#                   x         Ti_Te
# count  6.479137e+06  6.479137e+06
# mean   5.509633e-18  5.804416e-17
# std    1.000000e+00  1.000000e+00
# min   -1.405340e+00 -1.235044e+00
# 25%   -9.907529e-01 -8.817246e-01
# 50%   -1.615792e-01 -1.750863e-01
# 75%    6.675945e-01  7.576761e-01
# max    1.704062e+00  1.944828e+00

# %%
# Creates a pandas dataframe for the inputs
shuffled_clean_input_df_1 = shuffled_clean_input_df_7D.drop('Ate', axis=1)

# %%
shuffled_clean_input_df_1.describe(include='all')
# Out:
#                 Ati            An             q          smag             x  \
# count  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06  6.479137e+06
# mean  -2.555908e-15  2.201046e-16  3.881308e-17 -4.491930e-17  5.509633e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.632300e+00 -1.901001e+00 -8.370116e-01 -1.574307e+00 -1.405340e+00
# 25%   -7.928000e-01 -5.438138e-01 -6.367600e-01 -8.011463e-01 -9.907529e-01
# 50%   -1.059360e-01  1.347799e-01 -3.983652e-01 -1.936629e-01 -1.615792e-01
# 75%    5.809279e-01  6.437252e-01  1.976217e-01  9.108525e-01  6.675945e-01
# max    2.641520e+00  1.831264e+00  2.581570e+00  1.739239e+00  1.704062e+00
#
#               Ti_Te
# count  6.479137e+06
# mean   5.804416e-17
# std    1.000000e+00
# min   -1.235044e+00
# 25%   -8.817246e-01
# 50%   -1.750863e-01
# 75%    7.576761e-01
# max    1.944828e+00

# %%
print(shuffled_clean_input_df_1.shape)
# Out:
# (6479137, 6)

# %%
shuffled_clean_input_df_2 = shuffled_clean_input_df_7D.drop('Ati', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('An', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('q', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('smag', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('x', axis=1)
shuffled_clean_input_df_2 = shuffled_clean_input_df_2.drop('Ti_Te', axis=1)

# %%
shuffled_clean_input_df_2.describe(include='all')
# Out:
#                 Ate
# count  6.479137e+06
# mean  -4.941123e-17
# std    1.000000e+00
# min   -1.639065e+00
# 25%   -7.898708e-01
# 50%   -9.507533e-02
# 75%    5.997202e-01
# max    2.684107e+00

# %%
print(shuffled_clean_input_df_2.shape)
# Out:
# (6479137, 1)

# %%
# *************************************************************************** #
# Branch 1

# Creates training dataset (90% of total data) for inputs
x_train_1 = shuffled_clean_input_df_1.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_1 = shuffled_clean_input_df_1.iloc[int(
    numpy.round(len(shuffled_clean_input_df_1)*0.9)):]
# *************************************************************************** #

# %%
# *************************************************************************** #
# Branch 2

# Creates training dataset (90% of total data) for inputs
x_train_2 = shuffled_clean_input_df_2.iloc[:int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9))]

# Creates testing dataset (10% of total data) for inputs
x_test_2 = shuffled_clean_input_df_2.iloc[int(
    numpy.round(len(shuffled_clean_input_df_2)*0.9)):]
# *************************************************************************** #

# %%
# branch1
visible_branch1 = Input(shape=(6,))
hidden1_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch1 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch1)
theta_branch1 = Dense(1,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden2_branch1)
theta_branch1_feeder = Dense(1,
        activation='linear',
        kernel_initializer=Constant(value=-1),
        bias_initializer='Zeros',
        trainable=False)(theta_branch1)

# branch2 (Ate input)
visible_branch2 = Input(shape=(1,))
visible_branch2_feeder = Dense(1,
                activation='linear')(visible_branch2)

# addition_pooling (effectively subtraction though...)
addition_pooling = keras.layers.Add()([theta_branch1_feeder, visible_branch2_feeder])


TR = Dense(1, activation='relu',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=False)(addition_pooling)

# merge input models
#merge = concatenate([hidden2_branch1, TR])

# branch 3 (for the gradient)
hidden1_branch3 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(visible_branch1)
hidden2_branch3 = Dense(30,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden1_branch3)
m_branch3 = Dense(1,
        activation='tanh',
        kernel_initializer='glorot_normal',
        kernel_regularizer=regularizers.l2(0.00005),
        use_bias=True, bias_initializer='glorot_normal')(hidden2_branch3)
m_branch3_feeder = Dense(1,
        activation='linear',
        kernel_initializer=Constant(value=+1),
        bias_initializer='Zeros',
        trainable=False)(m_branch3)

# multiplication pooling
multiplication_pooling = keras.layers.Multiply()([m_branch3_feeder, TR])

# interpretation model
output = Dense(1, activation='linear',
           kernel_initializer='Ones',
           bias_initializer='Zeros',
           trainable=True)(multiplication_pooling)

model = Model(inputs=[visible_branch1, visible_branch2], outputs=output)

# summarize layers
print(model.summary())

# plot graph
#plot_model(model, 'ModelPlots/' + str(file_name) + '_model_plot.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           930         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 30)           210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            31          dense_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 30)           930         dense_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            2           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           input_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            31          dense_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            2           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            2           add_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1)            0           dense_10[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            2           multiply_1[0][0]
# ==================================================================================================
# Total params: 2,352
# Trainable params: 2,346
# Non-trainable params: 6
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error',   #categorical_crossentropy
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=["mae", "mean_squared_error", rmse])

# Add CallBacks (including TensorBoard)
tbCallBack = keras.callbacks.TensorBoard(
        log_dir='TensorBoard_logs/' + str(file_name), write_graph = False, write_images=False, write_grads=False)
EarlyStoppingCallBack = keras.callbacks.EarlyStopping(
        monitor='val_rmse', min_delta=0, patience=15, verbose=0, mode='auto')

history = model.fit([x_train_1, x_train_2],
                    y = y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    verbose=2,
                    # validation_data=(x_test, y_test),
                    validation_data=([x_test_1, x_test_2], y_test),
                    callbacks=[tbCallBack, EarlyStoppingCallBack])

# score = model.evaluate(x_test, y_test, verbose=0)
score = model.evaluate([x_test_1, x_test_2], y_test, verbose=0)

print('Test loss:', score[0])
print('val_mean_absolute_error:', score[1])

print("score")
print(score)

print("model.metrics_names")
print(model.metrics_names)

# creates a HDF5 file 'my_model.h5'
model.save("./Saved-Networks/" + str(file_name) +".h5")

# Create output file
OutputFile = open("./Loss-Values/" +str(file_name) +".txt", "w+")
OutputFile.write("Test loss: " + str(score[0]) + "\n")
OutputFile.write("val_mean_absolute_error: " +str(score[1]) + "\n")
OutputFile.write("val_mean_squared_error: " +str(score[2]) + "\n")
OutputFile.write("RMSE: " +str(score[3]) + "\n")
OutputFile.close()

del history
del model
# Out:
# Train on 5831223 samples, validate on 647914 samples
# Epoch 1/100
#  - 366s - loss: 0.1214 - mean_absolute_error: 0.0875 - mean_squared_error: 0.1094 - rmse: 0.2135 - val_loss: 0.1579 - val_mean_absolute_error: 0.1092 - val_mean_squared_error: 0.1443 - val_rmse: 0.1510
# Epoch 2/100
#  - 360s - loss: 0.0959 - mean_absolute_error: 0.0727 - mean_squared_error: 0.0822 - rmse: 0.1803 - val_loss: 0.1064 - val_mean_absolute_error: 0.0827 - val_mean_squared_error: 0.0928 - val_rmse: 0.1206
# Epoch 3/100
#  - 359s - loss: 0.0925 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0791 - rmse: 0.1746 - val_loss: 0.1259 - val_mean_absolute_error: 0.0937 - val_mean_squared_error: 0.1126 - val_rmse: 0.1371
# Epoch 4/100
#  - 357s - loss: 0.0907 - mean_absolute_error: 0.0682 - mean_squared_error: 0.0775 - rmse: 0.1720 - val_loss: 0.1183 - val_mean_absolute_error: 0.0889 - val_mean_squared_error: 0.1052 - val_rmse: 0.1327
# Epoch 5/100
#  - 358s - loss: 0.0894 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0765 - rmse: 0.1706 - val_loss: 0.0982 - val_mean_absolute_error: 0.0782 - val_mean_squared_error: 0.0855 - val_rmse: 0.1167
# Epoch 6/100
#  - 357s - loss: 0.0884 - mean_absolute_error: 0.0670 - mean_squared_error: 0.0759 - rmse: 0.1695 - val_loss: 0.1287 - val_mean_absolute_error: 0.0927 - val_mean_squared_error: 0.1164 - val_rmse: 0.1342
# Epoch 7/100
#  - 359s - loss: 0.0875 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0753 - rmse: 0.1686 - val_loss: 0.1182 - val_mean_absolute_error: 0.0958 - val_mean_squared_error: 0.1061 - val_rmse: 0.1369
# Epoch 8/100
#  - 353s - loss: 0.0870 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0749 - rmse: 0.1680 - val_loss: 0.1064 - val_mean_absolute_error: 0.0829 - val_mean_squared_error: 0.0943 - val_rmse: 0.1227
# Epoch 9/100
#  - 354s - loss: 0.0870 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0749 - rmse: 0.1678 - val_loss: 0.1108 - val_mean_absolute_error: 0.0852 - val_mean_squared_error: 0.0987 - val_rmse: 0.1264
# Epoch 10/100
#  - 357s - loss: 0.0873 - mean_absolute_error: 0.0666 - mean_squared_error: 0.0752 - rmse: 0.1683 - val_loss: 0.1096 - val_mean_absolute_error: 0.0862 - val_mean_squared_error: 0.0975 - val_rmse: 0.1245
# Epoch 11/100
#  - 355s - loss: 0.0870 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0750 - rmse: 0.1682 - val_loss: 0.1591 - val_mean_absolute_error: 0.0956 - val_mean_squared_error: 0.1471 - val_rmse: 0.1463
# Epoch 12/100
#  - 354s - loss: 0.0870 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0749 - rmse: 0.1680 - val_loss: 0.1141 - val_mean_absolute_error: 0.0933 - val_mean_squared_error: 0.1021 - val_rmse: 0.1351
# Epoch 13/100
#  - 354s - loss: 0.0868 - mean_absolute_error: 0.0664 - mean_squared_error: 0.0747 - rmse: 0.1680 - val_loss: 0.1046 - val_mean_absolute_error: 0.0799 - val_mean_squared_error: 0.0924 - val_rmse: 0.1175
# Epoch 14/100
#  - 356s - loss: 0.0867 - mean_absolute_error: 0.0662 - mean_squared_error: 0.0747 - rmse: 0.1679 - val_loss: 0.1159 - val_mean_absolute_error: 0.0832 - val_mean_squared_error: 0.1039 - val_rmse: 0.1224
# Epoch 15/100
#  - 354s - loss: 0.0867 - mean_absolute_error: 0.0662 - mean_squared_error: 0.0746 - rmse: 0.1678 - val_loss: 0.1170 - val_mean_absolute_error: 0.0885 - val_mean_squared_error: 0.1050 - val_rmse: 0.1329
# Epoch 16/100
#  - 354s - loss: 0.0863 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0743 - rmse: 0.1672 - val_loss: 0.1031 - val_mean_absolute_error: 0.0763 - val_mean_squared_error: 0.0912 - val_rmse: 0.1160
# Epoch 17/100
#  - 355s - loss: 0.0863 - mean_absolute_error: 0.0661 - mean_squared_error: 0.0744 - rmse: 0.1674 - val_loss: 0.1018 - val_mean_absolute_error: 0.0756 - val_mean_squared_error: 0.0899 - val_rmse: 0.1163
# Epoch 18/100
#  - 356s - loss: 0.0862 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0742 - rmse: 0.1672 - val_loss: 0.1055 - val_mean_absolute_error: 0.0802 - val_mean_squared_error: 0.0935 - val_rmse: 0.1190
# Epoch 19/100
#  - 357s - loss: 0.0861 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0741 - rmse: 0.1670 - val_loss: 0.1222 - val_mean_absolute_error: 0.0879 - val_mean_squared_error: 0.1102 - val_rmse: 0.1299
# Epoch 20/100
#  - 357s - loss: 0.0861 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0741 - rmse: 0.1671 - val_loss: 0.1546 - val_mean_absolute_error: 0.1088 - val_mean_squared_error: 0.1428 - val_rmse: 0.1605
# Epoch 21/100
#  - 358s - loss: 0.0858 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0739 - rmse: 0.1667 - val_loss: 0.1286 - val_mean_absolute_error: 0.0850 - val_mean_squared_error: 0.1167 - val_rmse: 0.1277
# Epoch 22/100
#  - 358s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0739 - rmse: 0.1666 - val_loss: 0.1084 - val_mean_absolute_error: 0.0794 - val_mean_squared_error: 0.0965 - val_rmse: 0.1184
# Epoch 23/100
#  - 357s - loss: 0.0856 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1667 - val_loss: 0.1055 - val_mean_absolute_error: 0.0797 - val_mean_squared_error: 0.0936 - val_rmse: 0.1193
# Epoch 24/100
#  - 356s - loss: 0.0856 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0737 - rmse: 0.1666 - val_loss: 0.1070 - val_mean_absolute_error: 0.0812 - val_mean_squared_error: 0.0951 - val_rmse: 0.1212
# Epoch 25/100
#  - 358s - loss: 0.0856 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0737 - rmse: 0.1665 - val_loss: 0.1097 - val_mean_absolute_error: 0.0793 - val_mean_squared_error: 0.0978 - val_rmse: 0.1185
# Epoch 26/100
#  - 359s - loss: 0.0857 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0737 - rmse: 0.1664 - val_loss: 0.0987 - val_mean_absolute_error: 0.0804 - val_mean_squared_error: 0.0868 - val_rmse: 0.1187
# Epoch 27/100
#  - 364s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1666 - val_loss: 0.1153 - val_mean_absolute_error: 0.0865 - val_mean_squared_error: 0.1033 - val_rmse: 0.1305
# Epoch 28/100
#  - 356s - loss: 0.0858 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1665 - val_loss: 0.0962 - val_mean_absolute_error: 0.0769 - val_mean_squared_error: 0.0843 - val_rmse: 0.1142
# Epoch 29/100
#  - 357s - loss: 0.0856 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0737 - rmse: 0.1664 - val_loss: 0.1301 - val_mean_absolute_error: 0.0954 - val_mean_squared_error: 0.1182 - val_rmse: 0.1430
# Epoch 30/100
#  - 355s - loss: 0.0857 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0738 - rmse: 0.1666 - val_loss: 0.1087 - val_mean_absolute_error: 0.0797 - val_mean_squared_error: 0.0968 - val_rmse: 0.1190
# Epoch 31/100
#  - 354s - loss: 0.0856 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0737 - rmse: 0.1664 - val_loss: 0.1066 - val_mean_absolute_error: 0.0795 - val_mean_squared_error: 0.0947 - val_rmse: 0.1203
# Epoch 32/100
#  - 355s - loss: 0.0855 - mean_absolute_error: 0.0655 - mean_squared_error: 0.0736 - rmse: 0.1663 - val_loss: 0.1442 - val_mean_absolute_error: 0.0936 - val_mean_squared_error: 0.1324 - val_rmse: 0.1349
# Epoch 33/100
#  - 355s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0739 - rmse: 0.1666 - val_loss: 0.1095 - val_mean_absolute_error: 0.0816 - val_mean_squared_error: 0.0977 - val_rmse: 0.1234
# Epoch 34/100
#  - 356s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1665 - val_loss: 0.1496 - val_mean_absolute_error: 0.1011 - val_mean_squared_error: 0.1377 - val_rmse: 0.1480
# Epoch 35/100
#  - 355s - loss: 0.0856 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1665 - val_loss: 0.1165 - val_mean_absolute_error: 0.0842 - val_mean_squared_error: 0.1046 - val_rmse: 0.1229
# Epoch 36/100
#  - 354s - loss: 0.0858 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0739 - rmse: 0.1667 - val_loss: 0.1286 - val_mean_absolute_error: 0.0864 - val_mean_squared_error: 0.1167 - val_rmse: 0.1314
# Epoch 37/100
#  - 354s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1666 - val_loss: 0.1242 - val_mean_absolute_error: 0.0869 - val_mean_squared_error: 0.1123 - val_rmse: 0.1271
# Epoch 38/100
#  - 354s - loss: 0.0858 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0739 - rmse: 0.1666 - val_loss: 0.1071 - val_mean_absolute_error: 0.0830 - val_mean_squared_error: 0.0952 - val_rmse: 0.1238
# Epoch 39/100
#  - 358s - loss: 0.0857 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0738 - rmse: 0.1665 - val_loss: 0.1006 - val_mean_absolute_error: 0.0806 - val_mean_squared_error: 0.0888 - val_rmse: 0.1182
# Epoch 40/100
#  - 354s - loss: 0.0857 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0739 - rmse: 0.1666 - val_loss: 0.1112 - val_mean_absolute_error: 0.0783 - val_mean_squared_error: 0.0994 - val_rmse: 0.1200
# Epoch 41/100
#  - 359s - loss: 0.0855 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0737 - rmse: 0.1664 - val_loss: 0.0966 - val_mean_absolute_error: 0.0797 - val_mean_squared_error: 0.0849 - val_rmse: 0.1163
# Epoch 42/100
#  - 358s - loss: 0.0856 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0738 - rmse: 0.1665 - val_loss: 0.1018 - val_mean_absolute_error: 0.0856 - val_mean_squared_error: 0.0900 - val_rmse: 0.1228
# Epoch 43/100
#  - 358s - loss: 0.0857 - mean_absolute_error: 0.0657 - mean_squared_error: 0.0739 - rmse: 0.1665 - val_loss: 0.0966 - val_mean_absolute_error: 0.0798 - val_mean_squared_error: 0.0847 - val_rmse: 0.1171
# Test loss: 0.09664502141660271
# val_mean_absolute_error: 0.07975437615750046
# score
# [0.09664502141660271, 0.07975437615750046, 0.08473292208992007, 0.13182987705891788]
# model.metrics_names
# ['loss', 'mean_absolute_error', 'mean_squared_error', 'rmse']
